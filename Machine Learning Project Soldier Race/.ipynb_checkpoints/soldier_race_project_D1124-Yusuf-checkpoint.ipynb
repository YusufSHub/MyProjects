# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sqlalchemy import create_engine
import warnings
from IPython.core.pylabtools import figsize
from scipy.stats import zscore
from scipy import stats
from numpy import percentile
font_title = {'family': 'times new roman', 'color': 'darkred', 
              'weight': 'bold', 'size': 14}

warnings.filterwarnings('ignore')
sns.set_style("whitegrid")

plt.rcParams['figure.dpi'] = 100
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_male = pd.read_csv("ANSUR II MALE Public.csv", encoding="latin")

# %%
df_female = pd.read_csv("ANSUR II FEMALE Public.csv",encoding="latin")

# %%
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10037                             231            1282                    301                 204          1180                      222               177                373                        315               263               466                  65               338                        301                 141                  1011           223            836                587                     476                360             1336           274                 922         245         1095           759                    557                             310          35         65             16              220               713                     91         246                        316                         265                    517                432                 1028           75                182         184          141                548         191                     314           69         345                388                 966
# 1      10038                             194            1379                    320                 207          1292                      225               178                372                        272               250               430                  64               294                        270                 126                   893           186            900                583                     483                350             1440           261                 839         206         1234           835                    549                             329          32         60             23              208               726                     91         249                        341                         247                    468                463                 1117           78                187         189          138                535         180                     307           60         315                335                1048
# 2      10042                             183            1369                    329                 233          1271                      237               196                397                        300               276               450                  69               309                        270                 128                   987           204            861                583                     466                384             1451           287                 874         223         1226           821                    643                             374          36         65             26              204               790                    100         265                        343                         262                    488                469                 1060           84                198         195          146                588         207                     331           70         356                399                1043
# 3      10043                             261            1356                    306                 214          1250                      240               188                384                        364               276               484                  68               340                        294                 144                  1012           253            897                599                     471                372             1430           269                1008         285         1170           804                    640                             351          38         62             22              244               775                     97         265                        331                         309                    529                455                 1069           80                192         186          153                593         206                     332           68         337                402                1029
# 4      10051                             309            1303                    308                 214          1210                      217               182                378                        320               336               525                  67               300                        295                 135                  1281           284            811                607                     467                433             1362           305                1089         290         1112           726                    686                             356          34         65             18              233               732                     88         247                        339                         260                    596                447                 1039           78                183         187          140                522         181                     308           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender      Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    645         363          399                   435                496                             447                      55                      404                  118                335                    368                           1268         113              362                   235                   1062                  327             148            803                     809            513  1647     1560                 1280            1013                 622             174            736           430               110                  844                           1488              406           295                 850         217                      345                   942       657                 152          756  Female  5-Oct-10    Fort Hood  Regular Army          Combat Support        92Y               Germany                   2                 NaN        2   26        61        142        Right hand
# 1                    595         340          375                   483                532                             492                      69                      334                  115                302                    345                           1389         110              426                   259                   1014                  346             142            835                     810            575  1751     1665                 1372            1107                 524             152            771           475               125                  901                           1470              422           254                 708         168                      329                  1032       534                 155          815  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U            California                   3             Mexican        3   21        64        120        Right hand
# 2                    655         345          399                   470                530                             469                      64                      401                  135                325                    369                           1414         122              398                   258                   1049                  362             164            904                     855            568  1779     1711                 1383            1089                 577             164            814           458               129                  882                           1542              419           269                 727         159                      367                  1035       663                 162          799  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        35D                 Texas                   1                 NaN        1   23        68        147        Right hand
# 3                    655         392          435                   469                520                             478                      67                      402                  118                357                    386                           1329         115              394                   250                   1121                  333             157            875                     815            536  1708     1660                 1358            1065                 679             187            736           463               125                  866                           1627              451           302                 923         235                      371                   999       782                 173          818  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U  District of Columbia                   8  Caribbean Islander        2   22        66        175        Right hand
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand        NaN
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand        NaN
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand        NaN

# %%
df.Gender.value_counts()
# Out:
# Male      4082
# Female    1986
# Name: Gender, dtype: int64

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       float64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
#  108  SubjectId                       float64
# dtypes: float64(2), int64(98), object(9)
# memory usage: 5.0+ MB

# %%
df.describe().T
# Out:
#                                  count          mean           std      min       25%      50%       75%       max
# subjectid                       4082.0  20003.370897   6568.435122  10027.0  14270.25  17236.5  27315.75   29452.0
# abdominalextensiondepthsitting  6068.0    246.468688     37.400106    155.0    219.00    242.0    271.00     451.0
# acromialheight                  6068.0   1406.161338     79.091048   1115.0   1350.00   1410.0   1462.00    1683.0
# acromionradialelength           6068.0    327.374423     20.720018    249.0    313.00    328.0    341.25     393.0
# anklecircumference              6068.0    224.891397     16.051833    156.0    214.00    225.0    235.00     293.0
# axillaheight                    6068.0   1299.608767     72.022286   1038.0   1249.00   1302.0   1349.00    1553.0
# balloffootcircumference         6068.0    244.192650     16.845020    186.0    232.00    245.0    256.00     306.0
# balloffootlength                6068.0    194.754614     13.516368    151.0    185.00    195.0    204.00     245.0
# biacromialbreadth               6068.0    399.204186     30.236914    283.0    376.00    404.0    421.00     489.0
# bicepscircumferenceflexed       6068.0    340.934245     41.519866    216.0    311.00    341.0    370.00     490.0
# bicristalbreadth                6068.0    274.735003     19.221034    197.0    262.00    274.0    288.00     362.0
# bideltoidbreadth                6068.0    490.754450     42.135535    357.0    460.00    492.0    520.00     637.0
# bimalleolarbreadth              6068.0     72.252637      5.344590     55.0     68.00     72.0     76.00      91.0
# bitragionchinarc                6068.0    324.896506     17.087501    267.0    314.00    326.0    336.00     385.0
# bitragionsubmandibulararc       6068.0    306.636124     20.794166    245.0    292.00    307.0    321.00     390.0
# bizygomaticbreadth              6068.0    139.723467      7.308457    116.0    135.00    140.0    145.00     174.0
# trochanterionheight             6068.0    882.739947     54.402819    660.0    845.00    882.0    918.00    1095.0
# verticaltrunkcircumferenceusa   6068.0   1630.309492     98.624125   1342.0   1558.00   1628.0   1695.00    1991.0
# waistbacklength                 6068.0    460.524720     36.677909    345.0    435.00    463.0    486.00     598.0
# waistbreadth                    6068.0    317.750000     36.363125    211.0    292.00    316.0    343.00     461.0
# waistcircumference              6068.0    914.501483    114.274513    611.0    829.00    907.0    992.00    1379.0
# waistdepth                      6068.0    229.674028     35.613193    138.0    203.00    226.0    252.25     406.0
# waistfrontlengthsitting         6068.0    377.003790     31.617723    289.0    355.00    375.0    398.00     494.0
# waistheightomphalion            6068.0   1031.501154     62.702388    805.0    988.00   1033.0   1076.00    1245.0
# weightkg                        6068.0    797.093935    156.528164    358.0    682.00    785.0    896.00    1442.0
# wristcircumference              6068.0    169.002966     13.124513    124.0    159.00    170.0    179.00     216.0
# wristheight                     6068.0    830.059987     47.650519    672.0    797.00    830.0    863.00    1009.0
# SubjectNumericRace              6068.0     17.515326    550.949948      1.0      1.00      1.0      2.00   42351.0
# DODRace                         6068.0      1.615030      0.979156      1.0      1.00      1.0      2.00       8.0
# Age                             6068.0     29.761206      8.674650     17.0     23.00     28.0     36.00      58.0
# Heightin                        6068.0     68.257251      3.861954     56.0     66.00     68.0     71.00      94.0
# Weightlbs                       6068.0    174.749670     33.691952      0.0    150.00    173.0    196.00     321.0
# SubjectId                       1986.0  22306.606244  20904.730297  10037.0  17667.00  22096.5  26089.75  920103.0

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

# %%
df.isnull().sum()
# Out:
# subjectid                         1986
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
#                                   ...
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# SubjectId                         4082
# Length: 109, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop("subjectid", axis=1, inplace=True)

# %%
df.drop(["SubjectId"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  \
# 0                             266            1467                    337                 222
# 1                             233            1395                    326                 220
# 2                             287            1430                    341                 230
# 3                             234            1347                    310                 230
# 4                             250            1585                    372                 247
#
#    axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0          1347                      253               202                401
# 1          1293                      245               193                394
# 2          1327                      256               196                427
# 3          1239                      262               199                401
# 4          1478                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                        369               274               493                  71
# 1                        338               257               479                  67
# 2                        408               261               544                  75
# 3                        359               262               518                  73
# 4                        356               263               524                  80
#
#    bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0               319                        291                 142                   979
# 1               344                        320                 135                   944
# 2               345                        330                 135                  1054
# 3               328                        309                 143                   991
# 4               340                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0           240            882                619                     509                373
# 1           232            870                584                     468                357
# 2           258            901                623                     506                412
# 3           242            821                560                     437                395
# 4           275           1080                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0             1535           291                1074         259         1292           877
# 1             1471           269                1021         253         1244           851
# 2             1501           288                1120         267         1288           854
# 3             1423           296                1114         262         1205           769
# 4             1684           304                1048         232         1452          1014
#
#    crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                    607                             351          36         71             19
# 1                    615                             376          33         62             18
# 2                    636                             359          40         61             23
# 3                    590                             341          39         66             25
# 4                    682                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                        349                         299                    575
# 1                        348                         289                    523
# 2                        355                         357                    575
# 3                        352                         318                    593
# 4                        399                         324                    605
#
#    forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                477                 1136           90                214         193
# 1                476                 1096           86                203         195
# 2                491                 1115           93                220         203
# 3                467                 1034           91                217         194
# 4                550                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0          150                583         206                     326           70         332
# 1          146                568         201                     334           72         312
# 2          148                573         202                     356           70         349
# 3          158                576         199                     341           68         338
# 4          153                566         197                     374           69         332
#
#    ...  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  \
# 0  ...                             500                      77                      391
# 1  ...                             488                      73                      371
# 2  ...                             482                      72                      409
# 3  ...                             452                      76                      393
# 4  ...                             585                      85                      458
#
#    mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                  118                400                    436                           1447
# 1                  131                380                    420                           1380
# 2                  123                403                    434                           1447
# 3                  106                407                    446                           1357
# 4                  135                398                    430                           1572
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  \
# 0         113              437                   273                   1151                  368
# 1         118              417                   254                   1119                  353
# 2         121              431                   268                   1276                  367
# 3         118              393                   249                   1155                  330
# 4         132              523                   302                   1231                  400
#
#    shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 0             145            928                     883            600  1782     1776
# 1             141            884                     868            564  1745     1702
# 2             167            917                     910            604  1867     1735
# 3             148            903                     848            550  1708     1655
# 4             180            919                     995            641  2035     1914
#
#    suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  \
# 0                 1449            1092                 610             164            786
# 1                 1387            1076                 572             169            822
# 2                 1438            1105                 685             198            807
# 3                 1346            1021                 604             180            803
# 4                 1596            1292                 672             194            962
#
#    tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0           491               140                  919                           1700
# 1           476               120                  918                           1627
# 2           477               125                  918                           1678
# 3           445               127                  847                           1625
# 4           584               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0              501           329                 933         240                      440
# 1              432           316                 870         225                      371
# 2              472           329                 964         255                      411
# 3              461           315                 857         205                      399
# 4              467           303                 868         214                      379
#
#    waistheightomphalion  weightkg  wristcircumference  wristheight  Gender       Date  \
# 0                  1054       815                 175          853    Male   4-Oct-10
# 1                  1054       726                 167          815    Male   4-Oct-10
# 2                  1041       929                 180          831    Male   4-Oct-10
# 3                   968       794                 176          793    Male  12-Oct-10
# 4                  1245       946                 188          954    Male  12-Oct-10
#
#    Installation     Component                  Branch  PrimaryMOS  SubjectsBirthLocation  \
# 0     Fort Hood  Regular Army             Combat Arms         19D           North Dakota
# 1     Fort Hood  Regular Army          Combat Support         68W               New York
# 2     Fort Hood  Regular Army          Combat Support         68W               New York
# 3     Fort Hood  Regular Army  Combat Service Support         88M              Wisconsin
# 4     Fort Hood  Regular Army  Combat Service Support         92G         North Carolina
#
#   SubjectNumericRace Ethnicity DODRace Age Heightin Weightlbs WritingPreference
# 0                  1       NaN       1  41       71       180        Right hand
# 1                  1       NaN       1  35       68       160         Left hand
# 2                  2       NaN       2  42       68       205         Left hand
# 3                  1       NaN       1  31       66       175        Right hand
# 4                  2       NaN       2  21       77       213        Right hand
#
# [5 rows x 107 columns]

# %%
df.shape
# Out:
# (6068, 107)

# %%
df['Ethnicity'].value_counts()
# Out:
# Mexican                                      357
# Puerto Rican                                 183
# Caribbean Islander                           124
# Filipino                                      67
# Cherokee                                      65
#                                             ...
# Costa Rican Cuban                              1
# Blackfoot Caribbean Islander Puerto Rican      1
# Cuban Unreadable Native American Tribe         1
# Ute                                            1
# Apache Blackfoot Cherokee Crow                 1
# Name: Ethnicity, Length: 209, dtype: int64

# %%
df['Ethnicity'].value_counts(dropna = False, normalize = True) #normalize = percentage
# Out:
# NaN                               0.765821
# Mexican                           0.058833
# Puerto Rican                      0.030158
# Caribbean Islander                0.020435
# Filipino                          0.011042
#                                     ...
# Lakota Sioux                      0.000165
# Cuban Salvadoran                  0.000165
# Caribbean Islander Dominican      0.000165
# Azorean                           0.000165
# Apache Blackfoot Cherokee Crow    0.000165
# Name: Ethnicity, Length: 210, dtype: float64

# %% [markdown]
# I decide to drop beacuse too many missing values.

# %%
df.drop("Ethnicity", axis=1, inplace=True)

# %%
df.shape
# Out:
# (6068, 106)

# %%
numerical= df.select_dtypes('number').columns

categorical = df.select_dtypes('object').columns

print('---------------------')
print(f'Numerical Columns:  {df[numerical].columns}')
print('---------------------')
print(f'Categorical Columns: {df[categorical].columns}')
print('---------------------')
# Out:
# ---------------------
# Numerical Columns:  Index(['abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength',
#        'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength',
#        'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth',
#        'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth',
#        'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength',
#        'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth',
#        'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion',
#        'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion',
#        'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength',
#        'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth',
#        'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference',
#        'handlength', 'headbreadth', 'headcircumference', 'headlength', 'heelanklecircumference',
#        'heelbreadth', 'hipbreadth', 'hipbreadthsitting', 'iliocristaleheight',
#        'interpupillarybreadth', 'interscyei', 'interscyeii', 'kneeheightmidpatella',
#        'kneeheightsitting', 'lateralfemoralepicondyleheight', 'lateralmalleolusheight',
#        'lowerthighcircumference', 'mentonsellionlength', 'neckcircumference',
#        'neckcircumferencebase', 'overheadfingertipreachsitting', 'palmlength', 'poplitealheight',
#        'radialestylionlength', 'shouldercircumference', 'shoulderelbowlength', 'shoulderlength',
#        'sittingheight', 'sleevelengthspinewrist', 'sleeveoutseam', 'span', 'stature',
#        'suprasternaleheight', 'tenthribheight', 'thighcircumference', 'thighclearance',
#        'thumbtipreach', 'tibialheight', 'tragiontopofhead', 'trochanterionheight',
#        'verticaltrunkcircumferenceusa', 'waistbacklength', 'waistbreadth', 'waistcircumference',
#        'waistdepth', 'waistfrontlengthsitting', 'waistheightomphalion', 'weightkg',
#        'wristcircumference', 'wristheight', 'SubjectNumericRace', 'DODRace', 'Age', 'Heightin',
#        'Weightlbs'],
#       dtype='object')
# ---------------------
# Categorical Columns: Index(['Gender', 'Date', 'Installation', 'Component', 'Branch', 'PrimaryMOS',
#        'SubjectsBirthLocation', 'WritingPreference'],
#       dtype='object')
# ---------------------

# %%
df.select_dtypes("object")
# Out:
#       Gender       Date Installation            Component                  Branch PrimaryMOS  \
# 0       Male   4-Oct-10    Fort Hood         Regular Army             Combat Arms        19D
# 1       Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W
# 2       Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W
# 3       Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        88M
# 4       Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        92G
# ...      ...        ...          ...                  ...                     ...        ...
# 6063  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A
# 6064  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        25U
# 6065  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A
# 6066  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        92Y
# 6067  Female  28-May-11   Fort McCoy  Army National Guard          Combat Support        92F
#
#      SubjectsBirthLocation WritingPreference
# 0             North Dakota        Right hand
# 1                 New York         Left hand
# 2                 New York         Left hand
# 3                Wisconsin        Right hand
# 4           North Carolina        Right hand
# ...                    ...               ...
# 6063                 Texas        Right hand
# 6064                 Texas        Right hand
# 6065                 Texas        Right hand
# 6066                 Texas        Right hand
# 6067                 Texas        Right hand
#
# [6068 rows x 8 columns]

# %% [markdown]
# I will drop these cat columns. they got no use to my ML

# %%
df.drop(['Date', 'Installation', 'Component', 'Branch', 'WritingPreference', 'PrimaryMOS'], inplace = True, axis = 1)

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  \
# 0                             266            1467                    337                 222
# 1                             233            1395                    326                 220
# 2                             287            1430                    341                 230
# 3                             234            1347                    310                 230
# 4                             250            1585                    372                 247
#
#    axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0          1347                      253               202                401
# 1          1293                      245               193                394
# 2          1327                      256               196                427
# 3          1239                      262               199                401
# 4          1478                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                        369               274               493                  71
# 1                        338               257               479                  67
# 2                        408               261               544                  75
# 3                        359               262               518                  73
# 4                        356               263               524                  80
#
#    bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0               319                        291                 142                   979
# 1               344                        320                 135                   944
# 2               345                        330                 135                  1054
# 3               328                        309                 143                   991
# 4               340                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0           240            882                619                     509                373
# 1           232            870                584                     468                357
# 2           258            901                623                     506                412
# 3           242            821                560                     437                395
# 4           275           1080                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0             1535           291                1074         259         1292           877
# 1             1471           269                1021         253         1244           851
# 2             1501           288                1120         267         1288           854
# 3             1423           296                1114         262         1205           769
# 4             1684           304                1048         232         1452          1014
#
#    crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                    607                             351          36         71             19
# 1                    615                             376          33         62             18
# 2                    636                             359          40         61             23
# 3                    590                             341          39         66             25
# 4                    682                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                        349                         299                    575
# 1                        348                         289                    523
# 2                        355                         357                    575
# 3                        352                         318                    593
# 4                        399                         324                    605
#
#    forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                477                 1136           90                214         193
# 1                476                 1096           86                203         195
# 2                491                 1115           93                220         203
# 3                467                 1034           91                217         194
# 4                550                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0          150                583         206                     326           70         332
# 1          146                568         201                     334           72         312
# 2          148                573         202                     356           70         349
# 3          158                576         199                     341           68         338
# 4          153                566         197                     374           69         332
#
#    hipbreadthsitting  iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                366                1071                    685         422          441
# 1                356                1046                    620         441          447
# 2                393                1053                    665         462          475
# 3                367                 986                    640         458          461
# 4                372                1251                    675         481          505
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   502                560                             500
# 1                   490                540                             488
# 2                   496                556                             482
# 3                   460                511                             452
# 4                   612                666                             585
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      77                      391                  118                400
# 1                      73                      371                  131                380
# 2                      72                      409                  123                403
# 3                      76                      393                  106                407
# 4                      85                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  \
# 0                    436                           1447         113              437
# 1                    420                           1380         118              417
# 2                    434                           1447         121              431
# 3                    446                           1357         118              393
# 4                    430                           1572         132              523
#
#    radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                   273                   1151                  368             145
# 1                   254                   1119                  353             141
# 2                   268                   1276                  367             167
# 3                   249                   1155                  330             148
# 4                   302                   1231                  400             180
#
#    sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  \
# 0            928                     883            600  1782     1776                 1449
# 1            884                     868            564  1745     1702                 1387
# 2            917                     910            604  1867     1735                 1438
# 3            903                     848            550  1708     1655                 1346
# 4            919                     995            641  2035     1914                 1596
#
#    tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0            1092                 610             164            786           491
# 1            1076                 572             169            822           476
# 2            1105                 685             198            807           477
# 3            1021                 604             180            803           445
# 4            1292                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  \
# 0               140                  919                           1700              501
# 1               120                  918                           1627              432
# 2               125                  918                           1678              472
# 3               127                  847                           1625              461
# 4               122                 1090                           1679              467
#
#    waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  \
# 0           329                 933         240                      440                  1054
# 1           316                 870         225                      371                  1054
# 2           329                 964         255                      411                  1041
# 3           315                 857         205                      399                   968
# 4           303                 868         214                      379                  1245
#
#    weightkg  wristcircumference  wristheight Gender SubjectsBirthLocation  SubjectNumericRace  \
# 0       815                 175          853   Male          North Dakota                   1
# 1       726                 167          815   Male              New York                   1
# 2       929                 180          831   Male              New York                   2
# 3       794                 176          793   Male             Wisconsin                   1
# 4       946                 188          954   Male        North Carolina                   2
#
#    DODRace  Age  Heightin  Weightlbs
# 0        1   41        71        180
# 1        1   35        68        160
# 2        2   42        68        205
# 3        1   31        66        175
# 4        2   21        77        213

# %%
df.shape
# Out:
# (6068, 100)

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
df['DODRace'] = df['DODRace'].map({1: 'White',
                  2: 'Black',
                  3: 'Hispanic',
                  4: 'Asian',
                  5: 'Native_American',
                  6: 'Pacific_Islander',
                  8: 'Other'})

# %%
df.DODRace.value_counts()
# Out:
# White               3792
# Black               1298
# Hispanic             679
# Asian                188
# Pacific_Islander      59
# Native_American       49
# Other                  3
# Name: DODRace, dtype: int64

# %% [markdown]
# I decide to work with first 3 races.

# %%
df1 = df[(df['DODRace']=='White')|(df['DODRace']=='Black')| (df['DODRace']=='Hispanic')]

# %%
df1.reset_index(drop = True, inplace = True)
df1
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  \
# 0                                266            1467                    337                 222
# 1                                233            1395                    326                 220
# 2                                287            1430                    341                 230
# 3                                234            1347                    310                 230
# 4                                250            1585                    372                 247
# ...                              ...             ...                    ...                 ...
# 5764                             285            1392                    335                 223
# 5765                             262            1324                    301                 202
# 5766                             260            1334                    318                 213
# 5767                             205            1293                    302                 199
# 5768                             238            1346                    308                 210
#
#       axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0             1347                      253               202                401
# 1             1293                      245               193                394
# 2             1327                      256               196                427
# 3             1239                      262               199                401
# 4             1478                      267               224                435
# ...            ...                      ...               ...                ...
# 5764          1297                      252               196                368
# 5765          1204                      236               181                378
# 5766          1259                      234               183                363
# 5767          1207                      213               163                376
# 5768          1256                      236               188                361
#
#       bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                           369               274               493                  71
# 1                           338               257               479                  67
# 2                           408               261               544                  75
# 3                           359               262               518                  73
# 4                           356               263               524                  80
# ...                         ...               ...               ...                 ...
# 5764                        299               312               477                  72
# 5765                        294               287               468                  66
# 5766                        332               299               460                  70
# 5767                        276               280               426                  62
# 5768                        285               279               433                  71
#
#       bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                  319                        291                 142                   979
# 1                  344                        320                 135                   944
# 2                  345                        330                 135                  1054
# 3                  328                        309                 143                   991
# 4                  340                        310                 138                  1029
# ...                ...                        ...                 ...                   ...
# 5764               306                        282                 136                  1089
# 5765               309                        311                 145                  1016
# 5766               317                        311                 139                  1063
# 5767               282                        267                 137                  1051
# 5768               304                        278                 129                   974
#
#       buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0              240            882                619                     509                373
# 1              232            870                584                     468                357
# 2              258            901                623                     506                412
# 3              242            821                560                     437                395
# 4              275           1080                706                     567                425
# ...            ...            ...                ...                     ...                ...
# 5764           255            856                652                     541                373
# 5765           246            818                572                     464                375
# 5766           262            846                637                     525                370
# 5767           225            786                582                     480                370
# 5768           217            820                586                     479                343
#
#       cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0                1535           291                1074         259         1292           877
# 1                1471           269                1021         253         1244           851
# 2                1501           288                1120         267         1288           854
# 3                1423           296                1114         262         1205           769
# 4                1684           304                1048         232         1452          1014
# ...               ...           ...                 ...         ...          ...           ...
# 5764             1457           290                1082         293         1258           779
# 5765             1390           291                1016         269         1151           732
# 5766             1412           285                1093         286         1166           793
# 5767             1377           270                 922         243         1137           763
# 5768             1401           272                 902         219         1186           783
#
#       crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                       607                             351          36         71             19
# 1                       615                             376          33         62             18
# 2                       636                             359          40         61             23
# 3                       590                             341          39         66             25
# 4                       682                             382          32         56             19
# ...                     ...                             ...         ...        ...            ...
# 5764                    732                             382          36         60             19
# 5765                    647                             331          36         65             23
# 5766                    609                             326          39         62             18
# 5767                    575                             310          35         62             21
# 5768                    536                             307          35         58             23
#
#       elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0                 247               802                    101         273
# 1                 232               781                     98         263
# 2                 237               810                    103         270
# 3                 272               794                    106         267
# 4                 188               814                    111         305
# ...               ...               ...                    ...         ...
# 5764              210               746                    103         259
# 5765              274               770                    101         245
# 5766              204               739                     97         249
# 5767              222               738                     91         226
# 5768              243               754                    100         239
#
#       forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                           349                         299                    575
# 1                           348                         289                    523
# 2                           355                         357                    575
# 3                           352                         318                    593
# 4                           399                         324                    605
# ...                         ...                         ...                    ...
# 5764                        328                         262                    514
# 5765                        319                         261                    514
# 5766                        338                         288                    530
# 5767                        306                         258                    430
# 5768                        314                         259                    464
#
#       forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                   477                 1136           90                214         193
# 1                   476                 1096           86                203         195
# 2                   491                 1115           93                220         203
# 3                   467                 1034           91                217         194
# 4                   550                 1279           94                222         218
# ...                 ...                  ...          ...                ...         ...
# 5764                456                 1085           81                197         193
# 5765                440                  985           81                196         183
# 5766                459                 1050           82                192         191
# 5767                425                  995           74                177         176
# 5768                439                 1053           78                187         177
#
#       headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0             150                583         206                     326           70         332
# 1             146                568         201                     334           72         312
# 2             148                573         202                     356           70         349
# 3             158                576         199                     341           68         338
# 4             153                566         197                     374           69         332
# ...           ...                ...         ...                     ...          ...         ...
# 5764          151                582         205                     321           75         381
# 5765          160                570         186                     296           61         347
# 5766          144                559         190                     318           72         364
# 5767          149                558         186                     280           59         369
# 5768          148                561         189                     310           78         332
#
#       hipbreadthsitting  iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                   366                1071                    685         422          441
# 1                   356                1046                    620         441          447
# 2                   393                1053                    665         462          475
# 3                   367                 986                    640         458          461
# 4                   372                1251                    675         481          505
# ...                 ...                 ...                    ...         ...          ...
# 5764                413                1048                    615         373          390
# 5765                377                 974                    650         400          411
# 5766                400                 986                    640         400          412
# 5767                411                 971                    640         383          418
# 5768                376                 994                    595         333          373
#
#       kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                      502                560                             500
# 1                      490                540                             488
# 2                      496                556                             482
# 3                      460                511                             452
# 4                      612                666                             585
# ...                    ...                ...                             ...
# 5764                   462                535                             486
# 5765                   433                483                             457
# 5766                   450                517                             476
# 5767                   432                491                             445
# 5768                   444                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                         77                      391                  118                400
# 1                         73                      371                  131                380
# 2                         72                      409                  123                403
# 3                         76                      393                  106                407
# 4                         85                      458                  135                398
# ...                      ...                      ...                  ...                ...
# 5764                      61                      423                  121                369
# 5765                      58                      383                  130                359
# 5766                      57                      412                  111                352
# 5767                      58                      400                  119                326
# 5768                      66                      372                  114                325
#
#       neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  \
# 0                       436                           1447         113              437
# 1                       420                           1380         118              417
# 2                       434                           1447         121              431
# 3                       446                           1357         118              393
# 4                       430                           1572         132              523
# ...                     ...                            ...         ...              ...
# 5764                    391                           1307         118              414
# 5765                    399                           1323          99              377
# 5766                    402                           1318         116              392
# 5767                    380                           1286         111              375
# 5768                    381                           1372         112              390
#
#       radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      273                   1151                  368             145
# 1                      254                   1119                  353             141
# 2                      268                   1276                  367             167
# 3                      249                   1155                  330             148
# 4                      302                   1231                  400             180
# ...                    ...                    ...                  ...             ...
# 5764                   237                   1036                  354             145
# 5765                   237                   1051                  318             142
# 5766                   259                   1054                  338             136
# 5767                   230                    996                  321             136
# 5768                   249                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  \
# 0               928                     883            600  1782     1776                 1449
# 1               884                     868            564  1745     1702                 1387
# 2               917                     910            604  1867     1735                 1438
# 3               903                     848            550  1708     1655                 1346
# 4               919                     995            641  2035     1914                 1596
# ...             ...                     ...            ...   ...      ...                  ...
# 5764            865                     840            555  1716     1687                 1391
# 5765            881                     794            525  1620     1613                 1316
# 5766            841                     848            566  1740     1644                 1337
# 5767            854                     791            530  1628     1616                 1288
# 5768            861                     821            542  1685     1641                 1334
#
#       tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0               1092                 610             164            786           491
# 1               1076                 572             169            822           476
# 2               1105                 685             198            807           477
# 3               1021                 604             180            803           445
# 4               1292                 672             194            962           584
# ...              ...                 ...             ...            ...           ...
# 5764            1119                 660             155            749           446
# 5765            1043                 616             157            721           422
# 5766            1054                 640             159            758           449
# 5767            1028                 623             163            725           419
# 5768            1089                 592             162            762           436
#
#       tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  \
# 0                  140                  919                           1700              501
# 1                  120                  918                           1627              432
# 2                  125                  918                           1678              472
# 3                  127                  847                           1625              461
# 4                  122                 1090                           1679              467
# ...                ...                  ...                            ...              ...
# 5764               136                  872                           1706              447
# 5765               131                  838                           1648              446
# 5766               127                  862                           1590              444
# 5767               135                  802                           1525              450
# 5768               130                  849                           1547              462
#
#       waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  \
# 0              329                 933         240                      440                  1054
# 1              316                 870         225                      371                  1054
# 2              329                 964         255                      411                  1041
# 3              315                 857         205                      399                   968
# 4              303                 868         214                      379                  1245
# ...            ...                 ...         ...                      ...                   ...
# 5764           334                1043         265                      370                  1002
# 5765           334                 971         243                      374                   958
# 5766           335                 982         254                      351                   970
# 5767           298                 837         208                      335                   952
# 5768           299                 891         223                      394                   943
#
#       weightkg  wristcircumference  wristheight  Gender SubjectsBirthLocation  SubjectNumericRace  \
# 0          815                 175          853    Male          North Dakota                   1
# 1          726                 167          815    Male              New York                   1
# 2          929                 180          831    Male              New York                   2
# 3          794                 176          793    Male             Wisconsin                   1
# 4          946                 188          954    Male        North Carolina                   2
# ...        ...                 ...          ...     ...                   ...                 ...
# 5764       832                 162          836  Female                 Texas                   3
# 5765       717                 157          804  Female                 Texas                   3
# 5766       762                 159          774  Female                 Texas                   2
# 5767       632                 146          769  Female                 Texas                   3
# 5768       610                 154          797  Female                 Texas                   3
#
#        DODRace  Age  Heightin  Weightlbs
# 0        White   41        71        180
# 1        White   35        68        160
# 2        Black   42        68        205
# 3        White   31        66        175
# 4        Black   21        77        213
# ...        ...  ...       ...        ...
# 5764  Hispanic   51        67        180
# 5765  Hispanic   40        63        150
# 5766     Black   40        66        168
# 5767  Hispanic   31        63        133
# 5768  Hispanic   27        66        132
#
# [5769 rows x 100 columns]

# %%
df1.select_dtypes('object')
# Out:
#       Gender SubjectsBirthLocation   DODRace
# 0       Male          North Dakota     White
# 1       Male              New York     White
# 2       Male              New York     Black
# 3       Male             Wisconsin     White
# 4       Male        North Carolina     Black
# ...      ...                   ...       ...
# 5764  Female                 Texas  Hispanic
# 5765  Female                 Texas  Hispanic
# 5766  Female                 Texas     Black
# 5767  Female                 Texas  Hispanic
# 5768  Female                 Texas  Hispanic
#
# [5769 rows x 3 columns]

# %%
df1['SubjectsBirthLocation'].nunique()
# Out:
# 136

# %%
df1.Gender.value_counts()
# Out:
# Male      3899
# Female    1870
# Name: Gender, dtype: int64

# %%
df1.shape
# Out:
# (5769, 100)

# %%
df1
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  \
# 0                                266            1467                    337                 222
# 1                                233            1395                    326                 220
# 2                                287            1430                    341                 230
# 3                                234            1347                    310                 230
# 4                                250            1585                    372                 247
# ...                              ...             ...                    ...                 ...
# 5764                             285            1392                    335                 223
# 5765                             262            1324                    301                 202
# 5766                             260            1334                    318                 213
# 5767                             205            1293                    302                 199
# 5768                             238            1346                    308                 210
#
#       axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0             1347                      253               202                401
# 1             1293                      245               193                394
# 2             1327                      256               196                427
# 3             1239                      262               199                401
# 4             1478                      267               224                435
# ...            ...                      ...               ...                ...
# 5764          1297                      252               196                368
# 5765          1204                      236               181                378
# 5766          1259                      234               183                363
# 5767          1207                      213               163                376
# 5768          1256                      236               188                361
#
#       bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                           369               274               493                  71
# 1                           338               257               479                  67
# 2                           408               261               544                  75
# 3                           359               262               518                  73
# 4                           356               263               524                  80
# ...                         ...               ...               ...                 ...
# 5764                        299               312               477                  72
# 5765                        294               287               468                  66
# 5766                        332               299               460                  70
# 5767                        276               280               426                  62
# 5768                        285               279               433                  71
#
#       bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                  319                        291                 142                   979
# 1                  344                        320                 135                   944
# 2                  345                        330                 135                  1054
# 3                  328                        309                 143                   991
# 4                  340                        310                 138                  1029
# ...                ...                        ...                 ...                   ...
# 5764               306                        282                 136                  1089
# 5765               309                        311                 145                  1016
# 5766               317                        311                 139                  1063
# 5767               282                        267                 137                  1051
# 5768               304                        278                 129                   974
#
#       buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0              240            882                619                     509                373
# 1              232            870                584                     468                357
# 2              258            901                623                     506                412
# 3              242            821                560                     437                395
# 4              275           1080                706                     567                425
# ...            ...            ...                ...                     ...                ...
# 5764           255            856                652                     541                373
# 5765           246            818                572                     464                375
# 5766           262            846                637                     525                370
# 5767           225            786                582                     480                370
# 5768           217            820                586                     479                343
#
#       cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0                1535           291                1074         259         1292           877
# 1                1471           269                1021         253         1244           851
# 2                1501           288                1120         267         1288           854
# 3                1423           296                1114         262         1205           769
# 4                1684           304                1048         232         1452          1014
# ...               ...           ...                 ...         ...          ...           ...
# 5764             1457           290                1082         293         1258           779
# 5765             1390           291                1016         269         1151           732
# 5766             1412           285                1093         286         1166           793
# 5767             1377           270                 922         243         1137           763
# 5768             1401           272                 902         219         1186           783
#
#       crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                       607                             351          36         71             19
# 1                       615                             376          33         62             18
# 2                       636                             359          40         61             23
# 3                       590                             341          39         66             25
# 4                       682                             382          32         56             19
# ...                     ...                             ...         ...        ...            ...
# 5764                    732                             382          36         60             19
# 5765                    647                             331          36         65             23
# 5766                    609                             326          39         62             18
# 5767                    575                             310          35         62             21
# 5768                    536                             307          35         58             23
#
#       elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0                 247               802                    101         273
# 1                 232               781                     98         263
# 2                 237               810                    103         270
# 3                 272               794                    106         267
# 4                 188               814                    111         305
# ...               ...               ...                    ...         ...
# 5764              210               746                    103         259
# 5765              274               770                    101         245
# 5766              204               739                     97         249
# 5767              222               738                     91         226
# 5768              243               754                    100         239
#
#       forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                           349                         299                    575
# 1                           348                         289                    523
# 2                           355                         357                    575
# 3                           352                         318                    593
# 4                           399                         324                    605
# ...                         ...                         ...                    ...
# 5764                        328                         262                    514
# 5765                        319                         261                    514
# 5766                        338                         288                    530
# 5767                        306                         258                    430
# 5768                        314                         259                    464
#
#       forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                   477                 1136           90                214         193
# 1                   476                 1096           86                203         195
# 2                   491                 1115           93                220         203
# 3                   467                 1034           91                217         194
# 4                   550                 1279           94                222         218
# ...                 ...                  ...          ...                ...         ...
# 5764                456                 1085           81                197         193
# 5765                440                  985           81                196         183
# 5766                459                 1050           82                192         191
# 5767                425                  995           74                177         176
# 5768                439                 1053           78                187         177
#
#       headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0             150                583         206                     326           70         332
# 1             146                568         201                     334           72         312
# 2             148                573         202                     356           70         349
# 3             158                576         199                     341           68         338
# 4             153                566         197                     374           69         332
# ...           ...                ...         ...                     ...          ...         ...
# 5764          151                582         205                     321           75         381
# 5765          160                570         186                     296           61         347
# 5766          144                559         190                     318           72         364
# 5767          149                558         186                     280           59         369
# 5768          148                561         189                     310           78         332
#
#       hipbreadthsitting  iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                   366                1071                    685         422          441
# 1                   356                1046                    620         441          447
# 2                   393                1053                    665         462          475
# 3                   367                 986                    640         458          461
# 4                   372                1251                    675         481          505
# ...                 ...                 ...                    ...         ...          ...
# 5764                413                1048                    615         373          390
# 5765                377                 974                    650         400          411
# 5766                400                 986                    640         400          412
# 5767                411                 971                    640         383          418
# 5768                376                 994                    595         333          373
#
#       kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                      502                560                             500
# 1                      490                540                             488
# 2                      496                556                             482
# 3                      460                511                             452
# 4                      612                666                             585
# ...                    ...                ...                             ...
# 5764                   462                535                             486
# 5765                   433                483                             457
# 5766                   450                517                             476
# 5767                   432                491                             445
# 5768                   444                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                         77                      391                  118                400
# 1                         73                      371                  131                380
# 2                         72                      409                  123                403
# 3                         76                      393                  106                407
# 4                         85                      458                  135                398
# ...                      ...                      ...                  ...                ...
# 5764                      61                      423                  121                369
# 5765                      58                      383                  130                359
# 5766                      57                      412                  111                352
# 5767                      58                      400                  119                326
# 5768                      66                      372                  114                325
#
#       neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  \
# 0                       436                           1447         113              437
# 1                       420                           1380         118              417
# 2                       434                           1447         121              431
# 3                       446                           1357         118              393
# 4                       430                           1572         132              523
# ...                     ...                            ...         ...              ...
# 5764                    391                           1307         118              414
# 5765                    399                           1323          99              377
# 5766                    402                           1318         116              392
# 5767                    380                           1286         111              375
# 5768                    381                           1372         112              390
#
#       radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      273                   1151                  368             145
# 1                      254                   1119                  353             141
# 2                      268                   1276                  367             167
# 3                      249                   1155                  330             148
# 4                      302                   1231                  400             180
# ...                    ...                    ...                  ...             ...
# 5764                   237                   1036                  354             145
# 5765                   237                   1051                  318             142
# 5766                   259                   1054                  338             136
# 5767                   230                    996                  321             136
# 5768                   249                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  \
# 0               928                     883            600  1782     1776                 1449
# 1               884                     868            564  1745     1702                 1387
# 2               917                     910            604  1867     1735                 1438
# 3               903                     848            550  1708     1655                 1346
# 4               919                     995            641  2035     1914                 1596
# ...             ...                     ...            ...   ...      ...                  ...
# 5764            865                     840            555  1716     1687                 1391
# 5765            881                     794            525  1620     1613                 1316
# 5766            841                     848            566  1740     1644                 1337
# 5767            854                     791            530  1628     1616                 1288
# 5768            861                     821            542  1685     1641                 1334
#
#       tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0               1092                 610             164            786           491
# 1               1076                 572             169            822           476
# 2               1105                 685             198            807           477
# 3               1021                 604             180            803           445
# 4               1292                 672             194            962           584
# ...              ...                 ...             ...            ...           ...
# 5764            1119                 660             155            749           446
# 5765            1043                 616             157            721           422
# 5766            1054                 640             159            758           449
# 5767            1028                 623             163            725           419
# 5768            1089                 592             162            762           436
#
#       tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  \
# 0                  140                  919                           1700              501
# 1                  120                  918                           1627              432
# 2                  125                  918                           1678              472
# 3                  127                  847                           1625              461
# 4                  122                 1090                           1679              467
# ...                ...                  ...                            ...              ...
# 5764               136                  872                           1706              447
# 5765               131                  838                           1648              446
# 5766               127                  862                           1590              444
# 5767               135                  802                           1525              450
# 5768               130                  849                           1547              462
#
#       waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  \
# 0              329                 933         240                      440                  1054
# 1              316                 870         225                      371                  1054
# 2              329                 964         255                      411                  1041
# 3              315                 857         205                      399                   968
# 4              303                 868         214                      379                  1245
# ...            ...                 ...         ...                      ...                   ...
# 5764           334                1043         265                      370                  1002
# 5765           334                 971         243                      374                   958
# 5766           335                 982         254                      351                   970
# 5767           298                 837         208                      335                   952
# 5768           299                 891         223                      394                   943
#
#       weightkg  wristcircumference  wristheight  Gender SubjectsBirthLocation  SubjectNumericRace  \
# 0          815                 175          853    Male          North Dakota                   1
# 1          726                 167          815    Male              New York                   1
# 2          929                 180          831    Male              New York                   2
# 3          794                 176          793    Male             Wisconsin                   1
# 4          946                 188          954    Male        North Carolina                   2
# ...        ...                 ...          ...     ...                   ...                 ...
# 5764       832                 162          836  Female                 Texas                   3
# 5765       717                 157          804  Female                 Texas                   3
# 5766       762                 159          774  Female                 Texas                   2
# 5767       632                 146          769  Female                 Texas                   3
# 5768       610                 154          797  Female                 Texas                   3
#
#        DODRace  Age  Heightin  Weightlbs
# 0        White   41        71        180
# 1        White   35        68        160
# 2        Black   42        68        205
# 3        White   31        66        175
# 4        Black   21        77        213
# ...        ...  ...       ...        ...
# 5764  Hispanic   51        67        180
# 5765  Hispanic   40        63        150
# 5766     Black   40        66        168
# 5767  Hispanic   31        63        133
# 5768  Hispanic   27        66        132
#
# [5769 rows x 100 columns]

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = df1.drop("DODRace",axis=1)
X = pd.get_dummies(data=X, drop_first=True)
y = df1.DODRace

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify = y)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 233)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 233)
# Test target shape    :  (1154,)

# %%
df1.isnull().sum()
# Out:
# abdominalextensiondepthsitting    0
# acromialheight                    0
# acromionradialelength             0
# anklecircumference                0
# axillaheight                      0
# balloffootcircumference           0
# balloffootlength                  0
# biacromialbreadth                 0
# bicepscircumferenceflexed         0
# bicristalbreadth                  0
# bideltoidbreadth                  0
# bimalleolarbreadth                0
# bitragionchinarc                  0
# bitragionsubmandibulararc         0
# bizygomaticbreadth                0
# buttockcircumference              0
# buttockdepth                      0
# buttockheight                     0
# buttockkneelength                 0
# buttockpopliteallength            0
# calfcircumference                 0
# cervicaleheight                   0
# chestbreadth                      0
# chestcircumference                0
# chestdepth                        0
# chestheight                       0
# crotchheight                      0
# crotchlengthomphalion             0
# crotchlengthposterioromphalion    0
# earbreadth                        0
# earlength                         0
# earprotrusion                     0
# elbowrestheight                   0
# eyeheightsitting                  0
# footbreadthhorizontal             0
# footlength                        0
# forearmcenterofgriplength         0
# forearmcircumferenceflexed        0
# forearmforearmbreadth             0
# forearmhandlength                 0
# functionalleglength               0
# handbreadth                       0
# handcircumference                 0
# handlength                        0
# headbreadth                       0
# headcircumference                 0
# headlength                        0
# heelanklecircumference            0
# heelbreadth                       0
# hipbreadth                        0
# hipbreadthsitting                 0
# iliocristaleheight                0
# interpupillarybreadth             0
# interscyei                        0
# interscyeii                       0
# kneeheightmidpatella              0
# kneeheightsitting                 0
# lateralfemoralepicondyleheight    0
# lateralmalleolusheight            0
# lowerthighcircumference           0
# mentonsellionlength               0
# neckcircumference                 0
# neckcircumferencebase             0
# overheadfingertipreachsitting     0
# palmlength                        0
# poplitealheight                   0
# radialestylionlength              0
# shouldercircumference             0
# shoulderelbowlength               0
# shoulderlength                    0
# sittingheight                     0
# sleevelengthspinewrist            0
# sleeveoutseam                     0
# span                              0
# stature                           0
# suprasternaleheight               0
# tenthribheight                    0
# thighcircumference                0
# thighclearance                    0
# thumbtipreach                     0
# tibialheight                      0
# tragiontopofhead                  0
# trochanterionheight               0
# verticaltrunkcircumferenceusa     0
# waistbacklength                   0
# waistbreadth                      0
# waistcircumference                0
# waistdepth                        0
# waistfrontlengthsitting           0
# waistheightomphalion              0
# weightkg                          0
# wristcircumference                0
# wristheight                       0
# Gender                            0
# SubjectsBirthLocation             0
# SubjectNumericRace                0
# DODRace                           0
# Age                               0
# Heightin                          0
# Weightlbs                         0
# dtype: int64

# %%
df1
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  \
# 0                                266            1467                    337                 222
# 1                                233            1395                    326                 220
# 2                                287            1430                    341                 230
# 3                                234            1347                    310                 230
# 4                                250            1585                    372                 247
# ...                              ...             ...                    ...                 ...
# 5764                             285            1392                    335                 223
# 5765                             262            1324                    301                 202
# 5766                             260            1334                    318                 213
# 5767                             205            1293                    302                 199
# 5768                             238            1346                    308                 210
#
#       axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0             1347                      253               202                401
# 1             1293                      245               193                394
# 2             1327                      256               196                427
# 3             1239                      262               199                401
# 4             1478                      267               224                435
# ...            ...                      ...               ...                ...
# 5764          1297                      252               196                368
# 5765          1204                      236               181                378
# 5766          1259                      234               183                363
# 5767          1207                      213               163                376
# 5768          1256                      236               188                361
#
#       bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                           369               274               493                  71
# 1                           338               257               479                  67
# 2                           408               261               544                  75
# 3                           359               262               518                  73
# 4                           356               263               524                  80
# ...                         ...               ...               ...                 ...
# 5764                        299               312               477                  72
# 5765                        294               287               468                  66
# 5766                        332               299               460                  70
# 5767                        276               280               426                  62
# 5768                        285               279               433                  71
#
#       bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                  319                        291                 142                   979
# 1                  344                        320                 135                   944
# 2                  345                        330                 135                  1054
# 3                  328                        309                 143                   991
# 4                  340                        310                 138                  1029
# ...                ...                        ...                 ...                   ...
# 5764               306                        282                 136                  1089
# 5765               309                        311                 145                  1016
# 5766               317                        311                 139                  1063
# 5767               282                        267                 137                  1051
# 5768               304                        278                 129                   974
#
#       buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0              240            882                619                     509                373
# 1              232            870                584                     468                357
# 2              258            901                623                     506                412
# 3              242            821                560                     437                395
# 4              275           1080                706                     567                425
# ...            ...            ...                ...                     ...                ...
# 5764           255            856                652                     541                373
# 5765           246            818                572                     464                375
# 5766           262            846                637                     525                370
# 5767           225            786                582                     480                370
# 5768           217            820                586                     479                343
#
#       cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0                1535           291                1074         259         1292           877
# 1                1471           269                1021         253         1244           851
# 2                1501           288                1120         267         1288           854
# 3                1423           296                1114         262         1205           769
# 4                1684           304                1048         232         1452          1014
# ...               ...           ...                 ...         ...          ...           ...
# 5764             1457           290                1082         293         1258           779
# 5765             1390           291                1016         269         1151           732
# 5766             1412           285                1093         286         1166           793
# 5767             1377           270                 922         243         1137           763
# 5768             1401           272                 902         219         1186           783
#
#       crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                       607                             351          36         71             19
# 1                       615                             376          33         62             18
# 2                       636                             359          40         61             23
# 3                       590                             341          39         66             25
# 4                       682                             382          32         56             19
# ...                     ...                             ...         ...        ...            ...
# 5764                    732                             382          36         60             19
# 5765                    647                             331          36         65             23
# 5766                    609                             326          39         62             18
# 5767                    575                             310          35         62             21
# 5768                    536                             307          35         58             23
#
#       elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0                 247               802                    101         273
# 1                 232               781                     98         263
# 2                 237               810                    103         270
# 3                 272               794                    106         267
# 4                 188               814                    111         305
# ...               ...               ...                    ...         ...
# 5764              210               746                    103         259
# 5765              274               770                    101         245
# 5766              204               739                     97         249
# 5767              222               738                     91         226
# 5768              243               754                    100         239
#
#       forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                           349                         299                    575
# 1                           348                         289                    523
# 2                           355                         357                    575
# 3                           352                         318                    593
# 4                           399                         324                    605
# ...                         ...                         ...                    ...
# 5764                        328                         262                    514
# 5765                        319                         261                    514
# 5766                        338                         288                    530
# 5767                        306                         258                    430
# 5768                        314                         259                    464
#
#       forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                   477                 1136           90                214         193
# 1                   476                 1096           86                203         195
# 2                   491                 1115           93                220         203
# 3                   467                 1034           91                217         194
# 4                   550                 1279           94                222         218
# ...                 ...                  ...          ...                ...         ...
# 5764                456                 1085           81                197         193
# 5765                440                  985           81                196         183
# 5766                459                 1050           82                192         191
# 5767                425                  995           74                177         176
# 5768                439                 1053           78                187         177
#
#       headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0             150                583         206                     326           70         332
# 1             146                568         201                     334           72         312
# 2             148                573         202                     356           70         349
# 3             158                576         199                     341           68         338
# 4             153                566         197                     374           69         332
# ...           ...                ...         ...                     ...          ...         ...
# 5764          151                582         205                     321           75         381
# 5765          160                570         186                     296           61         347
# 5766          144                559         190                     318           72         364
# 5767          149                558         186                     280           59         369
# 5768          148                561         189                     310           78         332
#
#       hipbreadthsitting  iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                   366                1071                    685         422          441
# 1                   356                1046                    620         441          447
# 2                   393                1053                    665         462          475
# 3                   367                 986                    640         458          461
# 4                   372                1251                    675         481          505
# ...                 ...                 ...                    ...         ...          ...
# 5764                413                1048                    615         373          390
# 5765                377                 974                    650         400          411
# 5766                400                 986                    640         400          412
# 5767                411                 971                    640         383          418
# 5768                376                 994                    595         333          373
#
#       kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                      502                560                             500
# 1                      490                540                             488
# 2                      496                556                             482
# 3                      460                511                             452
# 4                      612                666                             585
# ...                    ...                ...                             ...
# 5764                   462                535                             486
# 5765                   433                483                             457
# 5766                   450                517                             476
# 5767                   432                491                             445
# 5768                   444                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                         77                      391                  118                400
# 1                         73                      371                  131                380
# 2                         72                      409                  123                403
# 3                         76                      393                  106                407
# 4                         85                      458                  135                398
# ...                      ...                      ...                  ...                ...
# 5764                      61                      423                  121                369
# 5765                      58                      383                  130                359
# 5766                      57                      412                  111                352
# 5767                      58                      400                  119                326
# 5768                      66                      372                  114                325
#
#       neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  \
# 0                       436                           1447         113              437
# 1                       420                           1380         118              417
# 2                       434                           1447         121              431
# 3                       446                           1357         118              393
# 4                       430                           1572         132              523
# ...                     ...                            ...         ...              ...
# 5764                    391                           1307         118              414
# 5765                    399                           1323          99              377
# 5766                    402                           1318         116              392
# 5767                    380                           1286         111              375
# 5768                    381                           1372         112              390
#
#       radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      273                   1151                  368             145
# 1                      254                   1119                  353             141
# 2                      268                   1276                  367             167
# 3                      249                   1155                  330             148
# 4                      302                   1231                  400             180
# ...                    ...                    ...                  ...             ...
# 5764                   237                   1036                  354             145
# 5765                   237                   1051                  318             142
# 5766                   259                   1054                  338             136
# 5767                   230                    996                  321             136
# 5768                   249                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  \
# 0               928                     883            600  1782     1776                 1449
# 1               884                     868            564  1745     1702                 1387
# 2               917                     910            604  1867     1735                 1438
# 3               903                     848            550  1708     1655                 1346
# 4               919                     995            641  2035     1914                 1596
# ...             ...                     ...            ...   ...      ...                  ...
# 5764            865                     840            555  1716     1687                 1391
# 5765            881                     794            525  1620     1613                 1316
# 5766            841                     848            566  1740     1644                 1337
# 5767            854                     791            530  1628     1616                 1288
# 5768            861                     821            542  1685     1641                 1334
#
#       tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0               1092                 610             164            786           491
# 1               1076                 572             169            822           476
# 2               1105                 685             198            807           477
# 3               1021                 604             180            803           445
# 4               1292                 672             194            962           584
# ...              ...                 ...             ...            ...           ...
# 5764            1119                 660             155            749           446
# 5765            1043                 616             157            721           422
# 5766            1054                 640             159            758           449
# 5767            1028                 623             163            725           419
# 5768            1089                 592             162            762           436
#
#       tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  \
# 0                  140                  919                           1700              501
# 1                  120                  918                           1627              432
# 2                  125                  918                           1678              472
# 3                  127                  847                           1625              461
# 4                  122                 1090                           1679              467
# ...                ...                  ...                            ...              ...
# 5764               136                  872                           1706              447
# 5765               131                  838                           1648              446
# 5766               127                  862                           1590              444
# 5767               135                  802                           1525              450
# 5768               130                  849                           1547              462
#
#       waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  \
# 0              329                 933         240                      440                  1054
# 1              316                 870         225                      371                  1054
# 2              329                 964         255                      411                  1041
# 3              315                 857         205                      399                   968
# 4              303                 868         214                      379                  1245
# ...            ...                 ...         ...                      ...                   ...
# 5764           334                1043         265                      370                  1002
# 5765           334                 971         243                      374                   958
# 5766           335                 982         254                      351                   970
# 5767           298                 837         208                      335                   952
# 5768           299                 891         223                      394                   943
#
#       weightkg  wristcircumference  wristheight  Gender SubjectsBirthLocation  SubjectNumericRace  \
# 0          815                 175          853    Male          North Dakota                   1
# 1          726                 167          815    Male              New York                   1
# 2          929                 180          831    Male              New York                   2
# 3          794                 176          793    Male             Wisconsin                   1
# 4          946                 188          954    Male        North Carolina                   2
# ...        ...                 ...          ...     ...                   ...                 ...
# 5764       832                 162          836  Female                 Texas                   3
# 5765       717                 157          804  Female                 Texas                   3
# 5766       762                 159          774  Female                 Texas                   2
# 5767       632                 146          769  Female                 Texas                   3
# 5768       610                 154          797  Female                 Texas                   3
#
#        DODRace  Age  Heightin  Weightlbs
# 0        White   41        71        180
# 1        White   35        68        160
# 2        Black   42        68        205
# 3        White   31        66        175
# 4        Black   21        77        213
# ...        ...  ...       ...        ...
# 5764  Hispanic   51        67        180
# 5765  Hispanic   40        63        150
# 5766     Black   40        66        168
# 5767  Hispanic   31        63        133
# 5768  Hispanic   27        66        132
#
# [5769 rows x 100 columns]

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
from sklearn.pipeline import Pipeline
operations = [("scaler", StandardScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
pipe_log_model = Pipeline(steps=operations)

# %%
scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %%
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240   8  12]
#  [  8 106  22]
#  [ 26  87 645]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.92      0.90       260
#     Hispanic       0.53      0.78      0.63       136
#        White       0.95      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.78      0.85      0.81      1154
# weighted avg       0.88      0.86      0.87      1154
#
#
# Train_Set
# [[ 987   29   22]
#  [  16  463   64]
#  [  62  331 2641]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.95      0.94      1038
#     Hispanic       0.56      0.85      0.68       543
#        White       0.97      0.87      0.92      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.82      0.89      0.84      4615
# weighted avg       0.91      0.89      0.89      4615

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    "log__C": [1, 5, 10],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1, cv=5)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [1, 5, 10], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
log_model_grid.best_params_
# Out:
# {'log__C': 1, 'log__penalty': 'l2', 'log__solver': 'lbfgs'}

# %%
log_model_grid.best_score_
# Out:
# 0.7734624532789671

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[242  11   7]
#  [  5 111  20]
#  [ 27  88 643]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.93      0.91       260
#     Hispanic       0.53      0.82      0.64       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.87      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 968   40   30]
#  [  22  454   67]
#  [  60  356 2618]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93      1038
#     Hispanic       0.53      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.88      4615

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
operations_svc = [("scaler", StandardScaler()), ("svc", SVC(class_weight="balanced",random_state=101))]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)

eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[233   9  18]
#  [  4 110  22]
#  [ 15  89 654]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.90      0.91       260
#     Hispanic       0.53      0.81      0.64       136
#        White       0.94      0.86      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.80      0.86      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 980   29   29]
#  [  13  483   47]
#  [  42  294 2698]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.94      0.95      1038
#     Hispanic       0.60      0.89      0.72       543
#        White       0.97      0.89      0.93      3034
#
#     accuracy                           0.90      4615
#    macro avg       0.84      0.91      0.86      4615
# weighted avg       0.92      0.90      0.91      4615

# %%
model = Pipeline(steps=operations_svc)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.598455
# test_precision_Hispanic    0.505808
# test_recall_Hispanic       0.734680
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': [1,2,3],
    'svc__gamma': ["scale", "auto", 1, 0.1, 0.01]
}

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced",random_state=101))]
model = Pipeline(steps=operations_svc)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1)

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# GridSearchCV(estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=101))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [1, 2, 3],
#                          'svc__gamma': ['scale', 'auto', 1, 0.1, 0.01]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
svm_model_grid.best_params_
# Out:
# {'svc__C': 1, 'svc__gamma': 0.1}

# %%
svm_model_grid.best_score_
# Out:
# 0.7623513421678558

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[243   9   8]
#  [  5 110  21]
#  [ 16 101 641]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93       260
#     Hispanic       0.50      0.81      0.62       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 968   37   33]
#  [  20  458   65]
#  [  50  376 2608]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.93      0.93      1038
#     Hispanic       0.53      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.87      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.87      0.88      4615

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X2 = df1.drop("DODRace",axis=1)
y = df1.DODRace

# %%
cat = X2.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation'], dtype='object')

# %%
enc = OrdinalEncoder()
X2[cat] = enc.fit_transform(X2[cat])
X2.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  SubjectsBirthLocation  SubjectNumericRace  Age  Heightin  Weightlbs
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853     1.0                   91.0                   1   41        71        180
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815     1.0                   86.0                   1   35        68        160
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831     1.0                   86.0                   2   42        68        205
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793     1.0                  133.0                   1   31        66        175
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954     1.0                   90.0                   2   21        77        213

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, random_state=101, stratify =y)

# %%
print("Train features shape : ", X_train2.shape)
print("Train target shape   : ", y_train2.shape)
print("Test features shape  : ", X_test2.shape)
print("Test target shape    : ", y_test2.shape)
# Out:
# Train features shape :  (4615, 99)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 99)
# Test target shape    :  (1154,)

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)

# %%
rf_model.fit(X_train2, y_train2)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=101)

# %%
eval_metric(rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[239   6  15]
#  [ 22  82  32]
#  [  9  12 737]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.90       260
#     Hispanic       0.82      0.60      0.69       136
#        White       0.94      0.97      0.96       758
#
#     accuracy                           0.92      1154
#    macro avg       0.88      0.83      0.85      1154
# weighted avg       0.91      0.92      0.91      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.681643
# test_precision_Hispanic    0.846218
# test_recall_Hispanic       0.574209
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'n_estimators':[400,500],
             'max_depth':[10,12,14,16]} #'min_samples_split':[18,20,22], 'max_features': ['auto', None, 15, 20]

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)
rf_grid_model = GridSearchCV(rf_model,
                             param_grid,
                             verbose=3,
                             scoring=recall_Hispanic,
                             n_jobs=-1)

# %%
rf_grid_model.fit(X_train2,y_train2)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=101),
#              n_jobs=-1,
#              param_grid={'max_depth': [10, 12, 14, 16],
#                          'n_estimators': [400, 500]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
rf_grid_model.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 500}

# %%
rf_grid_model.best_score_
# Out:
# 0.762419300033979

# %%
eval_metric(rf_grid_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[246  11   3]
#  [ 20 106  10]
#  [ 12  31 715]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.95      0.91       260
#     Hispanic       0.72      0.78      0.75       136
#        White       0.98      0.94      0.96       758
#
#     accuracy                           0.92      1154
#    macro avg       0.86      0.89      0.87      1154
# weighted avg       0.93      0.92      0.93      1154
#
#
# Train_Set
# [[1037    1    0]
#  [   0  543    0]
#  [   1   42 2991]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       0.93      1.00      0.96       543
#        White       1.00      0.99      0.99      3034
#
#     accuracy                           0.99      4615
#    macro avg       0.98      0.99      0.98      4615
# weighted avg       0.99      0.99      0.99      4615

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101, max_depth=10, n_estimators = 500)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
y_pred = rf_grid_model.predict(X_test2)

rf_AP = viz.score_["Hispanic"]
rf_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
pip install xgboost==0.90
# Out:
# Requirement already satisfied: xgboost==0.90 in c:\users\44778\anaconda3\lib\site-packages (0.90)
# Requirement already satisfied: scipy in c:\users\44778\anaconda3\lib\site-packages (from xgboost==0.90) (1.8.0)
# Requirement already satisfied: numpy in c:\users\44778\appdata\roaming\python\python39\site-packages (from xgboost==0.90) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
xgb.__version__
# Out:
# '1.6.1'

# %%
xgb_model = XGBClassifier(random_state=101)

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train2)
classes_weights
# Out:
# array([2.8330264 , 0.50703142, 0.50703142, ..., 0.50703142, 1.4820167 ,
#        0.50703142])

# %%
comp = pd.DataFrame(classes_weights)

comp["label"] = y_train2.reset_index(drop=True)
comp.groupby("label")[0].value_counts()
# Out:
# label     0
# Black     1.482017    1038
# Hispanic  2.833026     543
# White     0.507031    3034
# Name: 0, dtype: int64

# %%
#xgb_model.fit(X_train2,y_train2, sample_weight=classes_weights)
# weight parameter in XGBoost is per instance not per class. Therefore, we need to assign the weight of each class to its instances, which is the same thing.

# %%
#eval_metric(xgb_model, X_train2, y_train2, X_test2, y_test2)

# %%
#eval_metric(xgb_model, X_train2, y_train2, X_test2, y_test2)

# %%
#model = XGBClassifier(random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          NaN
# test_precision_Hispanic   NaN
# test_recall_Hispanic      NaN
# dtype: float64

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
param_grid = {"n_estimators":[50, 100],
              'max_depth':[1,2],
              "learning_rate": [0.1, 0.3],
              "subsample":[0.8, 1],
              "colsample_bytree":[0.8, 1]}

# %%
xgb_model = XGBClassifier(random_state=101)
xgb_grid_model = GridSearchCV(xgb_model, 
                              param_grid, 
                              scoring=recall_Hispanic, 
                              n_jobs = -1, 
                              verbose = 2).fit(X_train2, y_train2,sample_weight=classes_weights)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# exception calling callback for <Future at 0x27ee5dd61f0 state=finished raised BrokenProcessPool>
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "C:\Users\44778\anaconda3\lib\multiprocessing\queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "C:\Users\44778\anaconda3\lib\site-packages\xgboost\sklearn.py", line 178, in __setstate__
#     bst = state["_Booster"]
# KeyError: '_Booster'
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\externals\loky\_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\parallel.py", line 794, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\externals\loky\reusable_executor.py", line 177, in submit
#     return super(_ReusablePoolExecutor, self).submit(
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 1115, in submit
#     raise self._flags.broken
# joblib.externals.loky.process_executor.BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\44778\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "C:\Users\44778\anaconda3\lib\multiprocessing\queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "C:\Users\44778\anaconda3\lib\site-packages\xgboost\sklearn.py", line 178, in __setstate__
#     bst = state["_Booster"]
# KeyError: '_Booster'
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# Input In [199], in <cell line: 2>()
#       1 xgb_model = XGBClassifier(random_state=101)
# ----> 2 xgb_grid_model = GridSearchCV(xgb_model,
#       3                               param_grid,
#       4                               scoring=recall_Hispanic,
#       5                               n_jobs = -1,
#       6                               verbose = 2).fit(X_train2, y_train2,sample_weight=classes_weights)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py:841, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     835     results = self._format_results(
#     836         all_candidate_params, n_splits, all_out,
#     837         all_more_results)
#     839     return results
# --> 841 self._run_search(evaluate_candidates)
#     843 # multimetric is determined here because in the case of a callable
#     844 # self.scoring the return type is only known after calling
#     845 first_test_score = all_out[0]['test_scores']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py:1296, in GridSearchCV._run_search(self, evaluate_candidates)
#    1294 def _run_search(self, evaluate_candidates):
#    1295     """Search all candidates in param_grid"""
# -> 1296     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py:795, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     790 if self.verbose > 0:
#     791     print("Fitting {0} folds for each of {1} candidates,"
#     792           " totalling {2} fits".format(
#     793               n_splits, n_candidates, n_candidates * n_splits))
# --> 795 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                        X, y,
#     797                                        train=train, test=test,
#     798                                        parameters=parameters,
#     799                                        split_progress=(
#     800                                            split_idx,
#     801                                            n_splits),
#     802                                        candidate_progress=(
#     803                                            cand_idx,
#     804                                            n_candidates),
#     805                                        **fit_and_score_kwargs)
#     806                for (cand_idx, parameters),
#     807                    (split_idx, (train, test)) in product(
#     808                    enumerate(candidate_params),
#     809                    enumerate(cv.split(X, y, groups))))
#     811 if len(out) < 1:
#     812     raise ValueError('No fits were performed. '
#     813                      'Was the CV iterator empty? '
#     814                      'Were there no candidates?')
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~\anaconda3\lib\site-packages\joblib\externals\loky\_base.py:625, in Future._invoke_callbacks(self)
#     623 for callback in self._done_callbacks:
#     624     try:
# --> 625         callback(self)
#     626     except BaseException:
#     627         LOGGER.exception('exception calling callback for %r', self)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:359, in BatchCompletionCallBack.__call__(self, out)
#     357 with self.parallel._lock:
#     358     if self.parallel._original_iterator is not None:
# --> 359         self.parallel.dispatch_next()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:794, in Parallel.dispatch_next(self)
#     786 def dispatch_next(self):
#     787     """Dispatch more data for parallel processing
#     788
#     789     This method is meant to be called concurrently by the multiprocessing
#    (...)
#     792
#     793     """
# --> 794     if not self.dispatch_one_batch(self._original_iterator):
#     795         self._iterating = False
#     796         self._original_iterator = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:531, in LokyBackend.apply_async(self, func, callback)
#     529 def apply_async(self, func, callback=None):
#     530     """Schedule a func to be run"""
# --> 531     future = self._workers.submit(SafeFunction(func))
#     532     future.get = functools.partial(self.wrap_future_result, future)
#     533     if callback is not None:
#
# File ~\anaconda3\lib\site-packages\joblib\externals\loky\reusable_executor.py:177, in _ReusablePoolExecutor.submit(self, fn, *args, **kwargs)
#     175 def submit(self, fn, *args, **kwargs):
#     176     with self._submit_resize_lock:
# --> 177         return super(_ReusablePoolExecutor, self).submit(
#     178             fn, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:1115, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#    1113 with self._flags.shutdown_lock:
#    1114     if self._flags.broken is not None:
# -> 1115         raise self._flags.broken
#    1116     if self._flags.shutdown:
#    1117         raise ShutdownExecutorError(
#    1118             'cannot schedule new futures after shutdown')
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %%
xgb_grid_model.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [200], in <cell line: 1>()
# ----> 1 xgb_grid_model.best_params_
#
# NameError: name 'xgb_grid_model' is not defined

# %%
xgb_grid_model.best_score_

# %%
eval_metric(xgb_grid_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = XGBClassifier(learning_rate=0.3, max_depth=1,
              random_state=101, subsample=0.8)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1",
    sample_weight=classes_weights
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
y_pred = xgb_grid_model.predict(X_test2)

xgb_AP = viz.score_["Hispanic"]
xgb_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
xgb_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.40.0-cp38-cp38-win_amd64.whl (431 kB)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\madcat\anaconda3\lib\site-packages (from shap) (4.59.0)
# Requirement already satisfied: numba in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.53.1)
# Collecting packaging>20.9
#   Downloading packaging-21.2-py3-none-any.whl (40 kB)
# Requirement already satisfied: scikit-learn in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.24.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.2)
# Requirement already satisfied: cloudpickle in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.0)
# Requirement already satisfied: pandas in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.3.4)
# Requirement already satisfied: numpy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.20.1)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\madcat\anaconda3\lib\site-packages (from packaging>20.9->shap) (2.4.7)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\madcat\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (2.1.0)
# Installing collected packages: slicer, packaging, shap
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# Successfully installed packaging-21.2 shap-0.40.0 slicer-0.0.7

# %%
import shap
explainer = shap.Explainer(log_model,X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values

# %%
print(shap_values[0].shape)
# Out:
# (1, 232)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = log_model.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)

# %%
shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
final_model = Pipeline(steps=operations)

# %%
final_model.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
X.describe()
# Out:
#        abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference   chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion   earbreadth    earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal   footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference   handlength  headbreadth  headcircumference   headlength  heelanklecircumference  heelbreadth   hipbreadth  hipbreadthsitting  iliocristaleheight  \
# count                     5769.000000     5769.000000            5769.000000         5769.000000   5769.000000              5769.000000       5769.000000        5769.000000                5769.000000       5769.000000       5769.000000         5769.000000       5769.000000                5769.000000         5769.000000           5769.000000   5769.000000    5769.000000        5769.000000             5769.000000        5769.000000      5769.000000   5769.000000         5769.000000  5769.000000  5769.000000   5769.000000            5769.000000                     5769.000000  5769.000000  5769.000000    5769.000000      5769.000000       5769.000000            5769.000000  5769.000000                5769.000000                 5769.000000            5769.000000        5769.000000          5769.000000  5769.000000        5769.000000  5769.000000  5769.000000        5769.000000  5769.000000             5769.000000  5769.000000  5769.000000        5769.000000         5769.000000
# elbowrestheight                                  240.553302
# eyeheightsitting                                 786.399203
# footbreadthhorizontal                             98.915063
# footlength                                       263.512394
# forearmcenterofgriplength                        339.458832
# forearmcircumferenceflexed                       295.661640
# forearmforearmbreadth                            553.098284
# forearmhandlength                                467.898769
# functionalleglength                             1104.347201
# handbreadth                                       85.098111
# handcircumference                                204.215635
# handlength                                       189.574796
# headbreadth                                      152.043682
# headcircumference                                570.424337
# headlength                                       196.640839
# heelanklecircumference                           333.274918
# heelbreadth                                       70.834113
# hipbreadth                                       348.930837
# hipbreadthsitting                                386.417923
# iliocristaleheight                              1042.152366
# interpupillarybreadth                            632.534928
# interscyei                                       412.773964
# interscyeii                                      433.017334
# kneeheightmidpatella                             476.665280
# kneeheightsitting                                541.376668
# lateralfemoralepicondyleheight                   484.316693
# lateralmalleolusheight                            69.761830
# lowerthighcircumference                          406.943144
# mentonsellionlength                              119.601664
# neckcircumference                                376.127578
# neckcircumferencebase                            414.554516
# overheadfingertipreachsitting                   1390.525048
# palmlength                                       114.106604
# poplitealheight                                  417.227076
# radialestylionlength                             259.757670
# shouldercircumference                           1131.214422
# shoulderelbowlength                              354.805166
# shoulderlength                                   145.202288
# sittingheight                                    898.592477
# sleevelengthspinewrist                           868.361068
# sleeveoutseam                                    578.013001
# span                                            1766.951118
# stature                                         1716.938984
# suprasternaleheight                             1405.392442
# tenthribheight                                  1101.631479
# thighcircumference                               623.583637
# thighclearance                                   176.696481
# thumbtipreach                                    791.044548
# tibialheight                                     459.389149
# tragiontopofhead                                 129.580343
# trochanterionheight                              884.659386
# verticaltrunkcircumferenceusa                   1632.470966
# waistbacklength                                  460.990293
# waistbreadth                                     318.409950
# waistcircumference                               916.817126
# waistdepth                                       230.459178
# waistfrontlengthsitting                          377.352054
# waistheightomphalion                            1033.591090
# weightkg                                         800.981106
# wristcircumference                               169.308372
# wristheight                                      831.334547
# SubjectNumericRace                                16.894436
# Age                                               29.776391
# Heightin                                          68.359508
# Weightlbs                                        175.578263
# Gender_Male                                        0.675854
# SubjectsBirthLocation_Alaska                       0.001213
# SubjectsBirthLocation_Antigua and Barbuda          0.000347
# SubjectsBirthLocation_Argentina                    0.000173
# SubjectsBirthLocation_Arizona                      0.013001
# SubjectsBirthLocation_Arkansas                     0.009187
# SubjectsBirthLocation_Azerbaijan                   0.000173
# SubjectsBirthLocation_Bahamas                      0.000173
# SubjectsBirthLocation_Barbados                     0.000867
# SubjectsBirthLocation_Belarus                      0.000173
# SubjectsBirthLocation_Belgium                      0.000520
# SubjectsBirthLocation_Belize                       0.000347
# SubjectsBirthLocation_Bermuda                      0.000173
# SubjectsBirthLocation_Bolivia                      0.000347
# SubjectsBirthLocation_Bosnia and Herzegovina       0.000173
# SubjectsBirthLocation_Brazil                       0.000173
# SubjectsBirthLocation_British Virgin Islands       0.000173
# SubjectsBirthLocation_Bulgaria                     0.000173
# SubjectsBirthLocation_California                   0.072283
# SubjectsBirthLocation_Cameroon                     0.000347
# SubjectsBirthLocation_Canada                       0.001387
# SubjectsBirthLocation_Cape Verde                   0.000173
# SubjectsBirthLocation_Chile                        0.000173
# SubjectsBirthLocation_Colombia                     0.002253
# SubjectsBirthLocation_Colorado                     0.013521
# SubjectsBirthLocation_Connecticut                  0.006240
# SubjectsBirthLocation_Costa Rica                   0.000347
# SubjectsBirthLocation_Cuba                         0.000693
# SubjectsBirthLocation_Delaware                     0.002947
# SubjectsBirthLocation_Denmark                      0.000173
# SubjectsBirthLocation_District of Columbia         0.003293
# SubjectsBirthLocation_Dominica                     0.000173
# SubjectsBirthLocation_Dominican Republic           0.002947
# SubjectsBirthLocation_Ecuador                      0.000867
# SubjectsBirthLocation_Egypt                        0.000173
# SubjectsBirthLocation_El Salvador                  0.000867
# SubjectsBirthLocation_Ethiopia                     0.000173
# SubjectsBirthLocation_Florida                      0.036401
# SubjectsBirthLocation_France                       0.000520
# SubjectsBirthLocation_French Guiana                0.000173
# SubjectsBirthLocation_Georgia                      0.029121
# SubjectsBirthLocation_Germany                      0.015601
# SubjectsBirthLocation_Ghana                        0.000347
# SubjectsBirthLocation_Grenada                      0.000693
# SubjectsBirthLocation_Guadalupe                    0.000173
# SubjectsBirthLocation_Guam                         0.000520
# SubjectsBirthLocation_Guatemala                    0.000173
# SubjectsBirthLocation_Guyana                       0.001387
# SubjectsBirthLocation_Haiti                        0.002080
# SubjectsBirthLocation_Hawaii                       0.003120
# SubjectsBirthLocation_Honduras                     0.000693
# SubjectsBirthLocation_Iceland                      0.000173
# SubjectsBirthLocation_Idaho                        0.003467
# SubjectsBirthLocation_Illinois                     0.036401
# SubjectsBirthLocation_India                        0.000173
# SubjectsBirthLocation_Indiana                      0.045762
# SubjectsBirthLocation_Iowa                         0.009534
# SubjectsBirthLocation_Iran                         0.000173
# SubjectsBirthLocation_Iraq                         0.000347
# SubjectsBirthLocation_Israel                       0.000520
# SubjectsBirthLocation_Italy                        0.000347
# SubjectsBirthLocation_Ivory Coast                  0.000173
# SubjectsBirthLocation_Jamaica                      0.006067
# SubjectsBirthLocation_Japan                        0.001213
# SubjectsBirthLocation_Kansas                       0.010747
# SubjectsBirthLocation_Kentucky                     0.011614
# SubjectsBirthLocation_Kenya                        0.000520
# SubjectsBirthLocation_Lebanon                      0.000347
# SubjectsBirthLocation_Liberia                      0.001040
# SubjectsBirthLocation_Louisiana                    0.023574
# SubjectsBirthLocation_Maine                        0.003120
# SubjectsBirthLocation_Maryland                     0.013521
# SubjectsBirthLocation_Massachusetts                0.018894
# SubjectsBirthLocation_Mexico                       0.006760
# SubjectsBirthLocation_Michigan                     0.033628
# SubjectsBirthLocation_Minnesota                    0.033628
# SubjectsBirthLocation_Mississippi                  0.033455
# SubjectsBirthLocation_Missouri                     0.014387
# SubjectsBirthLocation_Montana                      0.002080
# SubjectsBirthLocation_Morocco                      0.000520
# SubjectsBirthLocation_Nebraska                     0.005200
# SubjectsBirthLocation_Netherlands                  0.000347
# SubjectsBirthLocation_Nevada                       0.003640
# SubjectsBirthLocation_New Hampshire                0.002427
# SubjectsBirthLocation_New Jersey                   0.015254
# SubjectsBirthLocation_New Mexico                   0.002773
# SubjectsBirthLocation_New York                     0.071243
# SubjectsBirthLocation_New Zealand                  0.000173
# SubjectsBirthLocation_Nicaragua                    0.000693
# SubjectsBirthLocation_Nigeria                      0.000693
# SubjectsBirthLocation_North Carolina               0.025134
# SubjectsBirthLocation_North Dakota                 0.003120
# SubjectsBirthLocation_Ohio                         0.024094
# SubjectsBirthLocation_Oklahoma                     0.035535
# SubjectsBirthLocation_Oregon                       0.006934
# SubjectsBirthLocation_Panama                       0.001733
# SubjectsBirthLocation_Paraguay                     0.000173
# SubjectsBirthLocation_Pennsylvania                 0.022534
# SubjectsBirthLocation_Peru                         0.001387
# SubjectsBirthLocation_Philippines                  0.000867
# SubjectsBirthLocation_Poland                       0.000867
# SubjectsBirthLocation_Portugal                     0.000693
# SubjectsBirthLocation_Puerto Rico                  0.015254
# SubjectsBirthLocation_Rhode Island                 0.003120
# SubjectsBirthLocation_Romania                      0.000520
# SubjectsBirthLocation_Russia                       0.001387
# SubjectsBirthLocation_Saint Lucia                  0.000173
# SubjectsBirthLocation_Senegal                      0.000173
# SubjectsBirthLocation_Serbia                       0.000173
# SubjectsBirthLocation_Sierra Leone                 0.000347
# SubjectsBirthLocation_South Africa                 0.000693
# SubjectsBirthLocation_South America                0.000173
# SubjectsBirthLocation_South Carolina               0.027908
# SubjectsBirthLocation_South Dakota                 0.009187
# SubjectsBirthLocation_South Korea                  0.000173
# SubjectsBirthLocation_Sri Lanka                    0.000173
# SubjectsBirthLocation_Sudan                        0.000347
# SubjectsBirthLocation_Syria                        0.000173
# SubjectsBirthLocation_Tennessee                    0.012827
# SubjectsBirthLocation_Texas                        0.066909
# SubjectsBirthLocation_Togo                         0.000173
# SubjectsBirthLocation_Trinidad and Tobago          0.001213
# SubjectsBirthLocation_Turkey                       0.000347
# SubjectsBirthLocation_US Virgin Islands            0.001213
# SubjectsBirthLocation_Ukraine                      0.001213
# SubjectsBirthLocation_United Kingdom               0.001907
# SubjectsBirthLocation_United States                0.000347
# SubjectsBirthLocation_Utah                         0.004680
# SubjectsBirthLocation_Venezuela                    0.000173
# SubjectsBirthLocation_Vermont                      0.002253
# SubjectsBirthLocation_Virginia                     0.019587
# SubjectsBirthLocation_Washington                   0.010574
# SubjectsBirthLocation_West Virginia                0.004507
# SubjectsBirthLocation_Wisconsin                    0.017161
# SubjectsBirthLocation_Wyoming                      0.001213
# SubjectsBirthLocation_Zambia                       0.000173
# Name: mean, dtype: float64

# %%
final_model.predict([mean_human])
# Out:
# array(['White'], dtype=object)

# %%
y[201]
# Out:
# 'Hispanic'

# %%
final_model.predict(X.loc[[201]])
# Out:
# array(['Hispanic'], dtype=object)

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7874908217272297

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7784998204866194

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
