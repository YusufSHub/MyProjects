# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"RFM Customer Segmentation & Cohort Analysis Project"**. This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply **RFM Analysis** and Customer Segmentation using **K-Means Clustering**. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct **Cohort Analysis**.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
# !pip install pyforest
# !pip install ipython
# !pip install pyclustertend
# !pip install xlrd
# !pip install Autoviz
# !pip3 install termcolor
# !pip install termcolor
# !pip install pandas-profiling
# !pip install lightgbm
# !pip3 install catboost
# !pip install colorama
# !pip install plotly
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install pyyaml==5.4.1
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install pyforest
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import scipy.stats as stats
import pyforest
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, StandardScaler, PowerTransformer, MinMaxScaler, LabelEncoder, RobustScaler
from sklearn.model_selection import RepeatedStratifiedKFold, KFold, cross_val_predict, train_test_split, GridSearchCV, cross_val_score, cross_validate
from sklearn.linear_model import LinearRegression, Lasso, Ridge,ElasticNet
from sklearn.metrics import plot_confusion_matrix, r2_score, mean_absolute_error, mean_squared_error, classification_report, confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import make_scorer, precision_score, precision_recall_curve, plot_precision_recall_curve, plot_roc_curve, roc_auc_score, roc_curve, f1_score, accuracy_score, recall_score
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostClassifier
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif, f_regression, mutual_info_regression
from xgboost import XGBRegressor, XGBClassifier
from xgboost import plot_importance
from sklearn.pipeline import Pipeline
from sklearn.tree import plot_tree
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

#importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)

# pd.set_option('display.max_rows', 100) # if you wish to see more rows rather than default, just uncomment this line.
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

import colorama
from colorama import Fore, Style  # maakes strings colored
# !pip3 install termcolor
from termcolor import colored
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# ...

# %%
###############################################################################
# Function for determining the number and percentages of missing values


def missing(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

def missing_values(df):
    return missing(df)[missing(df)['Missing_Number']>0]

###############################################################################
# To view summary information about the column

def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          f"There is ", df.shape[0], " observation and ", df.shape[1], " columns in the dataset.", '\n',
          colored('-'*79, 'magenta', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n', 
          colored('-'*79, 'magenta', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('-'*79, 'magenta', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n', 
          colored('-'*79, 'magenta', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n', 
          colored('-'*79, 'magenta', attrs=['bold']), sep='')

    df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

    print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')

def duplicate_values(df):
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored(" duplicates were dropped", attrs=['bold']),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')
    else:
        print(colored("No duplicates", attrs=['bold']),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')
        
def drop_columns(df, drop_columns):
    if drop_columns !=[]:
        df.drop(drop_columns, axis=1, inplace=True)
        print(drop_columns, 'were dropped')
    else:
        print(colored('We will now check the missing values and if necessary drop some columns!!!', attrs=['bold']),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')
        
def drop_null(df, limit):
    print('Shape:', df.shape)
    for i in df.isnull().sum().index:
        if (df.isnull().sum()[i]/df.shape[0]*100)>limit:
            print(df.isnull().sum()[i], 'percent of', i ,'null and were dropped')
            df.drop(i, axis=1, inplace=True)
            print('new shape:', df.shape)
        else:
            print(df.isnull().sum()[i], '%, percentage of missing values of', i ,'less than limit', limit, '%, so we will keep it.')
    print('New shape after missing value control:', df.shape)

###############################################################################

# %% [markdown]
# lazim olan libray cek al burdan.

# %%
df0 = pd.read_excel("Online Retail.xlsx")
df = df0.copy()
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom

# %%
first_looking(df)
# Out:
# Shape:(541909, 8)
# There is 541909 observation and 8 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# ...

# %% [markdown]
# - Missing valeues sadece custemer Id de var.
# - colum name lerini degistirdik.
# - Custimer id not neccesary for this model so we wont care about missing values.
# - Dropping columns are Invoice no, customer id,

# %%
column = ['invoiceno','stockcode']
for i in column:
    df[i]=df[i].astype('str')

# %%
df.customerid.isnull().sum()
# Out:
# 135080

# %%
pip install -U pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\44778\anaconda3\lib\site-packages (from pandas-profiling) (0.7.4)
#
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\44778\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# ...

# %%
# df.profile_report()

# %% [markdown]
# quantity de 10000+ negatif deger var
# uc degerler var outlier degerler datanin az kismini olurturyor simdilik drop edebilir analizimize gore karar vericez.

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1  536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           invoicedate  unitprice  customerid         country
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom

# %%
df.tail(15)
# Out:
#        invoiceno stockcode                      description  quantity  \
# 541894  581587.0   22631.0         CIRCUS PARADE LUNCH BOX     12.000
# 541895  581587.0   22556.0   PLASTERS IN TIN CIRCUS PARADE     12.000
# 541896  581587.0   22555.0        PLASTERS IN TIN STRONGMAN    12.000
# 541897  581587.0   22728.0        ALARM CLOCK BAKELIKE PINK     4.000
# 541898  581587.0   22727.0        ALARM CLOCK BAKELIKE RED      4.000
# 541899  581587.0   22726.0       ALARM CLOCK BAKELIKE GREEN     4.000
# 541900  581587.0   22730.0       ALARM CLOCK BAKELIKE IVORY     4.000
# 541901  581587.0   22367.0  CHILDRENS APRON SPACEBOY DESIGN     8.000
# 541902  581587.0   22629.0              SPACEBOY LUNCH BOX     12.000
# 541903  581587.0   23256.0      CHILDRENS CUTLERY SPACEBOY      4.000
# 541904  581587.0   22613.0      PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905  581587.0   22899.0     CHILDREN'S APRON DOLLY GIRL      6.000
# ...

# %% [markdown]
# burda date i index columuna alalim diye dusunduk cunku siralama ona gore yapilmis.

# %%
df.sample(9)
# Out:
#        invoiceno stockcode                         description  quantity  \
# 442629  574677.0    84030E       ENGLISH ROSE HOT WATER BOTTLE     1.000
# 19336   537852.0   21918.0    SET 12 KIDS COLOUR  CHALK STICKS     8.000
# 438329  574312.0   22385.0           JUMBO BAG SPACEBOY DESIGN     2.000
# 424192  573245.0   22578.0  WOODEN STAR CHRISTMAS SCANDINAVIAN    10.000
# 239080  557973.0   22699.0    ROSES REGENCY TEACUP AND SAUCER      6.000
# 107187  545416.0    84968D       SET OF 16 VINTAGE RED CUTLERY     8.000
# 290934  562420.0   22494.0            EMERGENCY FIRST AID TIN      1.000
# 13632   537434.0   22602.0      CHRISTMAS RETROSPOT HEART WOOD     1.000
# 246042  558663.0   23574.0                                 NaN   100.000
#
#                invoicedate  unitprice  customerid         country
# 442629 2011-11-06 12:32:00      4.250   16445.000  United Kingdom
# 19336  2010-12-08 15:56:00      0.420   17340.000  United Kingdom
# ...

# %%
# df.describe(include="all").T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')

# %%
'''df.hist(figsize=(15, 12), bins=15, xrot=90);
plt.tight_layout()'''
# Out:
# 'df.hist(figsize=(15, 12), bins=15, xrot=90);\nplt.tight_layout()'

# %%
df.describe(include=object).T
# Out:
#               count unique                                 top    freq
# invoiceno    541909  25900                            573585.0    1114
# stockcode    541909   4070                              85123A    2313
# description  540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# country      541909     38                      United Kingdom  495478

# %%
df.groupby("stockcode")["quantity"].sum().sort_values(ascending=False)
# Out:
# stockcode
# 22197.0    56450.000
# 84077.0    53847.000
# 85099B     47363.000
# 85123A     38830.000
# 84879.0    36221.000
#              ...
# 79323LP    -2618.000
# 79323W     -4838.000
# 72140F     -5368.000
# 23003.0    -8516.000
# 23005.0   -14418.000
# Name: quantity, Length: 4070, dtype: float64

# %%
df["stockcode"].loc[22197.0]
# Out:
# '22187.0'

# %%
df.loc[df["stockcode"] == "22197.0"]
# Out:
#        invoiceno stockcode           description  quantity  \
# 221     536390.0   22197.0  SMALL POPCORN HOLDER   100.000
# 393     536404.0   22197.0  SMALL POPCORN HOLDER    36.000
# 532     536409.0   22197.0  SMALL POPCORN HOLDER     2.000
# 610     536412.0   22197.0  SMALL POPCORN HOLDER     5.000
# 804     536464.0   22197.0  SMALL POPCORN HOLDER     5.000
# ...          ...       ...                   ...       ...
# 540321  581476.0   22197.0        POPCORN HOLDER   100.000
# 540785  581492.0   22197.0        POPCORN HOLDER    34.000
# 541285  581497.0   22197.0        POPCORN HOLDER    68.000
# 541678  581538.0   22197.0        POPCORN HOLDER     4.000
# 541825  581579.0   22197.0        POPCORN HOLDER    24.000
#
#                invoicedate  unitprice  customerid         country
# 221    2010-12-01 10:19:00      0.720   17511.000  United Kingdom
# 393    2010-12-01 11:29:00      0.850   16218.000  United Kingdom
# ...

# %%
df.nunique()
# Out:
# invoiceno      25900
# stockcode       4070
# description     4223
# quantity         722
# invoicedate    23260
# unitprice       1630
# customerid      4372
# country           38
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    536641
# True       5268
# dtype: int64

# %%
duplicate_values(df)
# Out:
# No duplicates
# -------------------------------------------------------------------------------

# %%
df.duplicated().value_counts()
# Out:
# False    536641
# dtype: int64

# %%
missing(df)
# Out:
#              Missing_Number  Missing_Percent
# customerid           135037            0.252
# description            1454            0.003
# invoiceno                 0            0.000
# stockcode                 0            0.000
# quantity                  0            0.000
# invoicedate               0            0.000
# unitprice                 0            0.000
# country                   0            0.000

# %%
df.isnull().melt(value_name="missing")
# Out:
#           variable  missing
# 0        invoiceno    False
# 1        invoiceno    False
# 2        invoiceno    False
# 3        invoiceno    False
# 4        invoiceno    False
# ...            ...      ...
# 4293123    country    False
# 4293124    country    False
# 4293125    country    False
# 4293126    country    False
# 4293127    country    False
#
# [4293128 rows x 2 columns]

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df.columns
# Out:
# Index(['invoiceno', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'unitprice', 'customerid', 'country'],
#       dtype='object')

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[['invoiceno','quantity','unitprice']].describe().T
# Out:
#                count  mean     std        min   25%   50%    75%       max
# quantity  536641.000 9.620 219.130 -80995.000 1.000 3.000 10.000 80995.000
# unitprice 536641.000 4.633  97.233 -11062.060 1.250 2.080  4.130 38970.000

# %%
df[['invoiceno','quantity','unitprice']].value_counts()
# Out:
# invoiceno  quantity  unitprice
# 573585.0   1.000     2.460        71
# 580367.0   1.000     2.460        59
# 580730.0   1.000     2.460        57
# 580729.0   1.000     4.130        55
# 579512.0   1.000     2.460        54
#                                   ..
# 556071.0   6.000     2.100         1
#                      2.950         1
#                      3.750         1
#            8.000     1.690         1
# C581569    -1.000    1.250         1
# Length: 304588, dtype: int64

# %%
sns.heatmap(df[['invoiceno','quantity','unitprice']].corr(), annot=True);

# %%
k = df[['quantity','unitprice']] < 0
k.sum()
# Out:
# quantity     10587
# unitprice        2
# dtype: int64

# %% [markdown]
# 10624 siparis negatif adetmis.

# %%
# 0dan kucuk olanlari cekecek kod

# %%
# 2 tanelik urun icn aratirma yapilacak , quantatity negatif olabilir mi

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
(df['invoiceno'] == "C*").sum()
# Out:
# 0

# %%
df[df['invoiceno'].str.count('^C*')>0]
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL      6.000
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                invoicedate  unitprice  customerid         country
# ...

# %%
df['invoiceno'].str[0].value_counts()
# Out:
# 5    527387
# C      9251
# A         3
# Name: invoiceno, dtype: int64

# %%
df[df['invoiceno'].str[0]=="A"]
# Out:
#        invoiceno stockcode      description  quantity         invoicedate  \
# 299982   A563185         B  Adjust bad debt     1.000 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         unitprice  customerid         country
# 299982  11062.060         NaN  United Kingdom
# 299983 -11062.060         NaN  United Kingdom
# 299984 -11062.060         NaN  United Kingdom

# %%
df[df['invoiceno'].str.count('^K*')>0]
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL      6.000
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                invoicedate  unitprice  customerid         country
# ...

# %% [markdown]
# 9291 tane invoice kodlu urun c li imis yani iadeli urun imis dikkat edilirse yukarda 10000+ negatif vardi bak bakalim bir baglanti var mi
# yani 1333 urun iade edilmemesine ragmen negetif adet urun iptal edilmis edilmemis bilinmiyor netlik yok ???
# bozuk urun mu?

# %% [markdown]
# #### 3836 or about 15% of the orders were cancelled. Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
# regex ile yapmak isterseniz aşağıdaki kodu da kullanabilirsiniz
# df[df['invoiceno']].str.match("(C\d+)")==True]

# %%
df[df['invoiceno'].str.match('^C*')== True]
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL      6.000
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                invoicedate  unitprice  customerid         country
# ...

# %%
df[df['invoiceno'].str.match('A*')== True]
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL      6.000
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                invoicedate  unitprice  customerid         country
# ...

# %%
df[df['invoiceno'].astype('str').str[0]=='A']
# Out:
#        invoiceno stockcode      description  quantity         invoicedate  \
# 299982   A563185         B  Adjust bad debt     1.000 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         unitprice  customerid         country
# 299982  11062.060         NaN  United Kingdom
# 299983 -11062.060         NaN  United Kingdom
# 299984 -11062.060         NaN  United Kingdom

# %%
df[df['invoiceno'].astype('str').str[0]=='C']
# Out:
#        invoiceno stockcode                       description  quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 541541   C581499         M                            Manual    -1.000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE    -5.000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                invoicedate  unitprice  customerid         country
# ...

# %%
df[df['unitprice'] < 0]
# Out:
#        invoiceno stockcode      description  quantity         invoicedate  \
# 299983   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         unitprice  customerid         country
# 299983 -11062.060         NaN  United Kingdom
# 299984 -11062.060         NaN  United Kingdom

# %% [markdown]
# ### iii. Handling Missing Values

# %%
df.customerid.isnull().sum()
# Out:
# 135037

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
# behgendikmmmm df["Inspection_new"] = [item[0] if type(item) == list else item for item in df["Inspection new"]]

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df.customerid.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (536641, 8)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby("customerid")["invoiceno"].nunique().sort_values()
# Out:
# customerid
# 15300.000      1
# 13833.000      1
# 16123.000      1
# 13829.000      1
# 13828.000      1
#             ...
# 13089.000    118
# 14606.000    128
# 17841.000    169
# 12748.000    224
# 14911.000    248
# Name: invoiceno, Length: 4372, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.groupby(["customerid","stockcode"])["quantity"].nunique().mean()
# Out:
# 1.2214748799581487

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby(["customerid"])["quantity"].nunique().mean()
# Out:
# 10.771729185727356

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df.columns
# Out:
# Index(['invoiceno', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'unitprice', 'customerid', 'country'],
#       dtype='object')

# %%
df["totalprice"] = (df["unitprice"] * df["quantity"])

# %%
df.groupby("country")["totalprice"].sum().sort_values(ascending=False)
# Out:
# country
# United Kingdom         8167128.184
# Netherlands             284661.540
# EIRE                    262993.380
# Germany                 221509.470
# France                  197317.110
# Australia               137009.770
# Switzerland              56363.050
# Spain                    54756.030
# Belgium                  40910.960
# Sweden                   36585.410
# Japan                    35340.620
# Norway                   35163.460
# Portugal                 29302.970
# Finland                  22326.740
# Channel Islands          20076.390
# Denmark                  18768.140
# Italy                    16890.510
# Cyprus                   12858.760
# Austria                  10154.320
# Hong Kong                 9908.240
# Singapore                 9120.390
# Israel                    7901.970
# Poland                    7213.140
# Unspecified               4740.940
# Greece                    4710.520
# Iceland                   4310.000
# ...

# %% [markdown]
# 2. Visualize number of customer per country

# %%
tp = df.groupby("country")["customerid"].nunique().sort_values(ascending=False)

plt.bar(tp.index, tp.values)
plt.xticks(rotation=90);

# %%
# sns.barplot(df.groupby("country")["customerid"].count())

# %% [markdown]
# 3. Visualize total cost per country

# %%
sns.barplot(df.groupby("country")["totalprice"].sum())
# Out:
# <AxesSubplot:xlabel='totalprice'>

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df.groupby("country").unitprice.describe()
# Out:
#                           count    mean     std        min   25%   50%   75%  \
# country
# Australia              1258.000   3.218  12.460      0.000 1.250 1.790 3.750
# Austria                 401.000   4.243   7.355      0.120 1.250 1.950 4.150
# Bahrain                  19.000   4.556   3.474      1.250 2.300 3.810 4.600
# Belgium                2069.000   3.644   4.245      0.120 1.250 1.950 4.150
# Brazil                   32.000   4.456   2.832      0.850 2.047 3.320 6.750
# Canada                  151.000   6.030  44.714      0.100 0.830 1.650 2.950
# Channel Islands         757.000   4.936  15.557      0.190 1.450 2.550 6.250
# Cyprus                  611.000   6.350  22.617      0.120 1.250 2.950 4.950
# Czech Republic           30.000   2.938   7.099      0.290 0.835 1.450 2.400
# Denmark                 389.000   3.257   3.960      0.210 1.250 1.950 3.750
# EIRE                   8184.000   5.914  54.074      0.000 1.250 2.100 4.250
# ...

# %%
df_uk = df[df["country"] == 'United Kingdom']
df_uk.sample(10)
# Out:
#        invoiceno stockcode                          description  quantity  \
# 160515  550459.0   22771.0  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN     2.000
# 471605  576644.0   22646.0   CERAMIC STRAWBERRY CAKE MONEY BANK     4.000
# 33580   539264.0   21231.0       SWEETHEART CERAMIC TRINKET BOX    12.000
# 464646  576148.0   22579.0   WOODEN TREE CHRISTMAS SCANDINAVIAN    24.000
# 2250    536569.0         M                               Manual     1.000
# 398483  571243.0   22554.0     PLASTERS IN TIN WOODLAND ANIMALS    12.000
# 145485  548894.0   21107.0       CREAM SLICE FLANNEL PINK SPOT      1.000
# 134659  547860.0   22286.0  DECORATION , WOBBLY RABBIT , METAL      8.000
# 452275  575331.0   22661.0      CHARLOTTE BAG DOLLY GIRL DESIGN    10.000
# 249418  558904.0   22559.0                  SEASIDE FLYING DISC    10.000
#
#                invoicedate  unitprice  customerid         country  totalprice
# ...

# %%
df[df["country"] == "United Kingdom"]["totalprice"].value_counts(dropna=False)
# Out:
# 15.000     16999
# 2.460       9275
# 1.250       8930
# 4.130       8811
# 17.700      7522
#            ...
# 331.200        1
# 77.000         1
# -3.710         1
# 176.800        1
# 66.360         1
# Name: totalprice, Length: 5954, dtype: int64

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df[df["totalprice"] < 0]
# Out:
#        invoiceno stockcode                       description  quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 541541   C581499         M                            Manual    -1.000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE    -5.000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                invoicedate  unitprice  customerid         country  totalprice
# ...

# %%
df_uk.shape
# Out:
# (490300, 9)

# %%
df_uk.columns
# Out:
# Index(['invoiceno', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'unitprice', 'customerid', 'country', 'totalprice'],
#       dtype='object')

# %%
df_uk["description"].astype('str').value_counts(dropna=False).head(1)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2260
# Name: description, dtype: int64

# %%
df_uk.description.value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2260
# JUMBO BAG RED RETROSPOT                1998
# REGENCY CAKESTAND 3 TIER               1849
# PARTY BUNTING                          1627
# LUNCH BAG RED RETROSPOT                1448
#                                        ...
# MIA                                       1
# PINK CRYSTAL GUITAR PHONE CHARM           1
# showroom                                  1
# TRAVEL CARD WALLET DOTCOMGIFTSHOP         1
# ORANGE PENDANT TRIPLE SHELL NECKLAC       1
# Name: description, Length: 4202, dtype: int64

# %%
y= df_uk.describe(include="O").T
y["top"].loc["description"]
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
df_uk.groupby("stockcode")["customerid"].nunique().sort_values(ascending= False)
# Out:
# stockcode
# 85123A     823
# 22423.0    773
# 47566.0    659
# 84879.0    643
# 22086.0    596
#           ...
# 20825.0      0
# 84968e       0
# 84968f       0
# 90059D       0
# m            0
# Name: customerid, Length: 4065, dtype: int64

# %%
df_uk[df_uk["stockcode"] == "85123A" ]
# Out:
#        invoiceno stockcode                         description  quantity  \
# 0       536365.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 49      536373.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 66      536375.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 220     536390.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER    64.000
# 262     536394.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER    32.000
# ...          ...       ...                                 ...       ...
# 539342  581439.0    85123A  CREAM HANGING HEART T-LIGHT HOLDER     1.000
# 539979  581452.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER    32.000
# 540217  581472.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 540837  581492.0    85123A  CREAM HANGING HEART T-LIGHT HOLDER     3.000
# 541639  581538.0    85123A  CREAM HANGING HEART T-LIGHT HOLDER     1.000
#
#                invoicedate  unitprice  customerid         country  totalprice
# ...

# %%
df_uk.describe(include="O").T["top"]
# Out:
# invoiceno                                573585.0
# stockcode                                  85123A
# description    WHITE HANGING HEART T-LIGHT HOLDER
# country                            United Kingdom
# Name: top, dtype: object

# %%
df_uk["description"].value_counts(dropna=False)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2260
# JUMBO BAG RED RETROSPOT               1998
# REGENCY CAKESTAND 3 TIER              1849
# PARTY BUNTING                         1627
# NaN                                   1454
#                                       ...
# re dotcom quick fix.                     1
# Dotcom sold in 6's                       1
# sold in set?                             1
# cracked                                  1
# FUNKY MONKEY MUG                         1
# Name: description, Length: 4203, dtype: int64

# %%
y= df_uk.describe(include="O").T
y["top"].loc["description"]
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %% [markdown]
# ![](https://18.cdn.ekm.net/ekmps/shops/mochaberry/images/cream-hanging-heart-t-light-holder-[2]-356-p.jpg?v=203c7948-6978-44e0-b8a2-5c5ac9211c0a "WHITE HANGING HEART T-LIGHT HOLDER")

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.describe()
# Out:
#         quantity  unitprice  customerid  totalprice
# count 490300.000 490300.000  356728.000  490300.000
# mean       8.669      4.555   15543.795      16.657
# std      228.768     99.838    1594.286     396.909
# min   -80995.000 -11062.060   12346.000 -168469.600
# 25%        1.000      1.250   14191.000       3.300
# 50%        3.000      2.100   15513.000       8.300
# 75%       10.000      4.130   16931.000      16.630
# max    80995.000  38970.000   18287.000  168469.600

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 490300 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    490300 non-null  object
#  1   stockcode    490300 non-null  object
#  2   description  488846 non-null  object
#  3   quantity     490300 non-null  float64
#  4   invoicedate  490300 non-null  datetime64[ns]
#  5   unitprice    490300 non-null  float64
#  6   customerid   356728 non-null  float64
#  7   country      490300 non-null  object
#  8   totalprice   490300 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 37.4+ MB

# %%
df_uk.isnull().sum()
# Out:
# invoiceno           0
# stockcode           0
# description      1454
# quantity            0
# invoicedate         0
# unitprice           0
# customerid     133572
# country             0
# totalprice          0
# dtype: int64

# %% [markdown]
# Customerid null ve description değerleri sil

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %%
df_uk.columns
# Out:
# Index(['invoiceno', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'unitprice', 'customerid', 'country', 'totalprice'],
#       dtype='object')

# %%
df_uk.invoicedate.min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
df_uk.invoicedate.max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
df_uk["totalprice"] = df["quantity"] * df["unitprice"]

# %%
NOW = dt.datetime(2011,12,9)

# %%
#Convert ORDERDATE to datetime format.
df_uk['invoicedate'] = pd.to_datetime(df_uk['invoicedate'])

# %%
df_uk.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1  536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           invoicedate  unitprice  customerid         country  totalprice
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom      15.300
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom      20.340
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom      22.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom      20.340
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom      20.340

# %%
# RFM Table
RFM_table = df_uk.groupby('customerid').agg({'invoicedate': lambda x: (NOW - x.max()).days, # Recency
                                                'invoiceno': lambda x: len(x.unique()), # Frequency
                                                'totalprice': lambda x: x.sum()})    # Monetary 

RFM_table['invoicedate'] = RFM_table['invoicedate'].astype(int)

RFM_table.rename(columns={'invoicedate': 'recency', 
                         'invoiceno': 'frequency',
                         'totalprice': 'monetary_value'}, inplace=True)
RFM_table.head()
# Out:
#             recency  frequency  monetary_value
# customerid
# 12346.000       324          2           0.000
# 12747.000         1         11        4196.010
# 12748.000        -1        224       28405.560
# 12749.000         2          8        3868.200
# 12820.000         2          4         942.340

# %%
RFM_table.reset_index()
# Out:
#       customerid  recency  frequency  monetary_value
# 0      12346.000      324          2           0.000
# 1      12747.000        1         11        4196.010
# 2      12748.000       -1        224       28405.560
# 3      12749.000        2          8        3868.200
# 4      12820.000        2          4         942.340
# ...          ...      ...        ...             ...
# 3945   18280.000      276          1         180.600
# 3946   18281.000      179          1          80.820
# 3947   18282.000        6          3         176.600
# 3948   18283.000        2         16        2045.530
# 3949   18287.000       41          3        1837.280
#
# [3950 rows x 4 columns]

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
now = dt.datetime(2011,12,9)

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uk['date'] = pd.DatetimeIndex(df_uk['invoicedate']).date

# %%
df_uk.last_purchase = df_uk.groupby("customerid")["date"].max()
df_uk.last_purchase
# Out:
# customerid
# 12346.000    2011-01-18
# 12747.000    2011-12-07
# 12748.000    2011-12-09
# 12749.000    2011-12-06
# 12820.000    2011-12-06
#                 ...
# 18280.000    2011-03-07
# 18281.000    2011-06-12
# 18282.000    2011-12-02
# 18283.000    2011-12-06
# 18287.000    2011-10-28
# Name: date, Length: 3950, dtype: object

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_uk['date'].max()
# Out:
# datetime.date(2011, 12, 9)

# %%
df_uk.groupby("customerid")["date"].max()
# Out:
# customerid
# 12346.000    2011-01-18
# 12747.000    2011-12-07
# 12748.000    2011-12-09
# 12749.000    2011-12-06
# 12820.000    2011-12-06
#                 ...
# 18280.000    2011-03-07
# 18281.000    2011-06-12
# 18282.000    2011-12-02
# 18283.000    2011-12-06
# 18287.000    2011-10-28
# Name: date, Length: 3950, dtype: object

# %%
df_uk.groupby("date")["customerid"].max().tail(1)# en son sparis veren amca.
# Out:
# date
# 2011-12-09   18102.000
# Name: customerid, dtype: float64

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df_uk.shape
# Out:
# (490300, 10)

# %%
df_uk.groupby("customerid")["invoicedate"].diff().sort_values(ascending= False)
# Out:
# 520468   365 days 23:34:00
# 521361   364 days 22:02:00
# 514153   364 days 01:16:00
# 527074   363 days 01:21:00
# 507249   356 days 23:59:00
#                 ...
# 534480                 NaT
# 536969                 NaT
# 537255                 NaT
# 538064                 NaT
# 538812                 NaT
# Name: invoicedate, Length: 356728, dtype: timedelta64[ns]

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_uk
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                invoicedate  unitprice  customerid         country  totalprice  \
# ...

# %%
drop_columns(df_uk,"date")
# Out:
# date were dropped

# %% [markdown]
# 6. Plot RFM distributions

# %%
# Plotting RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(RFM_table['recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(RFM_table['frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(RFM_table['monetary_value'])
# Show the plot
plt.show()

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk1 = df_uk.copy()
df_uk1
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                invoicedate  unitprice  customerid         country  totalprice
# ...

# %%
df_uk1.duplicated().sum()
# Out:
# 0

# %%
df_uk1.drop_duplicates(keep="first", inplace=True)

# %%
df_uk1.duplicated().sum()
# Out:
# 0

# %%
any(df_uk1.duplicated())
# Out:
# False

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
fre_df = df_uk1.groupby(by=['customerid'], as_index=False)['invoiceno'].count()
fre_df.columns = ['customerid','frequency']
fre_df.head()
# Out:
#    customerid  frequency
# 0   12346.000          2
# 1   12747.000        103
# 2   12748.000       4459
# 3   12749.000        231
# 4   12820.000         59

# %%
df_uk1.groupby("customerid")["invoicedate"].diff()
# Out:
# 0                     NaT
# 1         0 days 00:00:00
# 2         0 days 00:00:00
# 3         0 days 00:00:00
# 4         0 days 00:00:00
#                ...
# 541889    0 days 00:00:00
# 541890   14 days 02:27:00
# 541891    0 days 00:00:00
# 541892    0 days 00:00:00
# 541893    0 days 00:00:00
# Name: invoicedate, Length: 356728, dtype: timedelta64[ns]

# %% [markdown]
# 3. Plot RFM distributions

# %%
# Plotting RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(RFM_table['recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(RFM_table['frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(RFM_table['monetary_value'])
# Show the plot
plt.show()

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_uk1["totalprice"] = df_uk1["quantity"] * df_uk1["unitprice"]

# %%
df_uk1.sample()
# Out:
#        invoiceno stockcode             description  quantity  \
# 443373  574700.0   20757.0  RED DAISY POCKET BOOK      3.000
#
#                invoicedate  unitprice  customerid         country  totalprice
# 443373 2011-11-06 13:53:00      0.850   16033.000  United Kingdom       2.550

# %%
mon_df = df_uk1.groupby(by='customerid',as_index=False).agg({'totalprice': 'sum'})
mon_df.columns = ['customerid','monetary']
mon_df.head()
# Out:
#    customerid  monetary
# 0   12346.000     0.000
# 1   12747.000  4196.010
# 2   12748.000 28405.560
# 3   12749.000  3868.200
# 4   12820.000   942.340

# %%
df_uk1.groupby("customerid")["totalprice"].sum()
# Out:
# customerid
# 12346.000       0.000
# 12747.000    4196.010
# 12748.000   28405.560
# 12749.000    3868.200
# 12820.000     942.340
#                ...
# 18280.000     180.600
# 18281.000      80.820
# 18282.000     176.600
# 18283.000    2045.530
# 18287.000    1837.280
# Name: totalprice, Length: 3950, dtype: float64

# %% [markdown]
# 2. Plot RFM distributions

# %%
# Plotting RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(RFM_table['recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(RFM_table['frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(RFM_table['monetary_value'])
# Show the plot
plt.show()

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
# RFM Table
rfm_table=df_uk1.groupby('customerid').agg({'invoicedate': lambda x: (NOW - x.max()).days, # Recency
                                                'invoiceno': lambda x: len(x.unique()), # Frequency
                                                'totalprice': lambda x: x.sum()})    # Monetary 

rfm_table['invoicedate'] = rfm_table['invoicedate'].astype(int)

rfm_table.rename(columns={'invoicedate': 'recency', 
                         'invoiceno': 'frequency',
                         'totalprice': 'monetary_value'}, inplace=True)
rfm_table.head()
# Out:
#             recency  frequency  monetary_value
# customerid
# 12346.000       324          2           0.000
# 12747.000         1         11        4196.010
# 12748.000        -1        224       28405.560
# 12749.000         2          8        3868.200
# 12820.000         2          4         942.340

# %%
rfm_table.reset_index()
# Out:
#       customerid  recency  frequency  monetary_value
# 0      12346.000      324          2           0.000
# 1      12747.000        1         11        4196.010
# 2      12748.000       -1        224       28405.560
# 3      12749.000        2          8        3868.200
# 4      12820.000        2          4         942.340
# ...          ...      ...        ...             ...
# 3945   18280.000      276          1         180.600
# 3946   18281.000      179          1          80.820
# 3947   18282.000        6          3         176.600
# 3948   18283.000        2         16        2045.530
# 3949   18287.000       41          3        1837.280
#
# [3950 rows x 4 columns]

# %%
df_rfm = pd.concat([df_uk1,rfm_table],axis=1)
df_rfm
# Out:
#           invoiceno stockcode                          description  quantity  \
# 0.000      536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1.000      536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2.000      536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3.000      536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4.000      536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...             ...       ...                                  ...       ...
# 18255.000       NaN       NaN                                  NaN       NaN
# 18281.000       NaN       NaN                                  NaN       NaN
# 18282.000       NaN       NaN                                  NaN       NaN
# 18283.000       NaN       NaN                                  NaN       NaN
# 18287.000       NaN       NaN                                  NaN       NaN
#
# ...

# %%
df_rfm.loc[18255.000]
# Out:
# invoiceno            NaN
# stockcode            NaN
# description          NaN
# quantity             NaN
# invoicedate          NaT
# unitprice            NaN
# customerid           NaN
# country              NaN
# totalprice           NaN
# recency           88.000
# frequency          1.000
# monetary_value   103.300
# Name: 18255.0, dtype: object

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
quantiles = rfm_table.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#        recency  frequency  monetary_value
# 0.250   15.000      1.000         281.030
# 0.500   49.000      3.000         623.335
# 0.750  142.000      5.000        1517.798

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
# Converting quantiles to a dictionary, easier to use.
quantiles = quantiles.to_dict()
##  RFM Segmentation ----
rfm_segment = rfm_table.copy()
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def R_Class(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1
    
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FM_Class(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4

# %%
rfm_segment['R_Quartile'] = rfm_segment['recency'].apply(R_Class, args=('recency',quantiles,))
rfm_segment['F_Quartile'] = rfm_segment['frequency'].apply(FM_Class, args=('frequency',quantiles,))
rfm_segment['M_Quartile'] = rfm_segment['monetary_value'].apply(FM_Class, args=('monetary_value',quantiles,))

# %%
rfm_segment
# Out:
#             recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customerid
# 12346.000       324          2           0.000           1           2
# 12747.000         1         11        4196.010           4           4
# 12748.000        -1        224       28405.560           4           4
# 12749.000         2          8        3868.200           4           4
# 12820.000         2          4         942.340           4           3
# ...             ...        ...             ...         ...         ...
# 18280.000       276          1         180.600           1           1
# 18281.000       179          1          80.820           1           1
# 18282.000         6          3         176.600           4           2
# 18283.000         2         16        2045.530           4           4
# 18287.000        41          3        1837.280           3           2
#
#             M_Quartile
# customerid
# 12346.000            1
# 12747.000            4
# ...

# %%
rfm_segment['RFMClass'] = rfm_segment.R_Quartile.map(str) \
                            + rfm_segment.F_Quartile.map(str) \
                            + rfm_segment.M_Quartile.map(str)

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
#RFMClass = 444
rfm_segment[rfm_segment['RFMClass']=='444'].sort_values('monetary_value', ascending=False).head()
# Out:
#             recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customerid
# 18102.000        -1         62      256438.490           4           4
# 17450.000         7         55      187322.170           4           4
# 17511.000         1         46       88125.380           4           4
# 16684.000         3         31       65892.080           4           4
# 13694.000         2         60       62690.540           4           4
#
#             M_Quartile RFMClass
# customerid
# 18102.000            4      444
# 17450.000            4      444
# 17511.000            4      444
# 16684.000            4      444
# 13694.000            4      444

# %%
#Customers who's recency value is low

rfm_segment[rfm_segment['R_Quartile'] <= 2 ].sort_values('monetary_value', ascending=False).head(5)
# Out:
#             recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customerid
# 15749.000       234          4       21535.900           1           3
# 12939.000        63          8       11581.800           2           4
# 16180.000        99         10       10217.480           2           4
# 13093.000       266         13        7741.470           1           4
# 16745.000        85         18        7157.100           2           4
#
#             M_Quartile RFMClass
# customerid
# 15749.000            4      134
# 12939.000            4      244
# 16180.000            4      244
# 13093.000            4      144
# 16745.000            4      244

# %%
#Customers who's recency, frequency as well as monetary values are low 

rfm_segment[rfm_segment['RFMClass']=='111'].sort_values('recency',ascending=False).head(5)
# Out:
#             recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customerid
# 14237.000       372          1         161.000           1           1
# 13065.000       372          1         205.860           1           1
# 18011.000       372          1         102.790           1           1
# 15350.000       372          1         115.650           1           1
# 13747.000       372          1          79.600           1           1
#
#             M_Quartile RFMClass
# customerid
# 14237.000            1      111
# 13065.000            1      111
# 18011.000            1      111
# 15350.000            1      111
# 13747.000            1      111

# %%
#Customers with high frequency value

rfm_segment[rfm_segment['F_Quartile'] >= 3 ].sort_values('monetary_value', ascending=False).head(5)
# Out:
#             recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customerid
# 18102.000        -1         62      256438.490           4           4
# 17450.000         7         55      187322.170           4           4
# 17511.000         1         46       88125.380           4           4
# 16684.000         3         31       65892.080           4           4
# 13694.000         2         60       62690.540           4           4
#
#             M_Quartile RFMClass
# customerid
# 18102.000            4      444
# 17450.000            4      444
# 17511.000            4      444
# 16684.000            4      444
# 13694.000            4      444

# %%
print("Best Customers: ",len(rfm_segment[rfm_segment['RFMClass']=='444']))
print('Loyal Customers: ',len(rfm_segment[rfm_segment['F_Quartile']==4]))
print("Big Spenders: ",len(rfm_segment[rfm_segment['M_Quartile']==4]))
print('Almost Lost: ', len(rfm_segment[rfm_segment['RFMClass']=='244']))
print('Lost Customers: ',len(rfm_segment[rfm_segment['RFMClass']=='144']))
print('Lost Cheap Customers: ',len(rfm_segment[rfm_segment['RFMClass']=='111']))
# Out:
# Best Customers:  442
# Loyal Customers:  978
# Big Spenders:  988
# Almost Lost:  85
# Lost Customers:  14
# Lost Cheap Customers:  368

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
#Date from customer's last purchase.The nearest date gets 6 and the furthest date gets 1.
rfm_segment["recency_score"] = pd.qcut(rfm_segment['recency'], 6, labels=[6, 5, 4, 3, 2, 1])
# Total number of purchases.The least frequency gets 1 and the maximum frequency gets 6.
rfm_segment["frequency_score"] = pd.qcut(rfm_segment["frequency"].rank(method="first"), 6, labels=[1, 2, 3, 4, 5, 6])
#Total spend by the customer.The least money gets 1, the most money gets 6.
rfm_segment["monetary_score"]= pd.qcut(rfm_segment["monetary_value"],6,labels=[1,2,3,4,5, 6])
rfm_segment.head()
# Out:
#             recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customerid
# 12346.000       324          2           0.000           1           2
# 12747.000         1         11        4196.010           4           4
# 12748.000        -1        224       28405.560           4           4
# 12749.000         2          8        3868.200           4           4
# 12820.000         2          4         942.340           4           3
#
#             M_Quartile RFMClass recency_score frequency_score monetary_score
# customerid
# 12346.000            1      121             1               2              1
# 12747.000            4      444             6               6              6
# 12748.000            4      444             6               6              6
# 12749.000            4      444             6               5              6
# 12820.000            3      433             6               4              4

# %%
#RFM - The value of 2 different variables that were formed was recorded as a RFM_SCORE
rfm_segment["rfm_score"] = (rfm_segment["recency_score"].astype(str) + rfm_segment["frequency_score"].astype(str))

# %%
rfm_segment["rfm_score"] = rfm_segment.rfm_score.astype(int)

# %%
 rfm_segment.rfm_score.value_counts().sort_index()
# Out:
# 11    237
# 12    231
# 13    118
# 14     47
# 15     16
# 16     10
# 21    139
# 22    119
# 23    156
# 24    132
# 25     83
# 26     25
# 31    117
# 32    129
# 33    107
# 34    113
# 35    111
# 36     47
# 41     82
# 42    100
# 43    102
# 44    133
# 45    147
# 46    101
# 51     64
# 52     52
# 53    109
# 54    127
# 55    151
# 56    158
# 61     20
# 62     27
# 63     66
# 64    106
# 65    150
# 66    318
# Name: rfm_score, dtype: int64

# %%
len(rfm_segment.rfm_score.value_counts().sort_index())
# Out:
# 36

# %%
# Define rfm_level function
def FMCG_rfm_level(df):
    if df['rfm_score'] >= 61:
        return 'Can\'t Loose Them'
    elif ((df['rfm_score'] >= 51) & (df['rfm_score'] < 56)):
        return 'Champions'
    elif ((df['rfm_score'] >= 41) & (df['rfm_score'] < 46)):
        return 'Loyal/Commited'
    elif ((df['rfm_score'] >= 31) & (df['rfm_score'] < 36)):
        return 'Potential'
    elif ((df['rfm_score'] >= 21) & (df['rfm_score'] < 26)):
        return 'Promising'
    elif ((df['rfm_score'] >= 11) & (df['rfm_score'] < 16)):
        return 'Requires Attention'
    else:
        return 'Demands Activation'
# Create a new variable RFM_Level
rfm_segment['RFM_Level'] = rfm_segment.apply(FMCG_rfm_level, axis=1)
# Printing the header with top 15 rows 
rfm_segment.reset_index(inplace=True)

# %%
rfm_df = rfm_segment[["customerid","recency","frequency","monetary_value","recency_score", "frequency_score",	"monetary_score",	"rfm_score","RFM_Level"]]
rfm_df.columns
# Out:
# Index(['customerid', 'recency', 'frequency', 'monetary_value', 'recency_score',
#        'frequency_score', 'monetary_score', 'rfm_score', 'RFM_Level'],
#       dtype='object')

# %%
labels = rfm_df.RFM_Level
rfm_df['ClusterID']=labels
rfm_df
# Out:
#       customerid  recency  frequency  monetary_value recency_score  \
# 0      12346.000      324          2           0.000             1
# 1      12747.000        1         11        4196.010             6
# 2      12748.000       -1        224       28405.560             6
# 3      12749.000        2          8        3868.200             6
# 4      12820.000        2          4         942.340             6
# ...          ...      ...        ...             ...           ...
# 3945   18280.000      276          1         180.600             1
# 3946   18281.000      179          1          80.820             2
# 3947   18282.000        6          3         176.600             6
# 3948   18283.000        2         16        2045.530             6
# 3949   18287.000       41          3        1837.280             4
#
#      frequency_score monetary_score  rfm_score           RFM_Level  \
# 0                  2              1         12  Requires Attention
# ...

# %%
tpk = rfm_segment.groupby('RFM_Level')["customerid"].nunique().sort_values(ascending=False)

plt.bar(tpk.index, tpk.values)
plt.xticks(rotation=90);

# %%
sns.barplot(rfm_segment['RFM_Level'].value_counts());

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales) we can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
rfm_segment.columns
# Out:
# Index(['customerid', 'recency', 'frequency', 'monetary_value', 'R_Quartile',
#        'F_Quartile', 'M_Quartile', 'RFMClass', 'recency_score',
#        'frequency_score', 'monetary_score', 'rfm_score', 'RFM_Level'],
#       dtype='object')

# %%
rfm_segment.groupby("RFM_Level")["customerid"].sum()
# Out:
# RFM_Level
# Can't Loose Them     10638742.000
# Champions             7814440.000
# Demands Activation    5326879.000
# Loyal/Commited        8844916.000
# Potential             8938521.000
# Promising             9791248.000
# Requires Attention   10115270.000
# Name: customerid, dtype: float64

# %%
sns.pairplot(rfm_segment);

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into 6 different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
rfm_segment.sample().T
# Out:
#                       1586
# customerid       15054.000
# recency                 11
# frequency                2
# monetary_value     302.100
# R_Quartile               4
# F_Quartile               2
# M_Quartile               2
# RFMClass               422
# recency_score            5
# frequency_score          3
# monetary_score           2
# rfm_score               53
# RFM_Level        Champions

# %%
df_2 = rfm_segment[["recency","frequency","monetary_value"]]

df_2
# Out:
#       recency  frequency  monetary_value
# 0         324          2           0.000
# 1           1         11        4196.010
# 2          -1        224       28405.560
# 3           2          8        3868.200
# 4           2          4         942.340
# ...       ...        ...             ...
# 3945      276          1         180.600
# 3946      179          1          80.820
# 3947        6          3         176.600
# 3948        2         16        2045.530
# 3949       41          3        1837.280
#
# [3950 rows x 3 columns]

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
sns.heatmap(df_2.corr(),annot=True,cmap="PuBu_r");

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
# Plotting RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(df_2['recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(df_2['frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(df_2['monetary_value'])
# Show the plot
plt.show()

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. You can use the logarithm method to normalize the values in a column.

# %%
log_df = rfm_segment[['recency', 'frequency', 'monetary_value']].apply(np.log1p).round(3)
log_df.head()
# Out:
#    recency  frequency  monetary_value
# 0    5.784      1.099           0.000
# 1    0.693      2.485           8.342
# 2     -inf      5.416          10.254
# 3    1.099      2.197           8.261
# 4    1.099      1.609           6.849

# %% [markdown]
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
sns.pairplot(log_df);

# %%
matrix = np.triu(log_df[['recency','frequency','monetary_value']].corr())
fig, ax = plt.subplots(figsize=(11, 6)) 
sns.heatmap (log_df[['recency','frequency','monetary_value']].corr(), 
             annot=True, 
             fmt= '.2f', 
             vmin=-1, 
             vmax=1, 
             center=0, 
             cmap='coolwarm',
             mask=matrix, 
             ax=ax);

# %%
'''fig,ax = plt.subplots(figsize=(10, 12))
plt.subplot(3, 1, 1); sns.distplot(log_df.recency.astype(int), label = 'recency')
plt.subplot(3, 1, 2); sns.distplot(log_df.frequency, label = 'frequency')
plt.subplot(3, 1, 3); sns.distplot(log_df.monetary_value, label = 'monetary_value')
plt.style.use('fivethirtyeight')
plt.tight_layout()
plt.show()'''
# Out:
# "fig,ax = plt.subplots(figsize=(10, 12))\nplt.subplot(3, 1, 1); sns.distplot(log_df.recency.astype(int), label = 'recency')\nplt.subplot(3, 1, 2); sns.distplot(log_df.frequency, label = 'frequency')\nplt.subplot(3, 1, 3); sns.distplot(log_df.monetary_value, label = 'monetary_value')\nplt.style.use('fivethirtyeight')\nplt.tight_layout()\nplt.show()"

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %%
# !pip install pyclustertend
# Out:
# ...
#   Using cached scikit_learn-0.24.2-cp39-cp39-win_amd64.whl (6.9 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\44778\anaconda3\lib\site-packages\scikit_learn-1.0.2.dist-info\
#    from C:\Users\44778\anaconda3\Lib\site-packages\~cikit_learn-1.0.2.dist-info
#   Moving to c:\users\44778\anaconda3\lib\site-packages\sklearn\__check_build\
#    from C:\Users\44778\anaconda3\Lib\site-packages\sklearn\~_check_build
#   Moving to c:\users\44778\anaconda3\lib\site-packages\sklearn\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-8vi4om6z\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\sklearn\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\sklearn\~_pycache__
# ...

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from pyclustertend import hopkins
from sklearn.preprocessing import scale
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics import silhouette_samples,silhouette_score
from scipy.cluster.hierarchy import linkage, dendrogram
from yellowbrick.cluster import KElbowVisualizer

# %%
log_df.isnull().sum()
# Out:
# recency            0
# frequency          0
# monetary_value    37
# dtype: int64

# %%
log_df.shape
# Out:
# (3950, 3)

# %%
log_df.dropna(axis=0, inplace=True)

# %%
log_df.shape
# Out:
# (3913, 3)

# %%
trans_df = log_df.astype(int, errors='ignore')

# %%
np.any(np.isnan(log_df))


np.all(np.isfinite(log_df))
# Out:
# False

# %%
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3913 entries, 0 to 3949
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   recency         3913 non-null   float64
#  1   frequency       3913 non-null   float64
#  2   monetary_value  3913 non-null   float64
# dtypes: float64(3)
# memory usage: 122.3 KB

# %%
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3913 entries, 0 to 3949
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   recency         3913 non-null   float64
#  1   frequency       3913 non-null   float64
#  2   monetary_value  3913 non-null   float64
# dtypes: float64(3)
# memory usage: 122.3 KB

# %%
trans_df = trans_df[np.all(np.isfinite(trans_df), axis=1)]

# %%
scaler = StandardScaler()
scaler.fit(trans_df)

#Store it separately for clustering
rfm_scaled = scaler.transform(trans_df)

# %%
hopkins(rfm_scaled, rfm_scaled.shape[0])
# Out:
# 0.05302962125690427

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
ks = range(1, 12)
inertias=[]
for k in ks :
    # Create a KMeans clusters
    kc = KMeans(n_clusters=k, random_state=42)
    kc.fit(rfm_scaled)
    inertias.append(kc.inertia_)

# Plot ks vs inertias
f, ax = plt.subplots(figsize=(15, 8))
plt.plot(ks, inertias, '-o')
plt.xlabel('Number of clusters, k')
plt.ylabel('Inertia')
plt.xticks(ks)
plt.style.use('ggplot')
plt.title('What is the Best Number for KMeans?')
plt.show()

# %%
plt.rcParams['figure.facecolor'] = 'white'
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 12))

plt.figure(figsize=(14, 8))
visualizer.fit(rfm_scaled)        # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
ssd =[]

K = range(2, 12)

for k in K:
    model = KMeans(n_clusters=k)
    model.fit(rfm_scaled)
    ssd.append(model.inertia_)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(rfm_scaled, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.43159529128312824
# Silhouette Score for 3 clusters: 0.3350973697604992
# Silhouette Score for 4 clusters: 0.33619390904499485
# Silhouette Score for 5 clusters: 0.30969619867108034
# Silhouette Score for 6 clusters: 0.30266402700644496
# Silhouette Score for 7 clusters: 0.27847755572524296
# Silhouette Score for 8 clusters: 0.27498128890610724
# Silhouette Score for 9 clusters: 0.2757719291303361
# Silhouette Score for 10 clusters: 0.2883380104672014
# Silhouette Score for 11 clusters: 0.27475246071114434

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model_3 = KMeans(n_clusters=3, random_state=42)
visualizer = SilhouetteVisualizer(model_3)

visualizer.fit(rfm_scaled)    # Fit the data to the visualizer
visualizer.poof();

# %%
from yellowbrick.cluster import InterclusterDistance
plt.rcParams["figure.figsize"] = (10, 7)

# Instantiate the clustering model and visualizer
model = KMeans(3)
visualizer = InterclusterDistance(model_3)

visualizer.fit(rfm_scaled)  # Fit the data to the visualizer
visualizer.show()  # Finalize and render the figure
# Out:
# <AxesSubplot:title={'center':'KMeans Intercluster Distance Map (via MDS)'}, xlabel='PC2', ylabel='PC1'>

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
from sklearn.utils.sparsefuncs import inplace_column_scale
kmeans = KMeans(n_clusters = 3).fit(rfm_scaled)
kmeans.fit_predict(rfm_scaled)
labels = kmeans.labels_
trans_df['ClusterID']=labels
trans_df.reset_index(inplace=True)

# %%
trans_df.ClusterID.value_counts()
# Out:
# 0    1706
# 2    1494
# 1     682
# Name: ClusterID, dtype: int64

# %% [markdown]
# ### iii. Visualize the Clusters

# %%
'''from math import *
from matplotlib import pyplot as plt
print plt.get_backend()


fig = px.pie(df, values = trans_df['ClusterID'].value_counts(), 
             names = (trans_df['ClusterID'].value_counts()).index, 
             title = 'Predicted Clusters Distribution')
fig.show()'''
# Out:
# "from math import *\nfrom matplotlib import pyplot as plt\nprint plt.get_backend()\n\n\nfig = px.pie(df, values = trans_df['ClusterID'].value_counts(), \n             names = (trans_df['ClusterID'].value_counts()).index, \n             title = 'Predicted Clusters Distribution')\nfig.show()"

# %%
trans_df['ClusterID'] = labels
trans_df.sample(10)
# Out:
#       index  recency  frequency  monetary_value  ClusterID
# 2566   2607    4.663      0.693           5.654          0
# 2945   2994    5.215      1.792           6.204          2
# 903     917    3.932      2.197           7.897          2
# 2820   2868    2.303      2.996           7.710          1
# 63       65    4.060      1.609           5.509          0
# 1384   1408    3.332      0.693           5.291          0
# 1007   1023    5.762      0.693           5.716          0
# 1396   1420    2.079      0.693           5.870          2
# 2287   2323    4.443      1.386           5.500          0
# 581     589    5.371      0.693           5.747          0

# %%
rfm_table.reset_index(inplace=True)

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
'''plt.figure(figsize=(15, 8))
plt.scatter(trans_df.iloc[:, 0], log_df.iloc[:, 1], c = labels, s = 50, cmap = "viridis")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red',alpha=0.5, label = 'Centroids');'''
# Out:
# 'plt.figure(figsize=(15, 8))\nplt.scatter(trans_df.iloc[:, 0], log_df.iloc[:, 1], c = labels, s = 50, cmap = "viridis")\nplt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c=\'red\',alpha=0.5, label = \'Centroids\');'

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
plt.figure(figsize=(15,6))

plt.subplot(1, 3, 1)
sns.boxplot(trans_df['ClusterID'], trans_df['recency'])

plt.subplot(1, 3, 2)
sns.boxplot(trans_df['ClusterID'], trans_df['frequency'])

plt.subplot(1, 3, 3)
sns.boxplot(trans_df['ClusterID'], trans_df['monetary_value'])
plt.show()

# %% [markdown]
# ### iv. Assign the Label

# %%
trans_df['Labels'] = trans_df['ClusterID'].map({0:'Lost/Needed Attention Customers', 1:'Current Custemer', 2:'Top/Best Customer'})
trans_df.sample(8)
# Out:
#       index  recency  frequency  monetary_value  ClusterID  \
# 1899   1927    2.398      1.792           6.804          2
# 1603   1627    5.740      2.197           5.516          0
# 2569   2610    4.159      0.693           5.664          0
# 2654   2698    3.178      1.099           5.645          0
# 3059   3111    4.779      0.693           4.937          0
# 2879   2927    3.367      1.609           6.179          2
# 2805   2853    5.609      1.099           7.045          0
# 2884   2932    1.386      2.398           8.863          1
#
#                                Labels
# 1899                Top/Best Customer
# 1603  Lost/Needed Attention Customers
# 2569  Lost/Needed Attention Customers
# 2654  Lost/Needed Attention Customers
# 3059  Lost/Needed Attention Customers
# 2879                Top/Best Customer
# 2805  Lost/Needed Attention Customers
# 2884                 Current Custemer

# %%
trans_df[trans_df['Labels'] == "Lost/Needed Attention Customers"]
# Out:
#       index  recency  frequency  monetary_value  ClusterID  \
# 0         0    5.784      1.099           0.000          0
# 4         5    5.366      0.693           4.540          0
# 7         8    4.078      0.693           5.987          0
# 11       12    5.775      1.386           5.538          0
# 13       14    5.568      0.693           5.376          0
# ...     ...      ...        ...             ...        ...
# 3873   3941    2.833      1.099          -0.000          0
# 3875   3943    4.060      1.099           4.591          0
# 3876   3944    4.290      0.693           5.164          0
# 3877   3945    5.624      0.693           5.202          0
# 3878   3946    5.193      0.693           4.405          0
#
#                                Labels
# 0     Lost/Needed Attention Customers
# 4     Lost/Needed Attention Customers
# 7     Lost/Needed Attention Customers
# 11    Lost/Needed Attention Customers
# 13    Lost/Needed Attention Customers
# ...

# %%
trans_df[trans_df['Labels'] == "Top/Best Customer"]
# Out:
#       index  recency  frequency  monetary_value  ClusterID             Labels
# 3         4    1.099      1.609           6.849          2  Top/Best Customer
# 5         6    4.248      1.386           6.824          2  Top/Best Customer
# 6         7    4.304      1.792           7.473          2  Top/Best Customer
# 9        10    1.609      1.386           6.066          2  Top/Best Customer
# 14       15    3.466      1.099           5.951          2  Top/Best Customer
# ...     ...      ...        ...             ...        ...                ...
# 3867   3935    4.277      1.099           6.688          2  Top/Best Customer
# 3872   3940    0.693      1.386           5.323          2  Top/Best Customer
# 3874   3942    3.045      1.386           5.782          2  Top/Best Customer
# 3879   3947    1.946      1.386           5.180          2  Top/Best Customer
# 3881   3949    3.738      1.386           7.517          2  Top/Best Customer
#
# [1494 rows x 6 columns]

# %%
trans_df[trans_df['Labels'] == "Current Custemer"]
# Out:
#       index  recency  frequency  monetary_value  ClusterID            Labels
# 1         1    0.693      2.485           8.342          1  Current Custemer
# 2         3    1.099      2.197           8.261          1  Current Custemer
# 8         9    0.693      2.197           7.292          1  Current Custemer
# 10       11    0.693      1.946           6.927          1  Current Custemer
# 12       13    3.611      2.079           8.817          1  Current Custemer
# ...     ...      ...        ...             ...        ...               ...
# 3851   3918    2.197      2.944           7.630          1  Current Custemer
# 3853   3920    1.946      2.197           7.827          1  Current Custemer
# 3861   3929    3.664      2.565           7.726          1  Current Custemer
# 3871   3939    0.693      2.079           8.028          1  Current Custemer
# 3880   3948    1.099      2.833           7.624          1  Current Custemer
#
# [682 rows x 6 columns]

# %%
trans_df.sample(10)
# Out:
#       index  recency  frequency  monetary_value  ClusterID  \
# 3448   3511    3.135      0.693           5.223          0
# 1467   1491    0.693      1.099           6.934          2
# 1179   1200    1.099      1.946           8.173          1
# 3675   3740    3.611      1.099           5.944          0
# 1695   1719    5.737      0.693           5.046          0
# 3824   3891    3.219      1.792           6.399          2
# 890     904    2.303      2.708          10.828          1
# 3665   3730    4.977      0.693           5.035          0
# 2967   3016    1.099      2.079           7.389          1
# 638     648    5.380      0.693           5.303          0
#
#                                Labels
# 3448  Lost/Needed Attention Customers
# 1467                Top/Best Customer
# 1179                 Current Custemer
# 3675  Lost/Needed Attention Customers
# 1695  Lost/Needed Attention Customers
# 3824                Top/Best Customer
# 890                  Current Custemer
# ...

# %%
trans_df[trans_df['ClusterID'] == 0].sample(5)
# Out:
#       index  recency  frequency  monetary_value  ClusterID  \
# 2796   2844    5.366      0.693           5.482          0
# 375     382    5.561      0.693           6.655          0
# 3586   3651    5.717      0.693           4.900          0
# 576     584    4.205      0.693           6.977          0
# 3431   3494    4.949      0.693           5.192          0
#
#                                Labels
# 2796  Lost/Needed Attention Customers
# 375   Lost/Needed Attention Customers
# 3586  Lost/Needed Attention Customers
# 576   Lost/Needed Attention Customers
# 3431  Lost/Needed Attention Customers

# %%
trans_df[trans_df['ClusterID'] == 1].sample(5)
# Out:
#       index  recency  frequency  monetary_value  ClusterID            Labels
# 2925   2973    4.382      2.996           7.919          1  Current Custemer
# 3039   3091    1.386      2.197           7.588          1  Current Custemer
# 492     500    0.000      1.792           7.488          1  Current Custemer
# 1225   1246    1.946      3.219           7.685          1  Current Custemer
# 2349   2386    1.099      3.850           9.568          1  Current Custemer

# %%
trans_df[trans_df['ClusterID'] == 2].sample(5)
# Out:
#       index  recency  frequency  monetary_value  ClusterID             Labels
# 382     389    2.773      1.386           6.815          2  Top/Best Customer
# 102     105    1.946      1.099           5.589          2  Top/Best Customer
# 3401   3464    3.045      1.609           7.198          2  Top/Best Customer
# 720     732    4.554      1.386           7.883          2  Top/Best Customer
# 3063   3115    5.024      2.079           6.885          2  Top/Best Customer

# %% [markdown]
# **Conclusion Example :**
#
# - Cluster 0 : The first cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)
#
# - Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
# - Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
cohort_df = df
cohort_df.sample(5)
# Out:
#        invoiceno stockcode                          description  quantity  \
# 433004  573903.0   23524.0               WALL ART HORSE & PONY      1.000
# 341107  566734.0   21975.0       PACK OF 60 DINOSAUR CAKE CASES     2.000
# 293045  562574.0   22149.0           FELTCRAFT 6 FLOWER FRIENDS     2.000
# 449133  575087.0   23130.0         MISTLETOE HEART WREATH GREEN     1.000
# 482159  577411.0   21123.0  SET/10 IVORY POLKADOT PARTY CANDLES     2.000
#
#                invoicedate  unitprice  customerid         country  totalprice
# 433004 2011-11-01 14:51:00      3.750   14667.000  United Kingdom       3.750
# 341107 2011-09-14 14:09:00      0.550   16910.000  United Kingdom       1.100
# 293045 2011-08-07 12:42:00      2.100   14903.000  United Kingdom       4.200
# 449133 2011-11-08 13:57:00      4.150   16549.000  United Kingdom       4.150
# 482159 2011-11-20 11:00:00      1.250   17387.000  United Kingdom       2.500

# %%
import datetime as dt
from datetime import datetime
from datetime import timedelta

# %%
'%m/%d/%Y %H:%M:%S.%f'
# Out:
# '%m/%d/%Y %H:%M:%S.%f'

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %%
df.invoicedate
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoicedate, Length: 536641, dtype: datetime64[ns]

# %%
cohort_df['cohortmonth'] = cohort_df.groupby('customerid')['invoicedate'].transform('min')
cohort_df.sample(10)
# Out:
#        invoiceno stockcode                         description  quantity  \
# 495172  578292.0   48116.0          DOORMAT MULTICOLOUR STRIPE     1.000
# 64857   541678.0   20759.0          CHRYSANTHEMUM POCKET BOOK      3.000
# 191295  553348.0   79321.0                       CHILLI LIGHTS     4.000
# 114763  546084.0   22243.0   5 HOOK HANGER RED MAGIC TOADSTOOL    12.000
# 326515  565541.0   23204.0         CHARLOTTE BAG APPLES DESIGN     2.000
# 375229  569424.0   23504.0    PLAYING CARDS JUBILEE UNION JACK     6.000
# 388399  570427.0   22627.0                 MINT KITCHEN SCALES     2.000
# 438036  574304.0   22457.0     NATURAL SLATE HEART CHALKBOARD      3.000
# 263943  560047.0   21509.0  COWBOYS AND INDIANS BIRTHDAY CARD     12.000
# 212607  555499.0   22824.0      3 TIER SWEETHEART GARDEN SHELF     1.000
#
#                invoicedate  unitprice  customerid         country  totalprice  \
# 495172 2011-11-23 14:35:00      8.250   13174.000  United Kingdom       8.250
# ...

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %%
def get_month_int(df, column):
    year = df[column].dt.year
    month = df[column].dt.month
    day = df[column].dt.day
    return year, month, day

# %%
pd.DataFrame(get_month_int(cohort_df,"invoicedate"))
# Out:
#              0       1       2       3       4       5       6       7       \
# invoicedate    2010    2010    2010    2010    2010    2010    2010    2010
# invoicedate      12      12      12      12      12      12      12      12
# invoicedate       1       1       1       1       1       1       1       1
#
#              8       9       10      11      12      13      14      15      \
# invoicedate    2010    2010    2010    2010    2010    2010    2010    2010
# invoicedate      12      12      12      12      12      12      12      12
# invoicedate       1       1       1       1       1       1       1       1
#
#              16      17      18      19      20      21      22      23      \
# invoicedate    2010    2010    2010    2010    2010    2010    2010    2010
# invoicedate      12      12      12      12      12      12      12      12
# invoicedate       1       1       1       1       1       1       1       1
#
# ...

# %%
def get_month(x) : return dt.datetime(x.year,x.month,1)
cohort_df['invoicemonth'] = cohort_df['invoicedate'].apply(get_month)
grouping = cohort_df.groupby('customerid')['invoicemonth']
cohort_df['cohortmonth'] = grouping.transform('min')
cohort_df.tail()
# Out:
#        invoiceno stockcode                      description  quantity  \
# 541904  581587.0   22613.0      PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905  581587.0   22899.0     CHILDREN'S APRON DOLLY GIRL      6.000
# 541906  581587.0   23254.0    CHILDRENS CUTLERY DOLLY GIRL      4.000
# 541907  581587.0   23255.0  CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 541908  581587.0   22138.0    BAKING SET 9 PIECE RETROSPOT      3.000
#
#                invoicedate  unitprice  customerid country  totalprice  \
# 541904 2011-12-09 12:50:00      0.850   12680.000  France      10.200
# 541905 2011-12-09 12:50:00      2.100   12680.000  France      12.600
# 541906 2011-12-09 12:50:00      4.150   12680.000  France      16.600
# 541907 2011-12-09 12:50:00      4.150   12680.000  France      16.600
# 541908 2011-12-09 12:50:00      4.950   12680.000  France      14.850
#
#        cohortmonth invoicemonth
# 541904  2011-08-01   2011-12-01
# 541905  2011-08-01   2011-12-01
# ...

# %%
def get_month_int (dframe,column):
    year = dframe[column].dt.year
    month = dframe[column].dt.month
    day = dframe[column].dt.day
    return year, month , day 

invoice_year,invoice_month,_ = get_month_int(cohort_df,'invoicemonth')
cohort_year,cohort_month,_ = get_month_int(cohort_df,'cohortmonth')

year_diff = invoice_year - cohort_year 
month_diff = invoice_month - cohort_month 

cohort_df['cohortindex'] = year_diff * 12 + month_diff + 1

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 seperate series for each of the two columns

# %%
#Count monthly active customers from each cohort
grouping = cohort_df.groupby(['cohortmonth', 'cohortindex'])
cohort_data = grouping['customerid'].apply(pd.Series.nunique)
# Return number of unique elements in the object.
cohort_data = cohort_data.reset_index()
cohort_counts = cohort_data.pivot(index='cohortmonth',columns='cohortindex',values='customerid')
cohort_counts
# Out:
# cohortindex  1.000   2.000   3.000   4.000   5.000   6.000   7.000   8.000   \
# cohortmonth
# 2010-12-01  948.000 362.000 317.000 367.000 341.000 376.000 360.000 336.000
# 2011-01-01  421.000 101.000 119.000 102.000 138.000 126.000 110.000 108.000
# 2011-02-01  380.000  94.000  73.000 106.000 102.000  94.000  97.000 107.000
# 2011-03-01  440.000  84.000 112.000  96.000 102.000  78.000 116.000 105.000
# 2011-04-01  299.000  68.000  66.000  63.000  62.000  71.000  69.000  78.000
# 2011-05-01  279.000  66.000  48.000  48.000  60.000  68.000  74.000  29.000
# 2011-06-01  235.000  49.000  44.000  64.000  58.000  79.000  24.000     NaN
# 2011-07-01  191.000  40.000  39.000  44.000  52.000  22.000     NaN     NaN
# 2011-08-01  167.000  42.000  42.000  42.000  23.000     NaN     NaN     NaN
# 2011-09-01  298.000  89.000  97.000  36.000     NaN     NaN     NaN     NaN
# 2011-10-01  352.000  93.000  46.000     NaN     NaN     NaN     NaN     NaN
# ...

# %%
df['cohortindex'].value_counts()
# Out:
# 1.000     117289
# 2.000      28793
# 4.000      27810
# 6.000      27289
# 3.000      27227
# 5.000      25665
# 12.000     24075
# 7.000      23970
# 8.000      23895
# 10.000     23813
# 9.000      23419
# 11.000     21031
# 13.000      7328
# Name: cohortindex, dtype: int64

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %%
year_diff = invoice_year - cohort_year 
month_diff = invoice_month - cohort_month 

cohort_df['cohortindex'] = year_diff * 12 + month_diff + 1

# %%
cohort_df.sample(5)
# Out:
#        invoiceno stockcode                        description  quantity  \
# 280428  561399.0   23344.0          JUMBO BAG 50'S CHRISTMAS    100.000
# 287732  562113.0   23245.0         SET OF 3 REGENCY CAKE TINS     1.000
# 506810  579156.0   22138.0      BAKING SET 9 PIECE RETROSPOT     12.000
# 205252  554770.0   84077.0  WORLD WAR 2 GLIDERS ASSTD DESIGNS    96.000
# 36765   539451.0   22817.0                 CARD SUKI BIRTHDAY     2.000
#
#                invoicedate  unitprice  customerid         country  totalprice  \
# 280428 2011-07-27 10:53:00      1.790   15125.000  United Kingdom     179.000
# 287732 2011-08-02 16:11:00     10.790         NaN  United Kingdom      10.790
# 506810 2011-11-28 13:47:00      4.950   17419.000  United Kingdom      59.400
# 205252 2011-05-26 11:40:00      0.290   14911.000            EIRE      27.840
# 36765  2010-12-17 16:59:00      0.850         NaN  United Kingdom       1.700
#
#        cohortmonth invoicemonth  cohortindex
# ...

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
first_cohort = cohort_df.groupby(['cohortmonth', 'cohortindex'])['customerid'].nunique().reset_index()
first_cohort
# Out:
#    cohortmonth  cohortindex  customerid
# 0   2010-12-01        1.000         948
# 1   2010-12-01        2.000         362
# 2   2010-12-01        3.000         317
# 3   2010-12-01        4.000         367
# 4   2010-12-01        5.000         341
# ..         ...          ...         ...
# 86  2011-10-01        2.000          93
# 87  2011-10-01        3.000          46
# 88  2011-11-01        1.000         321
# 89  2011-11-01        2.000          43
# 90  2011-12-01        1.000          41
#
# [91 rows x 3 columns]

# %%
first_cohort.head()
# Out:
#   cohortmonth  cohortindex  customerid
# 0  2010-12-01        1.000         948
# 1  2010-12-01        2.000         362
# 2  2010-12-01        3.000         317
# 3  2010-12-01        4.000         367
# 4  2010-12-01        5.000         341

# %%
cohort_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536641 entries, 0 to 541908
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoiceno     536641 non-null  object
#  1   stockcode     536641 non-null  object
#  2   description   535187 non-null  object
#  3   quantity      536641 non-null  float64
#  4   invoicedate   536641 non-null  datetime64[ns]
#  5   unitprice     536641 non-null  float64
#  6   customerid    401604 non-null  float64
#  7   country       536641 non-null  object
#  8   totalprice    536641 non-null  float64
#  9   cohortmonth   401604 non-null  datetime64[ns]
#  10  CohortIndex   401604 non-null  float64
#  11  InvoiceMonth  536641 non-null  datetime64[ns]
#  12  CohortMonth   401604 non-null  datetime64[ns]
#  13  invoicemonth  536641 non-null  datetime64[ns]
#  14  cohortindex   401604 non-null  float64
# dtypes: datetime64[ns](5), float64(6), object(4)
# ...

# %%
cohort_min = cohort_df['cohortmonth'].min()
cohort_min
# Out:
# Timestamp('2010-12-01 00:00:00')

# %%
cohort_max = cohort_df['cohortmonth'].max()
cohort_max
# Out:
# Timestamp('2011-12-01 00:00:00')

# %%
cohort_max - cohort_min
# Out:
# Timedelta('365 days 00:00:00')

# %%
first_pivot = first_cohort.pivot(index='cohortmonth', columns='cohortindex', values='customerid').round(1)
first_pivot
# Out:
# cohortindex  1.000   2.000   3.000   4.000   5.000   6.000   7.000   8.000   \
# cohortmonth
# 2010-12-01  948.000 362.000 317.000 367.000 341.000 376.000 360.000 336.000
# 2011-01-01  421.000 101.000 119.000 102.000 138.000 126.000 110.000 108.000
# 2011-02-01  380.000  94.000  73.000 106.000 102.000  94.000  97.000 107.000
# 2011-03-01  440.000  84.000 112.000  96.000 102.000  78.000 116.000 105.000
# 2011-04-01  299.000  68.000  66.000  63.000  62.000  71.000  69.000  78.000
# 2011-05-01  279.000  66.000  48.000  48.000  60.000  68.000  74.000  29.000
# 2011-06-01  235.000  49.000  44.000  64.000  58.000  79.000  24.000     NaN
# 2011-07-01  191.000  40.000  39.000  44.000  52.000  22.000     NaN     NaN
# 2011-08-01  167.000  42.000  42.000  42.000  23.000     NaN     NaN     NaN
# 2011-09-01  298.000  89.000  97.000  36.000     NaN     NaN     NaN     NaN
# 2011-10-01  352.000  93.000  46.000     NaN     NaN     NaN     NaN     NaN
# ...

# %%
sizes = first_pivot.iloc[:, 0]
retention = first_pivot.divide(sizes, axis=0).round(2)  #axis=0 to ensure the divide along the row axis
retention
# Out:
# cohortindex  1.000   2.000   3.000   4.000   5.000   6.000   7.000   8.000   \
# cohortmonth
# 2010-12-01    1.000   0.380   0.330   0.390   0.360   0.400   0.380   0.350
# 2011-01-01    1.000   0.240   0.280   0.240   0.330   0.300   0.260   0.260
# 2011-02-01    1.000   0.250   0.190   0.280   0.270   0.250   0.260   0.280
# 2011-03-01    1.000   0.190   0.250   0.220   0.230   0.180   0.260   0.240
# 2011-04-01    1.000   0.230   0.220   0.210   0.210   0.240   0.230   0.260
# 2011-05-01    1.000   0.240   0.170   0.170   0.220   0.240   0.270   0.100
# 2011-06-01    1.000   0.210   0.190   0.270   0.250   0.340   0.100     NaN
# 2011-07-01    1.000   0.210   0.200   0.230   0.270   0.120     NaN     NaN
# 2011-08-01    1.000   0.250   0.250   0.250   0.140     NaN     NaN     NaN
# 2011-09-01    1.000   0.300   0.330   0.120     NaN     NaN     NaN     NaN
# 2011-10-01    1.000   0.260   0.130     NaN     NaN     NaN     NaN     NaN
# ...

# %%
sizes
# Out:
# cohortmonth
# 2010-12-01   948.000
# 2011-01-01   421.000
# 2011-02-01   380.000
# 2011-03-01   440.000
# 2011-04-01   299.000
# 2011-05-01   279.000
# 2011-06-01   235.000
# 2011-07-01   191.000
# 2011-08-01   167.000
# 2011-09-01   298.000
# 2011-10-01   352.000
# 2011-11-01   321.000
# 2011-12-01    41.000
# Name: 1.0, dtype: float64

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 8))
plt.title('Retention rates')
sns.heatmap(data=retention, annot=True, fmt='.0%', vmin=0.0, vmax=0.5, cmap=sns.cubehelix_palette(8))
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(data=first_pivot[1]);

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
second_cohort = cohort_df.groupby(['cohortmonth', 'cohortindex'])['quantity'].mean().reset_index()
second_cohort
# Out:
#    cohortmonth  cohortindex  quantity
# 0   2010-12-01        1.000    11.200
# 1   2010-12-01        2.000    14.692
# 2   2010-12-01        3.000    15.108
# 3   2010-12-01        4.000    14.954
# 4   2010-12-01        5.000    13.055
# ..         ...          ...       ...
# 86  2011-10-01        2.000     7.056
# 87  2011-10-01        3.000     8.080
# 88  2011-11-01        1.000     8.901
# 89  2011-11-01        2.000     9.508
# 90  2011-12-01        1.000    14.795
#
# [91 rows x 3 columns]

# %%
second_pivot = second_cohort.pivot(index='cohortmonth', columns='cohortindex', values='quantity').round(1)
second_pivot
# Out:
# cohortindex  1.000   2.000   3.000   4.000   5.000   6.000   7.000   8.000   \
# cohortmonth
# 2010-12-01   11.200  14.700  15.100  15.000  13.100  14.400  15.300  14.900
# 2011-01-01   10.100  12.700  12.400  11.000  12.300  15.000  14.300  14.500
# 2011-02-01   10.900  12.300  18.600  12.000  11.200  11.500  13.400  12.400
# 2011-03-01    9.800  10.000  12.200   9.500  13.000  12.400  13.200  12.300
# 2011-04-01    9.800  10.100   9.400  11.600  11.600   8.300   9.800   9.500
# 2011-05-01   11.000   9.100  14.000  11.800  11.000   8.700  10.300   7.600
# 2011-06-01   10.400  13.900  10.500  13.400  10.400   9.900   9.300     NaN
# 2011-07-01    9.800  12.700   7.200   7.900   6.100   7.100     NaN     NaN
# 2011-08-01    9.900   6.000   5.400   6.000   7.000     NaN     NaN     NaN
# 2011-09-01   12.000   5.600   7.700   8.900     NaN     NaN     NaN     NaN
# 2011-10-01    8.600   7.100   8.100     NaN     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12, 8))
plt.title('Average Quantity')
sns.heatmap(data=second_pivot, annot=True, cmap='Greens', fmt='g');

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %%
third_cohort = cohort_df.groupby(['cohortmonth', 'cohortindex'])['totalprice'].mean().reset_index()
third_cohort
# Out:
#    cohortmonth  cohortindex  totalprice
# 0   2010-12-01        1.000      20.960
# 1   2010-12-01        2.000      25.100
# 2   2010-12-01        3.000      25.343
# 3   2010-12-01        4.000      25.232
# 4   2010-12-01        5.000      20.074
# ..         ...          ...         ...
# 86  2011-10-01        2.000      10.923
# 87  2011-10-01        3.000      13.721
# 88  2011-11-01        1.000      12.213
# 89  2011-11-01        2.000      13.178
# 90  2011-12-01        1.000      27.464
#
# [91 rows x 3 columns]

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
third_pivot = third_cohort.pivot(index='cohortmonth', columns='cohortindex', values='totalprice').round(2)
third_pivot
# Out:
# cohortindex  1.000   2.000   3.000   4.000   5.000   6.000   7.000   8.000   \
# cohortmonth
# 2010-12-01   20.960  25.100  25.340  25.230  20.070  25.660  26.680  25.580
# 2011-01-01   18.640  23.700  20.410  17.660  21.620  25.590  24.510  24.770
# 2011-02-01   17.170  17.180  19.500  18.870  16.140  15.200  21.670  21.040
# 2011-03-01   17.150  17.930  21.550  17.010  19.170  18.130  21.800  17.400
# 2011-04-01   16.450  20.210  18.790  18.440  18.880  14.370  14.770  15.600
# 2011-05-01   19.230  15.910  21.410  19.440  17.920  14.170  16.330  13.630
# 2011-06-01   16.510  14.730  19.070  19.950  15.160  16.130  12.830     NaN
# 2011-07-01   13.230  21.190  11.510  12.590  10.630  11.590     NaN     NaN
# 2011-08-01   16.200  11.940  11.570  14.360  15.630     NaN     NaN     NaN
# 2011-09-01   18.490  10.540  13.300  14.110     NaN     NaN     NaN     NaN
# 2011-10-01   13.240  10.920  13.720     NaN     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12, 8))
plt.title('Average Revenue')
sns.heatmap(data=third_pivot, annot=True, cmap='Paired')

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
