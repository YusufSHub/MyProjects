# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

#import warnings
#warnings.filterwarnings("ignore")
#warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Recognizing and Understanding Data

# %%
pwd
# Out:
# 'C:\\Users\\44778\\Desktop\\AI Summer Camp\\Proje 2'

# %%
my_data_dir = 'C:\\Users\\44778\\Desktop\\AI Summer Camp\\Proje 2\\PetImages2'

# %% [markdown]
# You may need to choose your own directory

# %%
os.listdir(my_data_dir)
# Out:
# ['test', 'train', 'val']

# %%
val_path = my_data_dir+'/val/'
train_path = my_data_dir+'/train/'
# test_path = my_data_dir+'/test/'

# %%
os.listdir(train_path)
# Out:
# ['Cat', 'Dog']

# %%
os.listdir(val_path)
# Out:
# ['Cat', 'Dog']

# %%
# os.listdir(test_path)

# %%
classes = os.listdir(train_path)
classes
# Out:
# ['Cat', 'Dog']

# %%
import pathlib

data_dir = pathlib.Path(train_path) # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')])) # created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['Cat' 'Dog']

# %%
class_names
# Out:
# array(['Cat', 'Dog'], dtype='<U3')

# %% [markdown]
# **Let's check how many images there are.**

# %%
os.listdir(train_path+'dog')
# Out:
# ['0.jpg',
#  '1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '1000.jpg',
#  '10000.jpg',
#  '10002.jpg',
#  '10003.jpg',
#  '10005.jpg',
#  '10007.jpg',
#  '10008.jpg',
#  '10009.jpg',
#  '1001.jpg',
#  '10010.jpg',
#  '10013.jpg',
#  '10014.jpg',
#  '10015.jpg',
#  '10016.jpg',
#  '10018.jpg',
#  '1002.jpg',
#  '10021.jpg',
#  '10022.jpg',
#  '10023.jpg',
#  '10024.jpg',
#  '10025.jpg',
#  '10026.jpg',
#  '10027.jpg',
#  '10029.jpg',
#  '1003.jpg',
#  '10030.jpg',
#  '10031.jpg',
#  '10033.jpg',
#  '10036.jpg',
#  '10037.jpg',
#  '10039.jpg',
#  '1004.jpg',
#  '10041.jpg',
#  '10042.jpg',
#  '10043.jpg',
#  '10045.jpg',
#  '10046.jpg',
#  '10048.jpg',
#  '1005.jpg',
#  '10050.jpg',
#  '10051.jpg',
#  '10052.jpg',
#  '10053.jpg',
#  '10054.jpg',
#  '10055.jpg',
#  '10056.jpg',
#  '10057.jpg',
#  '10058.jpg',
#  '10059.jpg',
#  '1006.jpg',
#  '10060.jpg',
#  '10062.jpg',
#  '10063.jpg',
#  '10064.jpg',
#  '10065.jpg',
#  '10066.jpg',
#  '10067.jpg',
#  '10068.jpg',
#  '10069.jpg',
#  '1007.jpg',
#  '10070.jpg',
#  '10071.jpg',
#  '10075.jpg',
#  '10076.jpg',
#  '10077.jpg',
#  '10079.jpg',
#  '1008.jpg',
#  '10080.jpg',
#  '10081.jpg',
#  '10082.jpg',
#  '10084.jpg',
#  '10085.jpg',
#  '10086.jpg',
#  '10088.jpg',
#  '10089.jpg',
#  '1009.jpg',
#  '10091.jpg',
#  '10093.jpg',
#  '10095.jpg',
#  '10098.jpg',
#  '10099.jpg',
#  '101.jpg',
#  '1010.jpg',
#  '10100.jpg',
#  '10102.jpg',
#  '10103.jpg',
#  '10104.jpg',
#  '10105.jpg',
#  '10106.jpg',
#  '10107.jpg',
#  '10108.jpg',
#  '10110.jpg',
#  '10112.jpg',
#  '10114.jpg',
#  '10117.jpg',
#  '10118.jpg',
#  '10119.jpg',
#  '1012.jpg',
#  '10121.jpg',
#  '10122.jpg',
#  '10123.jpg',
#  '10124.jpg',
#  '10125.jpg',
#  '10126.jpg',
#  '10127.jpg',
#  '10128.jpg',
#  '10129.jpg',
#  '1013.jpg',
#  '10131.jpg',
#  '10136.jpg',
#  '10137.jpg',
#  '1014.jpg',
#  '10140.jpg',
#  '10141.jpg',
#  '10142.jpg',
#  '10143.jpg',
#  '10144.jpg',
#  '10145.jpg',
#  '10147.jpg',
#  '10148.jpg',
#  '10149.jpg',
#  '1015.jpg',
#  '10150.jpg',
#  '10152.jpg',
#  '10153.jpg',
#  '10154.jpg',
#  '10155.jpg',
#  '10156.jpg',
#  '10157.jpg',
#  '10158.jpg',
#  '10159.jpg',
#  '1016.jpg',
#  '10160.jpg',
#  '10161.jpg',
#  '10162.jpg',
#  '10164.jpg',
#  '10167.jpg',
#  '10168.jpg',
#  '10169.jpg',
#  '1017.jpg',
#  '10170.jpg',
#  '10173.jpg',
#  '10175.jpg',
#  '10176.jpg',
#  '1018.jpg',
#  '10180.jpg',
#  '10181.jpg',
#  '10182.jpg',
#  '10184.jpg',
#  '10185.jpg',
#  '10186.jpg',
#  '10187.jpg',
#  '10188.jpg',
#  '10189.jpg',
#  '1019.jpg',
#  '10190.jpg',
#  '10191.jpg',
#  '10192.jpg',
#  '10193.jpg',
#  '10194.jpg',
#  '10195.jpg',
#  '10196.jpg',
#  '10197.jpg',
#  '10198.jpg',
#  '1020.jpg',
#  '10200.jpg',
#  '10202.jpg',
#  '10205.jpg',
#  '10206.jpg',
#  '10207.jpg',
#  '10208.jpg',
#  '10209.jpg',
#  '1021.jpg',
#  '10210.jpg',
#  '10211.jpg',
#  '10212.jpg',
#  '10214.jpg',
#  '10216.jpg',
#  '10217.jpg',
#  '10218.jpg',
#  '10219.jpg',
#  '1022.jpg',
#  '10220.jpg',
#  '10221.jpg',
#  '10223.jpg',
#  '10224.jpg',
#  '10225.jpg',
#  '10226.jpg',
#  '1023.jpg',
#  '10230.jpg',
#  '10231.jpg',
#  '10232.jpg',
#  '10233.jpg',
#  '10234.jpg',
#  '10237.jpg',
#  '10238.jpg',
#  '1024.jpg',
#  '10240.jpg',
#  '10244.jpg',
#  '10245.jpg',
#  '10246.jpg',
#  '10247.jpg',
#  '10248.jpg',
#  '1025.jpg',
#  '10251.jpg',
#  '10252.jpg',
#  '10253.jpg',
#  '10254.jpg',
#  '10255.jpg',
#  '10256.jpg',
#  '10257.jpg',
#  '10258.jpg',
#  '10259.jpg',
#  '1026.jpg',
#  '10260.jpg',
#  '10261.jpg',
#  '10262.jpg',
#  '10263.jpg',
#  '10264.jpg',
#  '10266.jpg',
#  '10267.jpg',
#  '10268.jpg',
#  '10269.jpg',
#  '1027.jpg',
#  '10270.jpg',
#  '10271.jpg',
#  '10272.jpg',
#  '10274.jpg',
#  '10275.jpg',
#  '10278.jpg',
#  '10279.jpg',
#  '1121.jpg',
#  '11210.jpg',
#  '11212.jpg',
#  '11213.jpg',
#  '11216.jpg',
#  '11217.jpg',
#  '11218.jpg',
#  '11219.jpg',
#  '1122.jpg',
#  '11220.jpg',
#  '11221.jpg',
#  '11222.jpg',
#  '11223.jpg',
#  '11224.jpg',
#  '11225.jpg',
#  '11226.jpg',
#  '11227.jpg',
#  '11228.jpg',
#  '1123.jpg',
#  '11230.jpg',
#  '11231.jpg',
#  '11232.jpg',
#  '11236.jpg',
#  '11237.jpg',
#  '11238.jpg',
#  '11240.jpg',
#  '11241.jpg',
#  '11242.jpg',
#  '11243.jpg',
#  '11244.jpg',
#  '11248.jpg',
#  '11250.jpg',
#  '11251.jpg',
#  '11253.jpg',
#  '11254.jpg',
#  '11256.jpg',
#  '11257.jpg',
#  '11258.jpg',
#  '11261.jpg',
#  '11263.jpg',
#  '11264.jpg',
#  ...]

# %%
len(os.listdir(train_path+'cat')), len(os.listdir(train_path+'dog'))
# Out:
# (8748, 8748)

# %%
len(os.listdir(val_path+'cat')), len(os.listdir(val_path+'dog'))
# Out:
# (2500, 2500)

# %%
# Walk through cell_images directory and list number of files
for dirpath, dirnames, filenames in os.walk(my_data_dir):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 3 directories and 0 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2'.
# There are 2 directories and 0 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\test'.
# There are 0 directories and 1251 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\test\Cat'.
# There are 0 directories and 1251 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\test\Dog'.
# There are 2 directories and 0 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\train'.
# There are 0 directories and 8748 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\train\Cat'.
# There are 0 directories and 8748 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\train\Dog'.
# There are 2 directories and 0 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\val'.
# There are 0 directories and 2500 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\val\Cat'.
# There are 0 directories and 2500 images in 'C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2\val\Dog'.

# %%
#val_dog = 2500
#val_cat = 2500
#train_dog = 8750
#train_cat = 8750
#train and valid sets are balanced

# %% [markdown]
# **Let's take an example images from both train-cat and train-dog folders to observe process**

# %%
os.listdir(train_path+'Cat')[2]
# Out:
# '10.jpg'

# %%
os.listdir(train_path+'Dog')[2]
# Out:
# '10.jpg'

# %%
path1=train_path+'Cat'+'/0.jpg'
path2=train_path+'Dog'+'/0.jpg'

# %%
cat_img=imread(path1)
dog_img=imread(path2)

# %%
plt.imshow(cat_img)

# %%
plt.imshow(dog_img)

# %%
# View an image
import random

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=train_path,
                        target_class="cat")
# Out:
# Image shape: (375, 500, 3)

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=train_path,
                        target_class="dog")
# Out:
# Image shape: (375, 500, 3)

# %%
# View a random image from the training dataset
import random
img = view_random_image(target_dir=train_path,
                        target_class=random.choice(class_names)) # get a random class name
# Out:
# Image shape: (375, 500, 3)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Defining Input Shape

# %% [markdown]
# **Let's decide on the final dimension of these images.**

# %%
cat_img.shape
# Out:
# (375, 500, 3)

# %%
dog_img.shape
# Out:
# (375, 500, 3)

# %%
image_shape = (128,128,3)

# %% [markdown]
# ## Scalling

# %% [markdown]
# **Let's check the images if they are needed to be scaled or not**

# %%
cat_img.max()
# Out:
# 255

# %%
cat_img.min()
# Out:
# 0

# %% [markdown]
# As we see above, images dont need to be scaled

# %% [markdown]
# ## Image Data Generator

# %% [markdown]
# **Image Manipulation**
#
# We can use the ImageDataGenerator to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. ImageDataGenerator does the followings.
#
# * Accepts a batch of images used for training.
# * Applies a series of random transformations to each image in the batch.
# * Replaces the original batch with randomly transformed batch.
# * Training the CNN on this randomly transformed batch.
#
# The goal of applying data augmentation is to have a more generalized model.
#
# Data augmentation is a way to try and prevent a model overfitting. If your model is overfiting (e.g. the validation loss keeps increasing), you may want to try using data augmentation.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=15, # rotate the image 15 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 10%
                               height_shift_range=0.10, # Shift the pic height by a max of 10%
                               #rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True, # Allow horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(dog_img);

# %%
plt.imshow(image_gen.random_transform(dog_img));

# %% [markdown]
# ### Taking the path to a directory & Generating batches of augmented data
#
# flow_from_directory function works with images organized in sub-directories. Your directories should include only one class of images, so one folder per class of images.

# %%
#help(image_gen.flow_from_directory)
#Takes the path to a directory & generates batches of augmented data.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 17496 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(val_path)
# Out:
# Found 5000 images belonging to 2 classes.

# %%
# image_gen.flow_from_directory(test_path)

# %%
batch_size = 32

# %%
train_image_gen = image_gen.flow_from_directory(directory=train_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='binary',
                                                shuffle=True)
# Out:
# Found 17496 images belonging to 2 classes.

# %%
val_image_gen = image_gen.flow_from_directory(directory=val_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=False)
# Out:
# Found 5000 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'Cat': 0, 'Dog': 1}

# %%
train_image_gen[0][0].shape
# Out:
# (32, 128, 128, 3)

# %%
len(train_image_gen), len(val_image_gen)
# Out:
# (547, 157)

# %%
len(train_image_gen)*batch_size, len(val_image_gen)*batch_size
# Out:
# (17504, 5024)

# %%
# Get a sample of the training data batch 
images, labels = train_image_gen.next() # get the 'next' batch of images/labels
len(images), len(labels)
# Out:
# (32, 32)

# %%
# Get a sample of the testing data batch 
images, labels = val_image_gen.next() # get the 'next' batch of images/labels
len(images), len(labels)
# Out:
# (32, 32)

# %% [markdown]
# # Modelling-1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
model1 = Sequential()

model1.add(Conv2D(filters=16, kernel_size=(3,3),input_shape=image_shape, activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Flatten())

model1.add(Dense(128))
model1.add(Activation('relu'))

model1.add(Dense(64))
model1.add(Activation('relu'))

model1.add(Dense(1))
model1.add(Activation('sigmoid'))

model1.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 126, 16)      448
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_3 (Dense)             (None, 128)               589952
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 695,713
# Trainable params: 695,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_image_gen

# %%
val_image_gen

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights = True)

# %% [markdown]
# ### Hata Ayiklamasi

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import os
from PIL import Image
folder_path = train_path
extensions = []
for fldr in os.listdir(folder_path):
    sub_folder_path = os.path.join(folder_path, fldr)
    for filee in os.listdir(sub_folder_path):
        file_path = os.path.join(sub_folder_path, filee)
        print('** Path: {}  **'.format(file_path), end="\r", flush=True)
        im = Image.open(file_path)
        rgb_im = im.convert('RGB')
        if filee.split('.')[1] not in extensions:
            extensions.append(filee.split('.')[1])
# Out:
# ** Path: C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2/train/Dog\9090.jpg  ***
# C:\Users\44778\anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:845: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# ** Path: C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2/train/Dog\9999.jpg  **

# %%
#train/Cat\666.jpg bozuk

# %%
#train/Dog\11702.jpg  ** bozuk

# %%
import os
from PIL import Image
folder_path = val_path
extensions = []
for fldr in os.listdir(folder_path):
    sub_folder_path = os.path.join(folder_path, fldr)
    for filee in os.listdir(sub_folder_path):
        file_path = os.path.join(sub_folder_path, filee)
        print('** Path: {}  **'.format(file_path), end="\r", flush=True)
        im = Image.open(file_path)
        rgb_im = im.convert('RGB')
        if filee.split('.')[1] not in extensions:
            extensions.append(filee.split('.')[1])
# Out:
# ** Path: C:\Users\44778\Desktop\AI Summer Camp\Proje 2\PetImages2/val/Dog\9995.jpg  ***

# %% [markdown]
# https://stackoverflow.com/questions/70115673/unidentifiedimageerror-cannot-identify-image-file-io-bytesio-object-at-0x0000

# %% [markdown]
# https://www.pythonfixing.com/2022/01/fixed-pilunidentifiedimageerror-cannot.html

# %%
model1.fit(train_image_gen,
          epochs=10,
          steps_per_epoch=len(train_image_gen),
          validation_data=val_image_gen,
          validation_steps=len(val_image_gen),
          callbacks=[early_stop])
# Out:
# Epoch 1/10
# 547/547 [==============================] - 200s 363ms/step - loss: 0.8835 - accuracy: 0.6089 - val_loss: 0.6186 - val_accuracy: 0.6698
# Epoch 2/10
# 547/547 [==============================] - 192s 351ms/step - loss: 0.5917 - accuracy: 0.6860 - val_loss: 0.5400 - val_accuracy: 0.7332
# Epoch 3/10
# 547/547 [==============================] - 187s 342ms/step - loss: 0.5493 - accuracy: 0.7233 - val_loss: 0.5431 - val_accuracy: 0.7260
# Epoch 4/10
# 547/547 [==============================] - 186s 340ms/step - loss: 0.5084 - accuracy: 0.7517 - val_loss: 0.5133 - val_accuracy: 0.7484
# Epoch 5/10
# 547/547 [==============================] - 186s 341ms/step - loss: 0.4692 - accuracy: 0.7783 - val_loss: 0.4288 - val_accuracy: 0.7978
# Epoch 6/10
# 547/547 [==============================] - 186s 341ms/step - loss: 0.4485 - accuracy: 0.7951 - val_loss: 0.4236 - val_accuracy: 0.8016
# Epoch 7/10
# 547/547 [==============================] - 186s 340ms/step - loss: 0.4214 - accuracy: 0.8065 - val_loss: 0.4068 - val_accuracy: 0.8116
# Epoch 8/10
# 547/547 [==============================] - 186s 339ms/step - loss: 0.4054 - accuracy: 0.8181 - val_loss: 0.3789 - val_accuracy: 0.8294
# Epoch 9/10
# 547/547 [==============================] - 186s 340ms/step - loss: 0.3822 - accuracy: 0.8276 - val_loss: 0.3879 - val_accuracy: 0.8284
# Epoch 10/10
# 547/547 [==============================] - 186s 340ms/step - loss: 0.3566 - accuracy: 0.8414 - val_loss: 0.4505 - val_accuracy: 0.8022

# %%
summary = pd.DataFrame(model1.history.history)

# %%
summary[["loss", "val_loss"]].plot();

# %%
summary[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # Modelling-3

# %%
model3 = Sequential()

model3.add(Conv2D(filters=16, kernel_size=(3,3), padding='same', input_shape=image_shape, activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Flatten())

model3.add(Dense(128))
model3.add(Activation('relu'))

model3.add(Dense(128))
model3.add(Activation('relu'))

model3.add(Dense(1))
model3.add(Activation('sigmoid'))

model3.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 128, 128, 16)      448
#
#  batch_normalization_4 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 16)      2320
#
#  batch_normalization_5 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 32)        4640
#
#  batch_normalization_6 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 32)        9248
#
#  batch_normalization_7 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 64)        18496
#
#  batch_normalization_8 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_9 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_11 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_9 (Dense)             (None, 128)               1048704
#
#  activation_9 (Activation)   (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  activation_10 (Activation)  (None, 128)               0
#
#  dense_11 (Dense)            (None, 1)                 129
#
#  activation_11 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 1,360,785
# Trainable params: 1,359,825
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights = True)

# %%
model3.fit(train_image_gen,
          epochs=5,
          steps_per_epoch=len(train_image_gen),
          validation_data=val_image_gen,
          validation_steps=len(val_image_gen),
          callbacks=[early_stop])
# Out:
# Epoch 1/5
# 547/547 [==============================] - 522s 952ms/step - loss: 0.6669 - accuracy: 0.6347 - val_loss: 0.6569 - val_accuracy: 0.6544
# Epoch 2/5
# 547/547 [==============================] - 532s 973ms/step - loss: 0.5340 - accuracy: 0.7302 - val_loss: 0.6443 - val_accuracy: 0.6314
# Epoch 3/5
# 547/547 [==============================] - 498s 911ms/step - loss: 0.4519 - accuracy: 0.7886 - val_loss: 0.4661 - val_accuracy: 0.7752
# Epoch 4/5
# 547/547 [==============================] - 607s 1s/step - loss: 0.3812 - accuracy: 0.8254 - val_loss: 0.5239 - val_accuracy: 0.7624
# Epoch 5/5
# 547/547 [==============================] - 549s 1s/step - loss: 0.3230 - accuracy: 0.8571 - val_loss: 0.4012 - val_accuracy: 0.8176

# %%
summary = pd.DataFrame(model3.history.history)

# %%
summary[["loss", "val_loss"]].plot();

# %%
summary[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # Evaluation on Test Data

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
score = model3.evaluate(val_image_gen)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 157/157 [==============================] - 53s 334ms/step - loss: 0.4029 - accuracy: 0.8174
# Test loss: 0.40286991000175476
# Test accuracy: 0.8173999786376953

# %%
pred_prob = model3.predict(val_image_gen)
pred_prob
# Out:
# 157/157 [==============================] - 46s 286ms/step
# array([[3.2838070e-04],
#        [1.5967362e-01],
#        [9.8063722e-03],
#        ...,
#        [9.6330023e-01],
#        [1.5670657e-01],
#        [5.8920914e-01]], dtype=float32)

# %%
y_pred = pred_prob > 0.5
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
y_test = val_image_gen.classes

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      2500
#            1       0.91      0.72      0.80      2500
#
#     accuracy                           0.82      5000
#    macro avg       0.84      0.82      0.82      5000
# weighted avg       0.84      0.82      0.82      5000

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2319,  181],
#        [ 710, 1790]], dtype=int64)
