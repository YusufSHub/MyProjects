# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "***Fraud Detection Project***". This is the last project of the Capstone Series.
#
# One of the challenges in this project is the absence of domain knowledge. So without knowing what the column names are, you will only be interested in their values. The other one is the class frequencies of the target variable are quite imbalanced.
#
# You will implement ***Logistic Regression, Random Forest, Neural Network*** algorithms and ***SMOTE*** technique. Also visualize performances of the models using ***Seaborn, Matplotlib*** and ***Yellowbrick*** in a variety of ways.
#
# At the end of the project, you will have the opportunity to deploy your model by ***Streamlit API***.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with model deployement (streamlit api) as well as the theory behind Logistic Regression, Random Forest, Neural Network.*

# %% [markdown]
# Bu projedeki zorluklardan biri, alan bilgisinin olmamasıdır. Yani sütun adlarının ne olduğunu bilmeden yalnızca değerleriyle ilgileneceksiniz. Diğeri ise hedef değişkenin sınıf frekanslarının oldukça dengesiz olmasıdır.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
# The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where it has **492 frauds** out of **284,807** transactions. The dataset is **highly unbalanced**, the positive class (frauds) account for 0.172% of all transactions.
#
# **Feature Information:**
#
# **Time**: This feature is contains the seconds elapsed between each transaction and the first transaction in the dataset.
#
# **Amount**:  This feature is the transaction Amount, can be used for example-dependant cost-senstive learning.
#
# **Class**: This feature is the target variable and it takes value 1 in case of fraud and 0 otherwise.
#
# ---
#
# The aim of this project is to predict whether a credit card transaction is fraudulent. Of course, this is not easy to do.
# First of all, you need to analyze and recognize your data well in order to draw your roadmap and choose the correct arguments you will use. Accordingly, you can examine the frequency distributions of variables. You can observe variable correlations and want to explore multicollinearity. You can show the distribution of the target variable's classes over other variables.
# Also, it is useful to take missing values and outliers.
#
# After these procedures, you can move on to the model building stage by doing the basic data pre-processing you are familiar with.
#
# Start with Logistic Regression and evaluate model performance. You will apply the SMOTE technique used to increase the sample for unbalanced data. Next, rebuild your Logistic Regression model with SMOTE applied data to observe its effect.
#
# Then, you will use three different algorithms in the model building phase. You have applied Logistic Regression and Random Forest in your previous projects. However, the Deep Learning Neural Network algorithm will appear for the first time.
#
# In the final step, you will deploy your model using ***Streamlit API***.
#
# **Optional**: You can Dockerize your project and deploy on cloud.

# %% [markdown]
# Veri kümeleri, Avrupalı ​​kart sahipleri tarafından Eylül 2013'te kredi kartlarıyla yapılan işlemleri içerir. Bu veri kümesi, 284,807 işlemden 492'sinin dolandırıcılık olduğu iki gün içinde gerçekleşen işlemleri sunar. Veri kümesi oldukça dengesizdir, pozitif sınıf (dolandırıcılık) tüm işlemlerin %0,172'sini oluşturur.
#
# -Özellik Bilgileri:
#
# Zaman: Bu özellik, veri setindeki her işlem ile ilk işlem arasında geçen saniyeleri içerir.
#
# Tutar: Bu özellik Tutar işlemidir, örneğin maliyete duyarlı öğrenme için kullanılabilir.
#
# Sınıf: Bu özellik hedef değişkendir ve dolandırıcılık durumunda 1, aksi halde 0 değerini alır.

# %% [markdown]
# Bu projenin amacı, bir kredi kartı işleminin hileli olup olmadığını tahmin etmektir. Tabii ki, bunu yapmak kolay değil. Öncelikle yol haritanızı çizmek ve kullanacağınız doğru argümanları seçmek için verilerinizi iyi analiz etmeniz ve tanımanız gerekiyor. Buna göre değişkenlerin frekans dağılımlarını inceleyebilirsiniz. Değişken korelasyonları gözlemleyebilir ve çoklu doğrusallığı keşfetmek isteyebilirsiniz. Hedef değişkenin sınıflarının diğer değişkenlere göre dağılımını gösterebilirsiniz. Ayrıca eksik değerlerin ve aykırı değerlerin alınmasında da fayda vardır.
#
#
# Bu işlemlerden sonra aşina olduğunuz temel veri ön işlemlerini yaparak model oluşturma aşamasına geçebilirsiniz.
#
# Lojistik Regresyon ile başlayın ve model performansını değerlendirin. Dengesiz veriler için örneği artırmak için kullanılan SMOTE tekniğini uygulayacaksınız. Ardından, etkisini gözlemlemek için SMOTE uygulanmış verilerle Lojistik Regresyon modelinizi yeniden oluşturun
#
# Ardından model oluşturma aşamasında üç farklı algoritma kullanacaksınız. Daha önceki projelerinizde Lojistik Regresyon ve Rastgele Orman uygulamışsınız. Ancak Derin Öğrenme Sinir Ağı algoritması ilk kez karşımıza çıkacak.
#
# Son adımda, modelinizi Streamlit API kullanarak dağıtacaksınız.
#
# İsteğe bağlı: Projenizi Dockerize edebilir ve bulutta dağıtabilirsiniz.

# %% [markdown]
# # makale notlari:
# Bu sorunlardan en kritik olanlardan biri de şüphesiz kartla yapılmış bir işlemin sahte olup olmadığının sorgulamasıdır. Yani “Fraud” işlemlerin tespitidir.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install patool
# import patoolib

# %%
# patoolib.extract_archive("/content/drive/MyDrive/Data/creditcard.part1.rar", 
#                           outdir="/content/drive/MyDrive/Data/Proje3/1")

# %%
# patoolib.extract_archive("/content/drive/MyDrive/Data/creditcard.part2.rar", 
#                         outdir="/content/drive/MyDrive/Data/Proje3/2")

# %%
# patoolib.extract_archive("/content/drive/MyDrive/Data/creditcard.part3.rar", 
#                         outdir="/content/drive/MyDrive/Data/Proje3/3")

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis & Data Cleaning
#
# - Import Modules, Load Data & Data Review
# - Exploratory Data Analysis
# - Data Cleaning
#
#
#
#
# #### 2. Data Preprocessing
#
# - Scaling
# - Train - Test Split
#
#
# #### 3. Model Building
#
# - Logistic Regression without SMOTE
# - Apply SMOTE
# - Logistic Regression with SMOTE
# - Random Forest Classifier with SMOTE
# - Neural Network
#
# #### 4. Model Deployement
#
# - Save and Export the Model as .pkl
# - Save and Export Variables as .pkl

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. Exploratory Data Analysis & Data Cleaning

# %%
# !pip install ipython # gorsellestirme kutuphanesi ama colabde calsmiyor uzerine gittiginde yazilar falan cikiyor dinamik bir kutuphane
# !pip install pyclustertend # Ml kutuphanesi hopkinsler falan icin 
# !pip install xlrd # verileri okumak ve Excel dosyalarından geçmiş .xls biçimindeki bilgileri biçimlendirmek için kullanılan bir kitaplıktır.
# !pip install Autoviz  # gorsellistrme toolunun kutuphanesi 
# !pip3 install termcolor
# !pip install termcolor # gorsellestirme kutuphasi ciktilari backroundlu veriyor
# !pip install pandas-profiling # Profilin toolunn kutuphanesi 
# !pip install lightgbm # bunun kitapligi, histogram tabanlı çalışan bir algoritmadır. Sürekli değere sahip olan değişkenleri kesikli(discrete bin) hale getirerek hesaplama maliyetini azaltır.
# !pip3 install catboost # boosting algoritmasinin kutuphansi
# !pip install colorama #konsol penceresindeki yazıları renklendirmeyi ve stil vermeyi sağlar.
# !pip install plotly
# !pip install pyyaml==5.4.1 #Python için tam özellikli bir YAML işleme çerçevesi. Kurulum.
# !pip install pyforest # (visulation kutuphanesi analizlerinde istatistik kullaniyor. )
# !pip install markupsafe==2.0.1 # HTML ve XML'de kullanılması güvenli olması için karakterlerden kaçan bir metin nesnesi uygular.
# Out:
# Requirement already satisfied: plotly in c:\users\44778\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\44778\anaconda3\lib\site-packages (from plotly) (8.0.1)
# WARNING: There was an error checking the latest version of pip.
# ERROR: Invalid requirement: '#'
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ### Import Modules, Load Data & Data Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import scipy.stats as stats
import pyforest
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_validate
from sklearn.metrics import plot_confusion_matrix, classification_report, confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import make_scorer, precision_score, precision_recall_curve, plot_precision_recall_curve, plot_roc_curve, roc_auc_score, roc_curve, f1_score, accuracy_score, recall_score
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif, f_regression, mutual_info_regression
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.pipeline import Pipeline
from sklearn.tree import plot_tree
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB

#importing plotly and cufflinks in offline mode
# !pip install cufflinks #  doğrudan veri çerçevelerinin grafiklerini ve çizelgelerini oluşturmak için pandalarla planlı bir şekilde bağlanır
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)

pd.set_option('display.max_rows', 100) # if you wish to see more rows rather than default, just uncomment this line.
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# !pip install colorama
import colorama
from colorama import Fore, Style  # maakes strings colored
# !pip3 install termcolor
from termcolor import colored
# Out:
# ERROR: Invalid requirement: '#'
# WARNING: There was an error checking the latest version of pip.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Requirement already satisfied: colorama in c:\users\44778\anaconda3\lib\site-packages (0.4.5)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: termcolor in c:\users\44778\anaconda3\lib\site-packages (1.1.0)
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def missing(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

def missing_values(df):
    return missing(df)[missing(df)['Missing_Number']>0]
    
def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          f"There is ", df.shape[0], " observation and ", df.shape[1], " columns in the dataset.", '\n',
          colored('-'*79, 'magenta', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n', 
          colored('-'*79, 'magenta', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('-'*79, 'magenta', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n', 
          colored('-'*79, 'magenta', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n', 
          colored('-'*79, 'magenta', attrs=['bold']), sep='')

    df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

    print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')

def first_looking_col(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()/df.shape[0]*100, 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print(df[col].value_counts(dropna = False)) 
    

def duplicate_values(df):
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored(" duplicates were dropped", attrs=['bold']),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')
    else:
        print(colored("No duplicates", attrs=['bold']),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')
        
def drop_columns(df, drop_columns):
    if drop_columns !=[]:
        df.drop(drop_columns, axis=1, inplace=True)
        print(drop_columns, 'were dropped')
    else:
        print(colored('We will now check the missing values and if necessary drop some columns!!!', attrs=['bold']),'\n',
              colored('-'*79, 'magenta', attrs=['bold']), sep='')
        
def drop_null(df, limit):
    print('Shape:', df.shape)
    for i in df.isnull().sum().index:
        if (df.isnull().sum()[i]/df.shape[0]*100)>limit:
            print(df.isnull().sum()[i], 'percent of', i ,'null and were dropped')
            df.drop(i, axis=0, inplace=True)
            print('new shape:', df.shape)
        else:
            print(df.isnull().sum()[i], '%, percentage of missing values of', i ,'less than limit', limit, '%, so we will keep it.')
    print('New shape after missing value control:', df.shape)

# %%
def matris_scorer(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

def model_scorer(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    
    scores = {"train_set": {"Accuracy" : accuracy_score(y_train, y_train_pred),
                            "Precision" : precision_score(y_train, y_train_pred),
                            "Recall" : recall_score(y_train, y_train_pred),                          
                            "f1" : f1_score(y_train, y_train_pred)},
    
              "test_set": {"Accuracy" : accuracy_score(y_test, y_pred),
                           "Precision" : precision_score(y_test, y_pred),
                           "Recall" : recall_score(y_test, y_pred),                          
                           "f1" : f1_score(y_test, y_pred)}}
    
    return pd.DataFrame(scores)   

# scorlarmizi gormek icin yaptigimiz defler

# %%
df0 = pd.read_csv("creditcard.csv")

# %%
df = df0.copy()

# %% [markdown]
# ### Data Cleaning
# Check Missing Values and Outliers

# %%
first_looking(df)
# Out:
# Shape:(284807, 31)
# There is 284807 observation and 31 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
# Empty DataFrame
# Columns: [Missing_Number, Missing_Percent]
# Index: []
# -------------------------------------------------------------------------------
# All Columns:['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
# -------------------------------------------------------------------------------
# Columns after rename:['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10', 'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount', 'class']
# -------------------------------------------------------------------------------

# %% [markdown]
# ---
# ---

# %%
duplicate_values(df)
# Out:
# 1081 duplicates were dropped
# -------------------------------------------------------------------------------

# %%
df.describe().T
# aslinda anlamlarini bilsek std ile mean arasinda ciddi farkin oldugu veriler var 
# bunlarda bize outlier oldugunu gosterir.
# Out:
#             count      mean       std      min       25%       50%        75%  \
# time   283726.000 94811.078 47481.048    0.000 54204.750 84692.500 139298.000
# v1     283726.000     0.006     1.948  -56.408    -0.916     0.020      1.316
# v2     283726.000    -0.004     1.647  -72.716    -0.600     0.064      0.800
# v3     283726.000     0.002     1.509  -48.326    -0.890     0.180      1.027
# v4     283726.000    -0.003     1.414   -5.683    -0.850    -0.022      0.740
# v5     283726.000     0.002     1.377 -113.743    -0.690    -0.053      0.612
# v6     283726.000    -0.001     1.332  -26.161    -0.769    -0.275      0.397
# v7     283726.000     0.002     1.228  -43.557    -0.553     0.041      0.570
# v8     283726.000    -0.001     1.179  -73.217    -0.209     0.022      0.326
# v9     283726.000    -0.002     1.095  -13.434    -0.644    -0.053      0.596
# v10    283726.000    -0.001     1.076  -24.588    -0.536    -0.093      0.454
# v11    283726.000     0.000     1.019   -4.797    -0.762    -0.032      0.740
# v12    283726.000    -0.001     0.995  -18.684    -0.406     0.139      0.617
# v13    283726.000     0.001     0.995   -5.792    -0.648    -0.013      0.663
# v14    283726.000     0.000     0.952  -19.214    -0.426     0.050      0.492
# v15    283726.000     0.001     0.915   -4.499    -0.581     0.049      0.650
# v16    283726.000     0.001     0.874  -14.130    -0.467     0.067      0.524
# v17    283726.000     0.000     0.843  -25.163    -0.484    -0.066      0.399
# v18    283726.000     0.002     0.837   -9.499    -0.498    -0.002      0.502
# v19    283726.000    -0.000     0.813   -7.214    -0.456     0.003      0.459
# v20    283726.000     0.000     0.770  -54.498    -0.211    -0.062      0.133
# v21    283726.000    -0.000     0.724  -34.830    -0.228    -0.029      0.186
# v22    283726.000    -0.000     0.725  -10.933    -0.543     0.007      0.528
# v23    283726.000     0.000     0.624  -44.808    -0.162    -0.011      0.148
# v24    283726.000     0.000     0.606   -2.837    -0.354     0.041      0.440
# v25    283726.000    -0.000     0.521  -10.295    -0.317     0.016      0.351
# v26    283726.000     0.000     0.482   -2.605    -0.327    -0.052      0.240
# v27    283726.000     0.002     0.396  -22.566    -0.071     0.001      0.091
# v28    283726.000     0.001     0.328  -15.430    -0.053     0.011      0.078
# amount 283726.000    88.473   250.399    0.000     5.600    22.000     77.510
# class  283726.000     0.002     0.041    0.000     0.000     0.000      0.000
#
#               max
# time   172792.000
# v1          2.455
# v2         22.058
# v3          9.383
# v4         16.875
# v5         34.802
# v6         73.302
# v7        120.589
# v8         20.007
# v9         15.595
# v10        23.745
# v11        12.019
# v12         7.848
# v13         7.127
# v14        10.527
# v15         8.878
# v16        17.315
# v17         9.254
# v18         5.041
# v19         5.592
# v20        39.421
# v21        27.203
# v22        10.503
# v23        22.528
# v24         4.585
# v25         7.520
# v26         3.517
# v27        31.612
# v28        33.848
# amount  25691.160
# class       1.000

# %%
first_looking_col("amount")
# Out:
# column name    :  amount
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  32767
# 1.000      13566
# 1.980       6044
# 0.890       4871
# 9.990       4738
# 15.000      3280
#            ...
# 526.600        1
# 248.160        1
# 492.650        1
# 811.500        1
# 95.630         1
# Name: amount, Length: 32767, dtype: int64

# %%
first_looking_col("time")
# Out:
# column name    :  time
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  124592
# 3767.000      21
# 3770.000      20
# 19912.000     19
# 3750.000      19
# 73885.000     17
#               ..
# 127732.000     1
# 62217.000      1
# 127739.000     1
# 127741.000     1
# 172792.000     1
# Name: time, Length: 124592, dtype: int64

# %%
first_looking_col("class")
# Out:
# column name    :  class
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# 0    283253
# 1       473
# Name: class, dtype: int64

# %% [markdown]
# - negatif degerler var
# - data imbalance
# - amonutun islem hacmi (amount	88.414 normal olan iken ,	123.872 dolandirilan meanleri.)

# %%
df.groupby("class")[df.columns].mean().T
# Out:
# class          0         1
# time   94835.058 80450.514
# v1         0.013    -4.498
# v2        -0.010     3.406
# v3         0.013    -6.730
# v4        -0.010     4.473
# v5         0.007    -2.957
# v6         0.001    -1.433
# v7         0.010    -5.176
# v8        -0.002     0.953
# v9         0.003    -2.522
# v10        0.008    -5.453
# v11       -0.006     3.716
# v12        0.009    -6.103
# v13        0.001    -0.094
# v14        0.012    -6.836
# v15        0.001    -0.073
# v16        0.008    -4.001
# v17        0.011    -6.463
# v18        0.005    -2.157
# v19       -0.001     0.669
# v20       -0.000     0.405
# v21       -0.001     0.467
# v22       -0.000     0.087
# v23        0.000    -0.096
# v24        0.000    -0.107
# v25       -0.000     0.041
# v26        0.000     0.050
# v27        0.001     0.214
# v28        0.000     0.078
# amount    88.414   123.872
# class      0.000     1.000

# %%
df_fraud = df[df["class"]==1] # datamizda target columumuz da binary degerler var. 
df_non_fraud = df[df["class"]==0] # chort analizi 0 ve 1 lerin davranislarina bakiyoruz.

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))

sns.distplot(df_fraud.amount, ax=ax[0])
sns.distplot(df_non_fraud.amount, ax=ax[1], color="purple")
ax[0].set_title("Fraud")
ax[1].set_title("Non Fraud");
# Amounta gore chortlarimizin dagilimi
# hight skewed dagilim var.

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))

ax[0].set_title("Fraud")
ax[1].set_title("Non Fraud");

sns.distplot(df_fraud.time, ax= ax[0], color="purple")
sns.distplot(df_non_fraud.time, ax= ax[1]);
# zamana gore yine chortlarimizn davranisi
# data saniyeli oldugu icin 10000. saniye de pasif oldugu donem olabilir
# insalarin kartlari ile daha az hasir nesir oldugu donem pandemi ne olabilir

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))

ax[0].set_title("Fraud")
ax[1].set_title("Non Fraud");

sns.distplot(df_fraud.v28, ax= ax[0], color="purple")
sns.distplot(df_non_fraud.v28, ax= ax[1]);
# herhangoi bir columa gore bir bakis atmisiz

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))

ax[0].set_title("Fraud")
ax[1].set_title("Non Fraud");

sns.distplot(df_fraud.v3, ax= ax[0], color="purple")
sns.distplot(df_non_fraud.v3, ax= ax[1]);

# %%
df_fraud.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# dolandiranlanlarin fraud lu describelari
# Out:
# <style type="text/css">
# #T_3d844_row0_col0, #T_3d844_row1_col0, #T_3d844_row1_col1, #T_3d844_row1_col2, #T_3d844_row1_col5, #T_3d844_row2_col0, #T_3d844_row2_col1, #T_3d844_row2_col2, #T_3d844_row2_col5, #T_3d844_row3_col0, #T_3d844_row3_col1, #T_3d844_row3_col2, #T_3d844_row3_col5, #T_3d844_row4_col0, #T_3d844_row4_col1, #T_3d844_row4_col2, #T_3d844_row4_col5, #T_3d844_row5_col0, #T_3d844_row5_col1, #T_3d844_row5_col2, #T_3d844_row5_col5, #T_3d844_row6_col0, #T_3d844_row6_col1, #T_3d844_row6_col2, #T_3d844_row6_col5, #T_3d844_row7_col0, #T_3d844_row7_col1, #T_3d844_row7_col2, #T_3d844_row7_col5, #T_3d844_row8_col0, #T_3d844_row8_col1, #T_3d844_row8_col2, #T_3d844_row8_col5, #T_3d844_row9_col0, #T_3d844_row9_col1, #T_3d844_row9_col2, #T_3d844_row9_col5, #T_3d844_row10_col0, #T_3d844_row10_col1, #T_3d844_row10_col2, #T_3d844_row10_col5, #T_3d844_row11_col0, #T_3d844_row11_col1, #T_3d844_row11_col2, #T_3d844_row11_col5, #T_3d844_row12_col0, #T_3d844_row12_col1, #T_3d844_row12_col2, #T_3d844_row12_col5, #T_3d844_row13_col0, #T_3d844_row13_col1, #T_3d844_row13_col2, #T_3d844_row13_col5, #T_3d844_row14_col0, #T_3d844_row14_col1, #T_3d844_row14_col2, #T_3d844_row14_col5, #T_3d844_row15_col0, #T_3d844_row15_col1, #T_3d844_row15_col2, #T_3d844_row15_col5, #T_3d844_row16_col0, #T_3d844_row16_col1, #T_3d844_row16_col2, #T_3d844_row16_col5, #T_3d844_row17_col0, #T_3d844_row17_col1, #T_3d844_row17_col2, #T_3d844_row17_col5, #T_3d844_row18_col0, #T_3d844_row18_col1, #T_3d844_row18_col2, #T_3d844_row18_col5, #T_3d844_row19_col0, #T_3d844_row19_col1, #T_3d844_row19_col2, #T_3d844_row19_col5, #T_3d844_row20_col0, #T_3d844_row20_col1, #T_3d844_row20_col2, #T_3d844_row20_col5, #T_3d844_row21_col0, #T_3d844_row21_col1, #T_3d844_row21_col2, #T_3d844_row21_col5, #T_3d844_row22_col0, #T_3d844_row22_col1, #T_3d844_row22_col2, #T_3d844_row22_col5, #T_3d844_row23_col0, #T_3d844_row23_col1, #T_3d844_row23_col2, #T_3d844_row23_col5, #T_3d844_row24_col0, #T_3d844_row24_col1, #T_3d844_row24_col2, #T_3d844_row24_col5, #T_3d844_row25_col0, #T_3d844_row25_col1, #T_3d844_row25_col2, #T_3d844_row25_col5, #T_3d844_row26_col0, #T_3d844_row26_col1, #T_3d844_row26_col2, #T_3d844_row26_col5, #T_3d844_row27_col0, #T_3d844_row27_col1, #T_3d844_row27_col2, #T_3d844_row27_col5, #T_3d844_row28_col0, #T_3d844_row28_col1, #T_3d844_row28_col2, #T_3d844_row28_col5, #T_3d844_row29_col0, #T_3d844_row29_col1, #T_3d844_row29_col5, #T_3d844_row30_col0, #T_3d844_row30_col1, #T_3d844_row30_col2, #T_3d844_row30_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_3d844_row0_col1, #T_3d844_row0_col2, #T_3d844_row0_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_3d844_row29_col2 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# </style>
# <table id="T_3d844">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d844_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_3d844_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3d844_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_3d844_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_3d844_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_3d844_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_3d844_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_3d844_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d844_level0_row0" class="row_heading level0 row0" >time</th>
#       <td id="T_3d844_row0_col0" class="data row0 col0" >473.000000</td>
#       <td id="T_3d844_row0_col1" class="data row0 col1" >80450.513742</td>
#       <td id="T_3d844_row0_col2" class="data row0 col2" >48636.179973</td>
#       <td id="T_3d844_row0_col3" class="data row0 col3" >406.000000</td>
#       <td id="T_3d844_row0_col4" class="data row0 col4" >41203.000000</td>
#       <td id="T_3d844_row0_col5" class="data row0 col5" >73408.000000</td>
#       <td id="T_3d844_row0_col6" class="data row0 col6" >129095.000000</td>
#       <td id="T_3d844_row0_col7" class="data row0 col7" >170348.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d844_level0_row1" class="row_heading level0 row1" >v1</th>
#       <td id="T_3d844_row1_col0" class="data row1 col0" >473.000000</td>
#       <td id="T_3d844_row1_col1" class="data row1 col1" >-4.498280</td>
#       <td id="T_3d844_row1_col2" class="data row1 col2" >6.593145</td>
#       <td id="T_3d844_row1_col3" class="data row1 col3" >-30.552380</td>
#       <td id="T_3d844_row1_col4" class="data row1 col4" >-5.603690</td>
#       <td id="T_3d844_row1_col5" class="data row1 col5" >-2.271755</td>
#       <td id="T_3d844_row1_col6" class="data row1 col6" >-0.361428</td>
#       <td id="T_3d844_row1_col7" class="data row1 col7" >2.132386</td>
#     </tr>
#     <tr>
#       <th id="T_3d844_level0_row2" class="row_heading level0 row2" >v2</th>
#       <td id="T_3d844_row2_col0" class="data row2 col0" >473.000000</td>
#       <td id="T_3d844_row2_col1" class="data row2 col1" >3.405965</td>
#       <td id="T_3d844_row2_col2" class="data row2 col2" >4.122500</td>
#       <td id="T_3d844_row2_col3" class="data row2 col3" >-8.402154</td>
#       <td id="T_3d844_row2_col4" class="data row2 col4" >1.145381</td>
#       <td id="T_3d844_row2_col5" class="data row2 col5" >2.617105</td>
#       <td id="T_3d844_row2_col6" class="data row2 col6" >4.571743</td>
#       <td id="T_3d844_row2_col7" class="data row2 col7" >22.057729</td>
#     </tr>
#     <tr>
#       <th id="T_3d844_level0_row3" class="row_heading level0 row3" >v3</th>
#       <td id="T_3d844_row3_col0" class="data row3 col0" >473.000000</td>
#       <td id="T_3d844_row3_col1" class="data row3 col1" >-6.729599</td>
#       <td id="T_3d844_row3_col2" class="data row3 col2" >6.909647</td>
#       <td id="T_3d844_row3_col3" class="data row3 col3" >-31.103685</td>
#       <td id="T_3d844_row3_col4" class="data row3 col4" >-7.926507</td>
#       <td id="T_3d844_row3_col5" class="data row3 col5" >-4.875397</td>
#       <td id="T_3d844_row3_col6" class="data row3 col6" >-2.171454</td>
#       <td id="T_3d844_row3_col7" class="data row3 col7" >2.250210</td>
#     </tr>
#     <tr>
#       <th id="T_3d844_level0_row4" class="row_heading level0 row4" >v4</th>
#       <td id="T_3d844_row4_col0" class="data row4 col0" >473.000000</td>
#       <td id="T_3d844_row4_col1" class="data row4 col1" >4.472591</td>
#       <td id="T_3d844_row4_col2" class="data row4 col2" >2.871523</td>
#       <td id="T_3d844_row4_col3" class="data row4 col3" >-1.313275</td>
#       <td id="T_3d844_row4_col4" class="data row4 col4" >2.288644</td>
#       <td id="T_3d844_row4_col5" class="data row4 col5" >4.100098</td>
#       <td id="T_3d844_row4_col6" class="data row4 col6" >6.290918</td>
#       <td id="T_3d844_row4_col7" class="data row4 col7" >12.114672</td>
#     </tr>
#     <tr>
#       <th id="T_3d844_level0_row5" class="row_heading level0 row5" >v5</th>
#       <td id="T_3d844_row5_col0" class="data row5 col0" >473.000000</td>
#       <td id="T_3d844_row5_col1" class="data row5 col1" >-2.957197</td>
#       <td id="T_3d844_row5_col2" class="data row5 col2" >5.278831</td>
#       <td id="T_3d844_row5_col3" class="data row5 col3" >-22.105532</td>
#       <td id="T_3d844_row5_col4" class="data row5 col4" >-4.278983</td>
#       <td id="T_3d844_row5_col5" class="data row5 col5" >-1.372245</td>
#       <td id="T_3d844_row5_col6" class="data row5 col6" >0.260821</td>
#       <td id="T_3d844_row5_col7" class="data row5 col7" >11.095089</td>
#     </tr>
#     <tr>
#       <th id="T_3d844_level0_row6" class="row_heading level0 row6" >v6</th>
#       <td id="T_3d844_row6_col0" class="data row6 col0" >473.000000</td>
#       <td id="T_3d844_row6_col1" class="data row6 col1" >-1.432518</td>
#       <td id="T_3d844_row6_col2" class="data row6 col2" >1.715347</td>
#       <td id="T_3d844_row6_col3" class="data row6 col3" >-6.406267</td>
#       <td id="T_3d844_row6_col4" class="data row6 col4" >-2.450444</td>
#       <td id="T_3d844_row6_col5"

# %%
df_non_fraud.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_99f4a_row0_col0, #T_99f4a_row1_col0, #T_99f4a_row1_col1, #T_99f4a_row1_col2, #T_99f4a_row1_col5, #T_99f4a_row2_col0, #T_99f4a_row2_col1, #T_99f4a_row2_col2, #T_99f4a_row2_col5, #T_99f4a_row3_col0, #T_99f4a_row3_col1, #T_99f4a_row3_col2, #T_99f4a_row3_col5, #T_99f4a_row4_col0, #T_99f4a_row4_col1, #T_99f4a_row4_col2, #T_99f4a_row4_col5, #T_99f4a_row5_col0, #T_99f4a_row5_col1, #T_99f4a_row5_col2, #T_99f4a_row5_col5, #T_99f4a_row6_col0, #T_99f4a_row6_col1, #T_99f4a_row6_col2, #T_99f4a_row6_col5, #T_99f4a_row7_col0, #T_99f4a_row7_col1, #T_99f4a_row7_col2, #T_99f4a_row7_col5, #T_99f4a_row8_col0, #T_99f4a_row8_col1, #T_99f4a_row8_col2, #T_99f4a_row8_col5, #T_99f4a_row9_col0, #T_99f4a_row9_col1, #T_99f4a_row9_col2, #T_99f4a_row9_col5, #T_99f4a_row10_col0, #T_99f4a_row10_col1, #T_99f4a_row10_col2, #T_99f4a_row10_col5, #T_99f4a_row11_col0, #T_99f4a_row11_col1, #T_99f4a_row11_col2, #T_99f4a_row11_col5, #T_99f4a_row12_col0, #T_99f4a_row12_col1, #T_99f4a_row12_col2, #T_99f4a_row12_col5, #T_99f4a_row13_col0, #T_99f4a_row13_col1, #T_99f4a_row13_col2, #T_99f4a_row13_col5, #T_99f4a_row14_col0, #T_99f4a_row14_col1, #T_99f4a_row14_col2, #T_99f4a_row14_col5, #T_99f4a_row15_col0, #T_99f4a_row15_col1, #T_99f4a_row15_col2, #T_99f4a_row15_col5, #T_99f4a_row16_col0, #T_99f4a_row16_col1, #T_99f4a_row16_col2, #T_99f4a_row16_col5, #T_99f4a_row17_col0, #T_99f4a_row17_col1, #T_99f4a_row17_col2, #T_99f4a_row17_col5, #T_99f4a_row18_col0, #T_99f4a_row18_col1, #T_99f4a_row18_col2, #T_99f4a_row18_col5, #T_99f4a_row19_col0, #T_99f4a_row19_col1, #T_99f4a_row19_col2, #T_99f4a_row19_col5, #T_99f4a_row20_col0, #T_99f4a_row20_col1, #T_99f4a_row20_col2, #T_99f4a_row20_col5, #T_99f4a_row21_col0, #T_99f4a_row21_col1, #T_99f4a_row21_col2, #T_99f4a_row21_col5, #T_99f4a_row22_col0, #T_99f4a_row22_col1, #T_99f4a_row22_col2, #T_99f4a_row22_col5, #T_99f4a_row23_col0, #T_99f4a_row23_col1, #T_99f4a_row23_col2, #T_99f4a_row23_col5, #T_99f4a_row24_col0, #T_99f4a_row24_col1, #T_99f4a_row24_col2, #T_99f4a_row24_col5, #T_99f4a_row25_col0, #T_99f4a_row25_col1, #T_99f4a_row25_col2, #T_99f4a_row25_col5, #T_99f4a_row26_col0, #T_99f4a_row26_col1, #T_99f4a_row26_col2, #T_99f4a_row26_col5, #T_99f4a_row27_col0, #T_99f4a_row27_col1, #T_99f4a_row27_col2, #T_99f4a_row27_col5, #T_99f4a_row28_col0, #T_99f4a_row28_col1, #T_99f4a_row28_col2, #T_99f4a_row28_col5, #T_99f4a_row29_col0, #T_99f4a_row29_col1, #T_99f4a_row29_col5, #T_99f4a_row30_col0, #T_99f4a_row30_col1, #T_99f4a_row30_col2, #T_99f4a_row30_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_99f4a_row0_col1, #T_99f4a_row0_col2, #T_99f4a_row0_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_99f4a_row29_col2 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# </style>
# <table id="T_99f4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99f4a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_99f4a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_99f4a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_99f4a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_99f4a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_99f4a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_99f4a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_99f4a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f4a_level0_row0" class="row_heading level0 row0" >time</th>
#       <td id="T_99f4a_row0_col0" class="data row0 col0" >283253.000000</td>
#       <td id="T_99f4a_row0_col1" class="data row0 col1" >94835.058093</td>
#       <td id="T_99f4a_row0_col2" class="data row0 col2" >47475.550607</td>
#       <td id="T_99f4a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_99f4a_row0_col4" class="data row0 col4" >54233.000000</td>
#       <td id="T_99f4a_row0_col5" class="data row0 col5" >84711.000000</td>
#       <td id="T_99f4a_row0_col6" class="data row0 col6" >139308.000000</td>
#       <td id="T_99f4a_row0_col7" class="data row0 col7" >172792.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99f4a_level0_row1" class="row_heading level0 row1" >v1</th>
#       <td id="T_99f4a_row1_col0" class="data row1 col0" >283253.000000</td>
#       <td id="T_99f4a_row1_col1" class="data row1 col1" >0.013439</td>
#       <td id="T_99f4a_row1_col2" class="data row1 col2" >1.922179</td>
#       <td id="T_99f4a_row1_col3" class="data row1 col3" >-56.407510</td>
#       <td id="T_99f4a_row1_col4" class="data row1 col4" >-0.913431</td>
#       <td id="T_99f4a_row1_col5" class="data row1 col5" >0.022562</td>
#       <td id="T_99f4a_row1_col6" class="data row1 col6" >1.316788</td>
#       <td id="T_99f4a_row1_col7" class="data row1 col7" >2.454930</td>
#     </tr>
#     <tr>
#       <th id="T_99f4a_level0_row2" class="row_heading level0 row2" >v2</th>
#       <td id="T_99f4a_row2_col0" class="data row2 col0" >283253.000000</td>
#       <td id="T_99f4a_row2_col1" class="data row2 col1" >-0.009829</td>
#       <td id="T_99f4a_row2_col2" class="data row2 col2" >1.633520</td>
#       <td id="T_99f4a_row2_col3" class="data row2 col3" >-72.715728</td>
#       <td id="T_99f4a_row2_col4" class="data row2 col4" >-0.601398</td>
#       <td id="T_99f4a_row2_col5" class="data row2 col5" >0.062561</td>
#       <td id="T_99f4a_row2_col6" class="data row2 col6" >0.797012</td>
#       <td id="T_99f4a_row2_col7" class="data row2 col7" >18.902453</td>
#     </tr>
#     <tr>
#       <th id="T_99f4a_level0_row3" class="row_heading level0 row3" >v3</th>
#       <td id="T_99f4a_row3_col0" class="data row3 col0" >283253.000000</td>
#       <td id="T_99f4a_row3_col1" class="data row3 col1" >0.012853</td>
#       <td id="T_99f4a_row3_col2" class="data row3 col2" >1.457593</td>
#       <td id="T_99f4a_row3_col3" class="data row3 col3" >-48.325589</td>
#       <td id="T_99f4a_row3_col4" class="data row3 col4" >-0.883966</td>
#       <td id="T_99f4a_row3_col5" class="data row3 col5" >0.182247</td>
#       <td id="T_99f4a_row3_col6" class="data row3 col6" >1.028261</td>
#       <td id="T_99f4a_row3_col7" class="data row3 col7" >9.382558</td>
#     </tr>
#     <tr>
#       <th id="T_99f4a_level0_row4" class="row_heading level0 row4" >v4</th>
#       <td id="T_99f4a_row4_col0" class="data row4 col0" >283253.000000</td>
#       <td id="T_99f4a_row4_col1" class="data row4 col1" >-0.010440</td>
#       <td id="T_99f4a_row4_col2" class="data row4 col2" >1.398575</td>
#       <td id="T_99f4a_row4_col3" class="data row4 col3" >-5.683171</td>
#       <td id="T_99f4a_row4_col4" class="data row4 col4" >-0.851605</td>
#       <td id="T_99f4a_row4_col5" class="data row4 col5" >-0.024500</td>
#       <td id="T_99f4a_row4_col6" class="data row4 col6" >0.734231</td>
#       <td id="T_99f4a_row4_col7" class="data row4 col7" >16.875344</td>
#     </tr>
#     <tr>
#       <th id="T_99f4a_level0_row5" class="row_heading level0 row5" >v5</th>
#       <td id="T_99f4a_row5_col0" class="data row5 col0" >283253.000000</td>
#       <td id="T_99f4a_row5_col1" class="data row5 col1" >0.006769</td>
#       <td id="T_99f4a_row5_col2" class="data row5 col2" >1.355816</td>
#       <td id="T_99f4a_row5_col3" class="data row5 col3" >-113.743307</td>
#       <td id="T_99f4a_row5_col4" class="data row5 col4" >-0.687888</td>
#       <td id="T_99f4a_row5_col5" class="data row5 col5" >-0.052807</td>
#       <td id="T_99f4a_row5_col6" class="data row5 col6" >0.612442</td>
#       <td id="T_99f4a_row5_col7" class="data row5 col7" >34.801666</td>
#     </tr>
#     <tr>
#       <th id="T_99f4a_level0_row6" class="row_heading level0 row6" >v6</th>
#       <td id="T_99f4a_row6_col0" class="data row6 col0" >283253.000000</td>
#       <td id="T_99f4a_row6_col1" class="data row6 col1" >0.001251</td>
#       <td id="T_99f4a_row6_col2" class="data row6 col2" >1.329914</td>
#       <td id="T_99f4a_row6_col3" class="data row6 col3" >-26.160506</td>
#       <td id="T_99f4a_row6_col4" class="data row6 col4" >-0.767543</td>
#       <td id=

# %%
colors = ['tab:purple', 'plum']
df["class"].value_counts().plot(kind="pie", autopct='%1.1f%%', figsize=(10,10), colors= colors, fontsize=15);
# imbalance data : banka datasinin imbalance olmasi beklenir
# data cok dengesiz
# onemli olan 1 leri yakalamak
# hangi algorutmaya koyarsak koyalim zaten 0 lari yakalar.
# dolayisiyla recall burda onemlidir.

# %%
#import plotly.io as pio
# pio.renderers.default = "colab"

# %%
#for i in df:
  #  df[i].iplot(kind="box", title=i, boxpoints="all", color='purple')

# %%
import matplotlib.colors as mcolors
colors ="brown"
def draw_histograms(dataframe, features, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=20,ax=ax,facecolor=colors)
        ax.set_title(feature+" Histogram",color=colors)
        ax.set_yscale('log')
    fig.tight_layout() 
    plt.savefig('Histograms.png')
    plt.show()
draw_histograms(df,df.columns,8,4)

# %%
# fig, ax = plt.subplots(10,3, figsize=(16,30))
# color="rocket"
# sns.scatterplot(df.v1, df.amount, hue=df["class"], ax=ax[0,0],palette=color)
# sns.scatterplot(df.v2, df.amount, hue=df["class"], ax=ax[0,1],palette=color)
# sns.scatterplot(df.v3, df.amount, hue=df["class"], ax=ax[0,2],palette=color)
# sns.scatterplot(df.v4, df.amount, hue=df["class"], ax=ax[1,0],palette=color)
# sns.scatterplot(df.v5, df.amount, hue=df["class"], ax=ax[1,1],palette=color)
# sns.scatterplot(df.v6, df.amount, hue=df["class"], ax=ax[1,2],palette=color)
# sns.scatterplot(df.v7, df.amount, hue=df["class"], ax=ax[2,0],palette=color)
# sns.scatterplot(df.v8, df.amount, hue=df["class"], ax=ax[2,1],palette=color)
# sns.scatterplot(df.v9, df.amount, hue=df["class"], ax=ax[2,2],palette=color)
# sns.scatterplot(df.v10, df.amount, hue=df["class"], ax=ax[3,0],palette=color)
# sns.scatterplot(df.v11, df.amount, hue=df["class"], ax=ax[3,1],palette=color)
# sns.scatterplot(df.v12, df.amount, hue=df["class"], ax=ax[3,2],palette=color)
# sns.scatterplot(df.v13, df.amount, hue=df["class"], ax=ax[4,0],palette=color)
# sns.scatterplot(df.v14, df.amount, hue=df["class"], ax=ax[4,1],palette=color)
# sns.scatterplot(df.v15, df.amount, hue=df["class"], ax=ax[4,2],palette=color)
# sns.scatterplot(df.v16, df.amount, hue=df["class"], ax=ax[5,0],palette=color)
# sns.scatterplot(df.v17, df.amount, hue=df["class"], ax=ax[5,1],palette=color)
# sns.scatterplot(df.v18, df.amount, hue=df["class"], ax=ax[5,2],palette=color)
# sns.scatterplot(df.v19, df.amount, hue=df["class"], ax=ax[6,0],palette=color)
# sns.scatterplot(df.v20, df.amount, hue=df["class"], ax=ax[6,1],palette=color)
# sns.scatterplot(df.v21, df.amount, hue=df["class"], ax=ax[6,2],palette=color)
# sns.scatterplot(df.v22, df.amount, hue=df["class"], ax=ax[7,0],palette=color)
# sns.scatterplot(df.v23, df.amount, hue=df["class"], ax=ax[7,1],palette=color)
# sns.scatterplot(df.v24, df.amount, hue=df["class"], ax=ax[7,2],palette=color)
# sns.scatterplot(df.v25, df.amount, hue=df["class"], ax=ax[8,0],palette=color)
# sns.scatterplot(df.v26, df.amount, hue=df["class"], ax=ax[8,1],palette=color)
# sns.scatterplot(df.v27, df.amount, hue=df["class"], ax=ax[8,2],palette=color)
# sns.scatterplot(df.v28, df.amount, hue=df["class"], ax=ax[9,0],palette=color)
# sns.scatterplot(df.time, df.amount, hue=df["class"], ax=ax[9,1],palette=color);
# Out:
# Error in callback <function flush_figures at 0x0000018AFD31BF70> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~\anaconda3\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~\anaconda3\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\collections.py:991, in _CollectionWithSizes.draw(self, renderer)
#     988 @artist.allow_rasterization
#     989 def draw(self, renderer):
#     990     self.set_sizes(self._sizes, self.figure.dpi)
# --> 991     super().draw(renderer)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\collections.py:426, in Collection.draw(self, renderer)
#     422     renderer.draw_markers(
#     423         gc, paths[0], combined_transform.frozen(),
#     424         mpath.Path(offsets), transOffset, tuple(facecolors[0]))
#     425 else:
# --> 426     renderer.draw_path_collection(
#     427         gc, transform.frozen(), paths,
#     428         self.get_transforms(), offsets, transOffset,
#     429         self.get_facecolor(), self.get_edgecolor(),
#     430         self._linewidths, self._linestyles,
#     431         self._antialiaseds, self._urls,
#     432         self._offset_position)
#     434 gc.restore()
#     435 renderer.close_group(self.__class__.__name__)
#
# File ~\anaconda3\lib\site-packages\matplotlib\path.py:200, in Path.vertices(self)
#     192     self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     193     self._should_simplify = (
#     194         self._simplify_threshold > 0 and
#     195         mpl.rcParams['path.simplify'] and
#     196         len(self._vertices) >= 128 and
#     197         (self._codes is None or np.all(self._codes <= Path.LINETO))
#     198     )
# --> 200 @property
#     201 def vertices(self):
#     202     """
#     203     The list of vertices in the `Path` as an Nx2 numpy array.
#     204     """
#     205     return self._vertices
#
# KeyboardInterrupt:

# %%
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Fraudulent transactions have a distribution more even than valid transactions - are equaly distributed in time, including the low real transaction times, during night in Europe timezone.

# %%
class_0 = df_non_fraud["time"]
class_1 =df_fraud["time"]

hist_data = [class_0, class_1]
group_labels = ['Not Fraud', 'Fraud']

fig = ff.create_distplot(hist_data, group_labels, show_hist=False, show_rug=False)
fig['layout'].update(title='Credit Card Transactions Time Density Plot', xaxis=dict(title='Time [s]'))
iplot(fig, filename='dist_only')
# Out:
# <div>                            <div id="684e5383-be63-4b9f-b18e-892119a10867" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("684e5383-be63-4b9f-b18e-892119a10867")) {                    Plotly.newPlot(                        "684e5383-be63-4b9f-b18e-892119a10867",                        [{"legendgroup":"Not Fraud","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"Not Fraud","showlegend":true,"x":[0.0,345.584,691.168,1036.752,1382.336,1727.92,2073.504,2419.088,2764.672,3110.256,3455.84,3801.424,4147.008,4492.592,4838.176,5183.76,5529.344,5874.928,6220.512,6566.096,6911.68,7257.264,7602.848,7948.432,8294.016,8639.6,8985.184,9330.768,9676.352,10021.936,10367.52,10713.104,11058.688,11404.272,11749.856,12095.44,12441.024,12786.608,13132.192,13477.776,13823.36,14168.944,14514.528,14860.112,15205.696,15551.28,15896.864,16242.448,16588.032,16933.616,17279.2,17624.784,17970.368,18315.952,18661.536,19007.12,19352.704,19698.288,20043.872,20389.456,20735.04,21080.624,21426.208,21771.792,22117.376,22462.96,22808.544,23154.128,23499.712,23845.296,24190.88,24536.464,24882.048,25227.632,25573.216,25918.8,26264.384,26609.968,26955.552,27301.136,27646.72,27992.304,28337.888,28683.472,29029.056,29374.64,29720.224,30065.808,30411.392,30756.976,31102.56,31448.144,31793.728,32139.312,32484.896,32830.48,33176.064,33521.648,33867.232,34212.816,34558.4,34903.984,35249.568,35595.152,35940.736,36286.32,36631.904,36977.488,37323.072,37668.656,38014.24,38359.824,38705.408,39050.992,39396.576,39742.16,40087.744,40433.328,40778.912,41124.496,41470.08,41815.664,42161.248,42506.832,42852.416,43198.0,43543.584,43889.168,44234.752,44580.336,44925.92,45271.504,45617.088,45962.672,46308.256,46653.84,46999.424,47345.008,47690.592,48036.176,48381.76,48727.344,49072.928,49418.512,49764.096,50109.68,50455.264,50800.848,51146.432,51492.016,51837.6,52183.184,52528.768,52874.352,53219.936,53565.52,53911.104,54256.688,54602.272,54947.856,55293.44,55639.024,55984.608,56330.192,56675.776,57021.36,57366.944,57712.528,58058.112,58403.696,58749.28,59094.864,59440.448,59786.032,60131.616,60477.2,60822.784,61168.368,61513.952,61859.536,62205.12,62550.704,62896.288,63241.872,63587.456,63933.04,64278.624,64624.208,64969.792,65315.376,65660.96,66006.544,66352.128,66697.712,67043.296,67388.88,67734.464,68080.048,68425.632,68771.216,69116.8,69462.384,69807.968,70153.552,70499.136,70844.72,71190.304,71535.888,71881.472,72227.056,72572.64,72918.224,73263.808,73609.392,73954.976,74300.56,74646.144,74991.728,75337.312,75682.896,76028.48,76374.064,76719.648,77065.232,77410.816,77756.4,78101.984,78447.568,78793.152,79138.736,79484.32,79829.904,80175.488,80521.072,80866.656,81212.24,81557.824,81903.408,82248.992,82594.576,82940.16,83285.744,83631.328,83976.912,84322.496,84668.08,85013.664,85359.248,85704.832,86050.416,86396.0,86741.584,87087.168,87432.752,87778.336,88123.92,88469.504,88815.088,89160.672,89506.256,89851.84,90197.424,90543.008,90888.592,91234.176,91579.76,91925.344,92270.928,92616.512,92962.096,93307.68,93653.264,93998.848,94344.432,94690.016,95035.6,95381.184,95726.768,96072.352,96417.936,96763.52,97109.104,97454.688,97800.272,98145.856,98491.44,98837.024,99182.608,99528.192,99873.776,100219.36,100564.944,100910.528,101256.112,101601.696,101947.28,102292.864,102638.448,102984.032,103329.616,103675.2,104020.784,104366.368,104711.952,105057.536,105403.12,105748.704,106094.288,106439.872,106785.456,107131.04,107476.624,107822.208,108167.792,108513.376,108858.96,109204.544,109550.128,109895.712,110241.296,110586.88,110932.464,111278.048,111623.632,111969.216,112314.8,112660.384,113005.968,113351.552,113697.136,114042.72,114388.304,114733.888,115079.472,115425.056,115770.64,116116.224,116461.808,116807.392,117152.976,117498.56,11 ...

# %% [markdown]
# Let's look into more details to the time distribution of both classes transaction, as well as to aggregated values of transaction count and amount, per hour. We assume (based on observation of the time distribution of transactions) that the time unit is second.

# %%
# Her iki sınıf işleminin zaman dağılımının yanı sıra saat başına işlem sayısı ve tutarının toplu değerlerine ilişkin daha fazla ayrıntıya bakalım.
# (İşlemlerin zaman dağılımının gözlemine dayanarak) zaman biriminin ikinci olduğunu varsayıyoruz.

# %%
df['hour'] = df['time'].apply(lambda x: np.floor(x / 3600))# 1 ssaat 3600 sn

tmp = df.groupby(['hour', 'class'])['amount'].aggregate(['min', 'max', 'count', 'sum', 'mean', 'median', 'var']).reset_index()
df1 = pd.DataFrame(tmp)
df1.columns = ['hour', 'class', 'Min', 'Max', 'Transactions', 'Sum', 'Mean', 'Median', 'Var']
df1.head()
# saniyelri saate cevirdik
# Out:
#    hour  class    Min      Max  Transactions        Sum    Mean  Median  \
# 0 0.000      0  0.000 7712.430          3929 255825.950  65.112  12.990
# 1 0.000      1  0.000  529.000             2    529.000 264.500 264.500
# 2 1.000      0  0.000 1769.690          2211 145744.590  65.918  23.000
# 3 1.000      1 59.000  239.930             2    298.930 149.465 149.465
# 4 2.000      0  0.000 4002.880          1552 106983.390  68.933  17.985
#
#          Var
# 0  45961.839
# 1 139920.500
# 2  20085.296
# 3  16367.832
# 4  45434.510

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="hour", y="Sum", data=df1.loc[df1["class"] == 0])
s = sns.lineplot(ax = ax2, x="hour", y="Sum", data=df1.loc[df1["class"] == 1], color="red")
plt.suptitle("Total Amount")
plt.show();
# kirmizilar fraud oldugu saatler
# maviler non-fraud olan degerler 
# zaman 0 dan basliyr - deger yok. 
# data 48 saatilik data 
# 20-30 arasi genelde uyudugu saaatler gibi
# gun icinde hars hours insanlar daha cok dolandiriliyor denilebilir

# %% [markdown]
# -- bu notebookdan daha biseler alabilirsin
# https://www.kaggle.com/code/gpreda/credit-card-fraud-detection-predictive-models

# %%
plt.figure(figsize=(10,10))
df.corr()["class"].drop("class").sort_values().plot.barh(color='brown' );

# %%
index = 0
plt.figure(figsize=(20,20))
for feature in df.columns :
    if feature != 'class' :
        index += 1
        plt.subplot(8,4,index)
        sns.boxplot(x = 'class', y = feature, data = df)
plt.tight_layout()
# plt.colors("red")
plt.show();

# %%
# %matplotlib inline
matrix = np.triu(df.corr())
fig,ax = plt.subplots(figsize=(24, 16),dpi=100)
sns.heatmap (df.corr(), annot=True, ax=ax, fmt='.2f', vmin=-1, vmax=1, center=0,mask=matrix, cmap='RdBu')
plt.xticks(rotation = 45);

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# #### Train - Test Split
#
# As in this case, for extremely imbalanced datasets you may want to make sure that classes are balanced across train and test data.

# %% [markdown]
# #### Scaling

# %% [markdown]
# try without scaler

# %% [markdown]
# This Scaler removes the median and scales the data according to the quantile range. [Source](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)

# %%
drop_columns(df, ["hour"])
# Out:
# ['hour'] were dropped

# %%
df_model, predict = \
              np.split(df.sample(frac=1, random_state=16), 
                       [int(.95*len(df))])

# %%
df_model.shape
# Out:
# (269539, 31)

# %%
predict.shape
# Out:
# (14187, 31)

# %%
X = df_model.drop(["class"], axis=1)
y = df_model["class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, stratify= y, random_state= 16)

# %% [markdown]
# ## 3. Model Building
# It was previously stated that you need to make class prediction with three different algorithms. As in this case, different approaches are required to obtain better performance on unbalanced data.
#
# This dataset is severely **unbalanced** (most of the transactions are non-fraud). So the algorithms are much more likely to classify new observations to the majority class and high accuracy won't tell us anything. To address the problem of imbalanced dataset we can use undersampling and oversampling data approach techniques. Oversampling increases the number of minority class members in the training set. The advantage of oversampling is that no information from the original training set is lost unlike in undersampling, as all observations from the minority and majority classes are kept. On the other hand, it is prone to overfitting.
#
# There is a type of oversampling called **[SMOTE](https://www.geeksforgeeks.org/ml-handling-imbalanced-data-with-smote-and-near-miss-algorithm-in-python/)** (Synthetic Minority Oversampling Technique), which we are going to use to make our dataset balanced. It creates synthetic points from the minority class.
#
# - It is important that you can evaluate the effectiveness of SMOTE. For this reason, implement the Logistic Regression algorithm in two different ways, with SMOTE applied and without.
#
# ***Note***:
#
# - *Do not forget to import the necessary libraries and modules before starting the model building!*
#
# - *If you are going to use the cross validation method to be more sure of the performance of your model for unbalanced data, you should make sure that the class distributions in the iterations are equal. For this case, you should use **[StratifiedKFold](https://www.analyseup.com/python-machine-learning/stratified-kfold.html)** instead of regular cross validation method.*

# %% [markdown]
# ### Logistic Regression without SMOTE
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    i. Import Libraries
#
#    *ii. Model Training*
#
#    *iii. Prediction and Model Evaluating*
#
#    *iv. Plot Precision and Recall Curve*
#
#    *v. Apply and Plot StratifiedKFold*

# %% [markdown]
# ***i. Import Libraries***

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
clf = LogisticRegression(random_state= 16)

# %% [markdown]
# ***ii. Model Training***

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=16)

# %% [markdown]
# ***iii. Prediction and Model Evaluating***

# %%
train_pred = clf.predict(X_train)

test_pred = clf.predict(X_test)

# %%
matris_scorer(clf, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[80686    42]
#  [   47    87]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     80728
#            1       0.67      0.65      0.66       134
#
#     accuracy                           1.00     80862
#    macro avg       0.84      0.82      0.83     80862
# weighted avg       1.00      1.00      1.00     80862
#
#
# Train_Set
# [[188260    106]
#  [    91    220]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    188366
#            1       0.67      0.71      0.69       311
#
#     accuracy                           1.00    188677
#    macro avg       0.84      0.85      0.85    188677
# weighted avg       1.00      1.00      1.00    188677

# %%
model_scorer(clf, X_train, y_train, X_test, y_test)
# Out:
#            train_set  test_set
# Accuracy       0.999     0.999
# Precision      0.675     0.674
# Recall         0.707     0.649
# f1             0.691     0.662

# %% [markdown]
# You're evaluating "accuracy score"? Is your performance metric reflect real success? You may need to use different metrics to evaluate performance on unbalanced data. You should use **[precision and recall metrics](https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#:~:text=The%20precision%2Drecall%20curve%20shows,a%20low%20false%20negative%20rate.)**.

# %% [markdown]
# ***iv. Plot Precision and Recall Curve***

# %%
plot_precision_recall_curve(clf, X_test, y_test);

# %%
log_model_f1 = f1_score(y_test, test_pred)
log_model_recall = recall_score(y_test,test_pred)
log_model_auc = roc_auc_score(y_test, test_pred)

# %% [markdown]
# ***v. Apply StratifiedKFold***

# %% [markdown]
# ![image.png](attachment:image.png) [image source](*https://miro.medium.com/max/434/1*m0sr75BFm4C3kTbb84iWVQ.png*)

# %%
from sklearn.model_selection import StratifiedKFold

# %%
 y_pred_proba = clf.predict_proba(X_test)

# %%
precisions, recalls, thresholds = precision_recall_curve(test_pred, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]
optimal_threshold
# Out:
# 0.5104784845985002

# %%
def cv_kfold(n, est, X, y, optimal_threshold):
    skf = StratifiedKFold(n_splits = n, shuffle = True, random_state = 16)
    acc_scores = []
    pre_scores = []
    rec_scores = []
    f1_scores  = []
    
    X = X.reset_index(drop=True)       # Index no'ları her işlemden sonra sıfırlaması için.
    y = y.reset_index(drop=True)
    
    for train_index, test_index in skf.split(X, y):
        
        X_train = X.loc[train_index]
        y_train = y.loc[train_index]
        X_test = X.loc[test_index]
        y_test = y.loc[test_index]
        
        
        est = est
        est.fit(X_train, y_train)
        y_pred = est.predict(X_test)
        y_pred_proba = est.predict_proba(X_test)
             
        y_pred2 = pd.Series(y_pred_proba[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
        
        acc_scores.append(accuracy_score(y_test, y_pred2))
        pre_scores.append(precision_score(y_test, y_pred2, pos_label=1))
        rec_scores.append(recall_score(y_test, y_pred2, pos_label=1))
        f1_scores.append(f1_score(y_test, y_pred2, pos_label=1))
    
    print(f'Accuracy {np.mean(acc_scores)*100:>10,.2f}%  std {np.std(acc_scores)*100:.2f}%')
    print(f'Precision-1 {np.mean(pre_scores)*100:>7,.2f}%  std {np.std(pre_scores)*100:.2f}%')
    print(f'Recall-1 {np.mean(rec_scores)*100:>10,.2f}%  std {np.std(rec_scores)*100:.2f}%')
    print(f'F1_score-1 {np.mean(f1_scores)*100:>8,.2f}%  std {np.std(f1_scores)*100:.2f}%')

# %%
cv_kfold(5, clf, pd.DataFrame(X_train), y_train, 0.5)
# Out:
# Accuracy      99.91%  std 0.01%
# Precision-1   75.48%  std 6.21%
# Recall-1      67.85%  std 2.21%
# F1_score-1    71.27%  std 2.49%

# %%
cv_kfold(5, clf, pd.DataFrame(X_train), y_train, optimal_threshold)
# Out:
# Accuracy      99.91%  std 0.01%
# Precision-1   75.88%  std 5.54%
# Recall-1      67.85%  std 2.21%
# F1_score-1    71.48%  std 2.20%

# %% [markdown]
# - Didn't the performance of the model you implemented above satisfy you? If your model is biased towards the majority class and minority class recall is not sufficient, apply **SMOTE**.

# %% [markdown]
# # Logistic Regression with Grid Search

# %%
clf_grid = LogisticRegression(random_state= 16, class_weight='balanced',max_iter=1000)

# %%
penalty = ["l1", "l2"]
l1_ratio = np.linspace(0, 1, 20)
C = np.logspace(0, 10, 20)
solver = ["lbfgs"] 



param_grid = {"penalty" : penalty,
             
             "C" : C,
              "solver": solver,
              
}

# %%
grid_model = GridSearchCV(clf_grid, param_grid = param_grid,scoring= "recall" )

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(class_weight='balanced',
#                                           max_iter=1000, random_state=16),
#              param_grid={'C': array([1.00000000e+00, 3.35981829e+00, 1.12883789e+01, 3.79269019e+01,
#        1.27427499e+02, 4.28133240e+02, 1.43844989e+03, 4.83293024e+03,
#        1.62377674e+04, 5.45559478e+04, 1.83298071e+05, 6.15848211e+05,
#        2.06913808e+06, 6.95192796e+06, 2.33572147e+07, 7.84759970e+07,
#        2.63665090e+08, 8.85866790e+08, 2.97635144e+09, 1.00000000e+10]),
#                          'penalty': ['l1', 'l2'], 'solver': ['lbfgs']},
#              scoring='recall')

# %%
grid_model.best_params_
# Out:
# {'C': 11.28837891684689, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
log_grid_scorer= model_scorer(grid_model, X_train, y_train, X_test, y_test)
log_grid_scorer
# Out:
#            train_set  test_set
# Accuracy       0.962     0.962
# Precision      0.038     0.037
# Recall         0.916     0.896
# f1             0.073     0.072

# %%
plot_precision_recall_curve(grid_model, X_test, y_test);

# %%
y_pred = grid_model.predict(X_test)

# %%
# vanila modelin scorelarini compare kullanmak icin kaydettik.
log_grid_f1 = f1_score(y_test, test_pred)
log_grid_recall = recall_score(y_test,test_pred)
log_grid_auc = roc_auc_score(y_test, test_pred)

# %% [markdown]
# ## Shap with Feature Selection

# %%
#!pip install shap

# %%
import shap

# %%
model_shap = LogisticRegression(class_weight={1:25, 0:1}, random_state=16, penalty='l2', C=1.0, solver='lbfgs')

model_shap.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight={0: 1, 1: 25}, random_state=16)

# %%
explainer = shap.Explainer(model_shap, X_train)
shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values, X_test, feature_names=X.columns)

# %%
plt.figure(figsize=(14,6))

y_pred = pd.Series(grid_model.predict_proba(X_test)[:,1]).apply(lambda x: 1 if x >= optimal_threshold else 0)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='viridis', linewidth=1)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import Pipeline, make_pipeline

from sklearn.model_selection import cross_val_score, cross_validate, StratifiedKFold, GridSearchCV

from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
from sklearn.metrics import accuracy_score, f1_score,recall_score,precision_score
from sklearn.metrics import average_precision_score,precision_recall_curve,plot_precision_recall_curve

from yellowbrick.classifier import PrecisionRecallCurve
from yellowbrick.classifier import ClassPredictionError

# %%
viz = PrecisionRecallCurve(model_shap)

viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
viz = PrecisionRecallCurve(grid_model)

viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred_proba = grid_model.predict_proba(X_test)
average_precision_score(y_test, y_pred_proba[:,1])
# Out:
# 0.6615969126757115

# %% [markdown]
# ### Apply SMOTE

# %% [markdown]
# ![image.png](attachment:image.png) [source](https://miro.medium.com/max/1400/1*GJY7UnJ4WCzqgtrfkCvkdA.png)

# %% [markdown]
# ### Logistic Regression with SMOTE
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Train-Test Split (Again)*
#
#    *ii. Model Training*
#
#    *iii. Prediction and Model Evaluating*
#
#    *iv. Plot Precision and Recall Curve*
#
#    *v. Apply and Plot StratifiedKFold*

# %% [markdown]
# ***i. Train-Test Split (Again)***
#
# Use SMOTE applied data.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
y.value_counts()
# Out:
# 0    269094
# 1       445
# Name: class, dtype: int64

# %%
over = SMOTE(sampling_strategy={1: 1000})
under = RandomUnderSampler(sampling_strategy={0: 100000})

# %%
X_resampled, y_resampled = over.fit_resample(X_train, y_train)

X_resampled, y_resampled = under.fit_resample(X_resampled, y_resampled)

y_resampled.value_counts()
# Out:
# 0    100000
# 1      1000
# Name: class, dtype: int64

# %% [markdown]
# ***ii. Model Training***

# %%
log_smoth = LogisticRegression(class_weight={1:25, 0:1}, random_state=16, penalty='l2', C=1.0, solver='lbfgs')
log_smoth.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(class_weight={0: 1, 1: 25}, random_state=16)

# %% [markdown]
# ***iii. Prediction and Model Evaluating***

# %%
matris_scorer(log_smoth, X_resampled, y_resampled, X_test, y_test)
# Out:
# Test_Set
# [[79924   804]
#  [   21   113]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     80728
#            1       0.12      0.84      0.22       134
#
#     accuracy                           0.99     80862
#    macro avg       0.56      0.92      0.60     80862
# weighted avg       1.00      0.99      0.99     80862
#
#
# Train_Set
# [[99027   973]
#  [   78   922]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    100000
#            1       0.49      0.92      0.64      1000
#
#     accuracy                           0.99    101000
#    macro avg       0.74      0.96      0.82    101000
# weighted avg       0.99      0.99      0.99    101000

# %%
model_scorer(log_smoth, X_resampled, y_resampled, X_test, y_test)
# Out:
#            train_set  test_set
# Accuracy       0.990     0.990
# Precision      0.487     0.123
# Recall         0.922     0.843
# f1             0.637     0.215

# %% [markdown]
# ***iv.  Plot Precision and Recall Curve***

# %%
plot_precision_recall_curve(log_smoth, X_test, y_test);

# %% [markdown]
# ***v. Apply StratifiedKFold***

# %%
cv_kfold(10, log_smoth, pd.DataFrame(X_train), y_train, 0.5)
# Out:
# Accuracy      99.59%  std 0.09%
# Precision-1   26.72%  std 4.00%
# Recall-1      81.66%  std 5.43%
# F1_score-1    40.02%  std 4.44%

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]

# %%
 cv_kfold(10, log_smoth, pd.DataFrame(X_train), y_train, optimal_threshold)
# Out:
# Accuracy      99.60%  std 0.08%
# Precision-1   27.29%  std 4.06%
# Recall-1      81.66%  std 5.43%
# F1_score-1    40.66%  std 4.42%

# %%
y_pred = log_smoth.predict(X_test)
log_smoth_f1 = f1_score(y_test, y_pred)
log_smoth_recall = recall_score(y_test, y_pred)
log_smoth_auc = roc_auc_score(y_test, y_pred)

# %% [markdown]
# ### Random Forest Classifier with SMOTE
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Model Training*
#
#    *ii. Prediction and Model Evaluating*
#
#    *iii. Plot Precision and Recall Curve*
#
#    *iv. Apply and Plot StratifiedKFold*

# %% [markdown]
# ***i. Model Training***

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ***ii. Prediction and Model Evaluating***

# %%
rf_model= RandomForestClassifier(random_state= 16)
rf_model.fit(X_train, y_train)
matris_scorer(rf_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[80719     9]
#  [   29   105]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     80728
#            1       0.92      0.78      0.85       134
#
#     accuracy                           1.00     80862
#    macro avg       0.96      0.89      0.92     80862
# weighted avg       1.00      1.00      1.00     80862
#
#
# Train_Set
# [[188366      0]
#  [     0    311]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    188366
#            1       1.00      1.00      1.00       311
#
#     accuracy                           1.00    188677
#    macro avg       1.00      1.00      1.00    188677
# weighted avg       1.00      1.00      1.00    188677

# %%
model_scorer(rf_model, X_train, y_train, X_test, y_test)
# Out:
#            train_set  test_set
# Accuracy       1.000     1.000
# Precision      1.000     0.921
# Recall         1.000     0.784
# f1             1.000     0.847

# %%
plot_precision_recall_curve(rf_model, X_test, y_test);

# %%
y_pred = rf_model.predict(X_test)
rf_model_f1 = f1_score(y_test, y_pred)
rf_model_recall = recall_score(y_test, y_pred)
rf_model_auc = roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## Smote with Random Forest Classifier

# %% [markdown]
# ***iii. Fit & Prediction and Model Evaluating***

# %%
smote_rf= RandomForestClassifier(random_state= 16)
smote_rf.fit(X_resampled, y_resampled)
matris_scorer(smote_rf, X_resampled, y_resampled, X_test_scaled, y_test)
# Out:
# Test_Set
# [[80710    18]
#  [   31   103]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     80728
#            1       0.85      0.77      0.81       134
#
#     accuracy                           1.00     80862
#    macro avg       0.93      0.88      0.90     80862
# weighted avg       1.00      1.00      1.00     80862
#
#
# Train_Set
# [[100000      0]
#  [     0   1000]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    100000
#            1       1.00      1.00      1.00      1000
#
#     accuracy                           1.00    101000
#    macro avg       1.00      1.00      1.00    101000
# weighted avg       1.00      1.00      1.00    101000

# %% [markdown]
# f1 100 olan code icin bak http://localhost:8888/notebooks/My%20Drive/Clarusway/GitHub/Machine-Learning/InClass/ML-9%20(Logistic%20Regression-diabates).ipynb

# %%
model_scorer(smote_rf, X_resampled, y_resampled, X_test, y_test)
# Out:
#            train_set  test_set
# Accuracy       1.000     0.999
# Precision      1.000     0.831
# Recall         1.000     0.806
# f1             1.000     0.818

# %%
plot_precision_recall_curve(smote_rf, X_test, y_test);

# %%
y_pred = smote_rf.predict(X_test)
smote_rf_f1 = f1_score(y_test, y_pred)
smote_rf_recall = recall_score(y_test, y_pred)
smote_rf_auc = roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## Random Forest with Grid Search

# %%
'''
param_grid_rf = {"n_estimators": [100,200,500,1000],
            "max_features": [3,5,7,8],
            "max_depth": [3,4,5,6],
            "min_samples_split": [2,5,10,20]}'''
            # 7 saat surdu :()
# Out:
# '\nparam_grid_rf = {"n_estimators": [100,200,500,1000],\n            "max_features": [3,5,7,8],\n            "max_depth": [3,4,5,6],\n            "min_samples_split": [2,5,10,20]}'

# %%
smote_rf_grid= RandomForestClassifier(random_state= 16, 
                                 n_estimators= 100)

# %%
param_grid = {
             'max_features':[5, 7],
             'max_depth':[5, 7]}

# %%
rf_grid = GridSearchCV(smote_rf_grid, param_grid, n_jobs = -1, verbose = 2,scoring= "recall")

# %%
rf_grid.fit(X_resampled, y_resampled)
matris_scorer(rf_grid, X_resampled, y_resampled, X_test, y_test)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 rf_grid.fit(X_resampled, y_resampled)
#       2 matris_scorer(rf_grid, X_resampled, y_resampled, X_test, y_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~\anaconda3\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
model_scorer(rf_grid, X_resampled, y_resampled, X_test, y_test)

# %%
rf_grid.best_params_

# %%
plot_precision_recall_curve(rf_grid, X_test, y_test);

# %%
y_pred = rf_grid.predict(X_test)
rf_grid_f1 = f1_score(y_test, y_pred)
rf_grid_recall = recall_score(y_test, y_pred)
rf_grid_auc = roc_auc_score(y_test, y_pred)

# %%
rf_grid.best_estimator_.feature_importances_

# %%
feats = pd.DataFrame(index=X.columns, data= rf_grid.best_estimator_.feature_importances_, columns=["Feature Importance"])
RF_feature_imp = feats.sort_values("Feature Importance", ascending=False)

RF_feature_imp

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=RF_feature_imp["Feature Importance"], x=RF_feature_imp.index)

plt.title("Feature Importance")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Random Forest With Shap

# %%
explainer = shap.TreeExplainer(smote_rf)
shap_values = explainer.shap_values(X_test,approximate=True)
shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=X.columns)

# %%
feature_rf_last = ['v14', 'v17', 'v12', 'v10', 'v11',"v4", "v3","v7", 'v16']

# %%
X_rf_shap= df[feature_rf_last]
y = df["class"]

# %%
X_train_sh, X_test_sh, y_train_sh, y_test_sh = train_test_split(X_rf_shap, y, test_size=0.1, random_state=16, stratify =y)

# %%
shap_rf_model = RandomForestClassifier(max_depth=5, random_state=16)

# %%
shap_rf_model.fit(X_train_sh, y_train_sh)
# Out:
# RandomForestClassifier(max_depth=5, random_state=16)

# %%
matris_scorer(shap_rf_model, X_train_sh, y_train_sh, X_test_sh, y_test_sh)
# Out:
# Test_Set
# [[28319     7]
#  [   14    33]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28326
#            1       0.82      0.70      0.76        47
#
#     accuracy                           1.00     28373
#    macro avg       0.91      0.85      0.88     28373
# weighted avg       1.00      1.00      1.00     28373
#
#
# Train_Set
# [[254908     19]
#  [    87    339]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    254927
#            1       0.95      0.80      0.86       426
#
#     accuracy                           1.00    255353
#    macro avg       0.97      0.90      0.93    255353
# weighted avg       1.00      1.00      1.00    255353

# %%
model_scorer(shap_rf_model, X_train_sh, y_train_sh, X_test_sh, y_test_sh)
# Out:
#            train_set  test_set
# Accuracy       1.000     0.999
# Precision      0.947     0.825
# Recall         0.796     0.702
# f1             0.865     0.759

# %%
# scorelarimiza cv ile butun datada baktik asagida :) karsilastirmak icin.

# %%
scores = cross_validate(shap_rf_model, X_train_sh, y_train_sh, scoring = ['accuracy', 'precision', 'recall', 'f1'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))

df_scores.mean()[2:]
# Out:
# test_accuracy    0.999
# test_precision   0.915
# test_recall      0.751
# test_f1          0.824
# dtype: float64

# %%
y_pred = shap_rf_model.predict(X_test_sh)
shap_rf_f1 = f1_score(y_test_sh, y_pred)
shap_rf_recall = recall_score(y_test_sh, y_pred)
shap_rf_auc = roc_auc_score(y_test_sh, y_pred)

# %% [markdown]
# ## Logistic Regresion with Shap

# %%
log_shap_model =  LogisticRegression(class_weight={1:25, 0:1}, random_state=16, penalty='l2', C=1.0, solver='saga')
log_shap_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight={0: 1, 1: 25}, random_state=16, solver='saga')

# %%
matris_scorer(log_shap_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[80673    55]
#  [   26   108]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     80728
#            1       0.66      0.81      0.73       134
#
#     accuracy                           1.00     80862
#    macro avg       0.83      0.90      0.86     80862
# weighted avg       1.00      1.00      1.00     80862
#
#
# Train_Set
# [[188242    124]
#  [    52    259]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    188366
#            1       0.68      0.83      0.75       311
#
#     accuracy                           1.00    188677
#    macro avg       0.84      0.92      0.87    188677
# weighted avg       1.00      1.00      1.00    188677

# %%
model_scorer(log_shap_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#            train_set  test_set
# Accuracy       0.999     0.999
# Precision      0.676     0.663
# Recall         0.833     0.806
# f1             0.746     0.727

# %%
df.columns
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
#        'class'],
#       dtype='object')

# %%
explainer = shap.Explainer(log_shap_model, X_train_scaled)    # Feature' lara göre renklendirme yapamadım?

shap_values = explainer.shap_values(X_test_scaled)

shap.summary_plot(shap_values, X_train_scaled, plot_type="bar")

# %%
feature_log_shap = ['v4', 'v14', 'v12', 'v10', 'time', 'v13',"v8","v16"]

# %%
X_shap = df[feature_log_shap]
y = df["class"]

# %%
X_train_shap, X_test_shap, y_train_shap, y_test_shap = train_test_split(X_shap, y, test_size=0.1, random_state=16, stratify =y)

# %%
# pipe model ile bir variable cagirarak islemimizi. hizlandirdik.

# %% [markdown]
# ### PipeModel

# %%
# Bu modeli kurarken pipeline kullandik 
# amac pipeline modelide notebookumuza eklemek
# Bizim istekelrimizi (data porcessing ve modelling asamalarini) tek satirda yapmamizi sagladi.
#

# %%
operations = [("scaler", RobustScaler()), ('log', LogisticRegression(class_weight={1:25, 0:1}, random_state=16, penalty='l2', C=1.0, solver='saga'))]
pipe_model_log_shap = Pipeline(steps=operations)
pipe_model_log_shap.fit(X_train_shap, y_train_shap)
matris_scorer(pipe_model_log_shap, X_train_shap, y_train_shap, X_test_shap, y_test_shap)
# Out:
# Test_Set
# [[28300    26]
#  [   11    36]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28326
#            1       0.58      0.77      0.66        47
#
#     accuracy                           1.00     28373
#    macro avg       0.79      0.88      0.83     28373
# weighted avg       1.00      1.00      1.00     28373
#
#
# Train_Set
# [[254723    204]
#  [    65    361]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    254927
#            1       0.64      0.85      0.73       426
#
#     accuracy                           1.00    255353
#    macro avg       0.82      0.92      0.86    255353
# weighted avg       1.00      1.00      1.00    255353

# %%
model_scorer(pipe_model_log_shap, X_train_shap, y_train_shap, X_test_shap, y_test_shap)
# Out:
#            train_set  test_set
# Accuracy       0.999     0.999
# Precision      0.639     0.581
# Recall         0.847     0.766
# f1             0.729     0.661

# %%
# butun data da gormek icinde cv yi denedik ykardaki ciktilar dogrumu ?

# %%
scores = cross_validate(pipe_model_log_shap, X_train_shap, y_train_shap, scoring = ['precision','recall','f1','accuracy'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision   0.646
# test_recall      0.845
# test_f1          0.730
# test_accuracy    0.999
# dtype: float64

# %%
y_pred = pipe_model_log_shap.predict(X_test_shap)
log_shap_f1 = f1_score(y_test_shap, y_pred)
log_shap_recall = recall_score(y_test_shap, y_pred)
log_shap_auc = roc_auc_score(y_test_shap, y_pred)

# %% [markdown]
# ***iii. Plot Precision and Recall Curve***

# %% [markdown]
# ***iv. Apply StratifiedKFold***

# %%
# without class_weight for StratifiedKFold :

rf_kfold = RandomForestClassifier(max_depth=7, random_state= 16)


rf_kfold.fit(X_resampled, y_resampled)

matris_scorer(rf_kfold, X_resampled, y_resampled, X_test, y_test)
# Out:
# Test_Set
# [[80709    19]
#  [   29   105]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     80728
#            1       0.85      0.78      0.81       134
#
#     accuracy                           1.00     80862
#    macro avg       0.92      0.89      0.91     80862
# weighted avg       1.00      1.00      1.00     80862
#
#
# Train_Set
# [[99992     8]
#  [  155   845]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    100000
#            1       0.99      0.84      0.91      1000
#
#     accuracy                           1.00    101000
#    macro avg       0.99      0.92      0.96    101000
# weighted avg       1.00      1.00      1.00    101000

# %%
y_pred_proba = rf_kfold.predict_proba(X_test)
average_precision_score(y_test, y_pred_proba[:,1])
# Out:
# 0.7933942549550432

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]
optimal_threshold
# Out:
# 0.5955719028564848

# %%
cv_kfold(10, rf_kfold, pd.DataFrame(X_train), y_train, optimal_threshold)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [172], in <cell line: 1>()
# ----> 1 cv_kfold(10, rf_kfold, pd.DataFrame(X_train), y_train, optimal_threshold)
#
# Input In [78], in cv_kfold(n, est, X, y, optimal_threshold)
#      18 y_test = y.loc[test_index]
#      21 est = est
# ---> 22 est.fit(X_train, y_train)
#      23 y_pred = est.predict(X_test)
#      24 y_pred_proba = est.predict_proba(X_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Neural Network
#
# In the final step, you will make classification with Neural Network which is a Deep Learning algorithm.
#
# Neural networks are a series of algorithms that mimic the operations of a human brain to recognize relationships between vast amounts of data. They are used in a variety of applications in financial services, from forecasting and marketing research to fraud detection and risk assessment.
#
# A neural network contains layers of interconnected nodes. Each node is a perceptron and is similar to a multiple linear regression. The perceptron feeds the signal produced by a multiple linear regression into an activation function that may be nonlinear.
#
# In a multi-layered perceptron (MLP), perceptrons are arranged in interconnected layers. The input layer collects input patterns. The output layer has classifications or output signals to which input patterns may map.
#
# Hidden layers fine-tune the input weightings until the neural network’s margin of error is minimal. It is hypothesized that hidden layers extrapolate salient features in the input data that have predictive power regarding the outputs.
#
# You will discover **[how to create](https://towardsdatascience.com/building-our-first-neural-network-in-keras-bdc8abbc17f5)** your deep learning neural network model in Python using **[Keras](https://keras.io/about/)**. Keras is a powerful and easy-to-use free open source Python library for developing and evaluating deep learning models.
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Import Libraries*
#
#    *ii. Define Model*
#
#    *iii. Compile Model*
#
#    *iv. Fit Model*
#
#    *v. Prediction and Model Evaluating*
#
#    *vi. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Import Libraries***

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

from sklearn.utils import class_weight

# %%
tf.__version__

# %% [markdown]
# ***ii. Define Model***

# %% [markdown]
# -- burda modele yukardan gelen en iyi future importance dolayi gelen columlar alinmis

# %%
col = ['v3','v4','v7','v10','v11','v12','v14','v16','v17','amount']

# %%
X = df[col]
y = df['class'].values

# %%
seed = 16

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size = 0.20, random_state=seed)

# %%
print("Train features shape : ", X_train.shape)
print("Test features shape  : ", X_test.shape)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
tf.random.set_seed(seed)

model = Sequential() # sirali yapi deeplearning olmazsa olmazi

model.add(Dense(64, input_dim = X_train.shape[1]))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(32))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(16))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ***iii. Compile Model***

# %%
opt = Adam(lr = 0.005) # optimizar adam iyi calisyordu 
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['Recall'])

# %% [markdown]
# ***iv. Fit Model***

# %%
early_stop = EarlyStopping(monitor="val_recall",# test edilen datanin sonucu bu oldugu iicn aldik
                           mode="auto",# 
                           verbose=1, # 
                           patience=5, # arda arda 5 adimda score iylesmiyorsa egitimi kes
                           restore_best_weights = True) # en iyi sonucu bize donderecek

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 200, callbacks=[early_stop], verbose=1)

# %%
model.summary()

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()

# %% [markdown]
# ***v. Prediction and Model Evaluating***

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve, average_precision_score, precision_recall_curve

# %%
loss_df=pd.DataFrame(model.history.history)
loss_df.plot()

# %%
# los cok duusuk gozukmuyor
# over fit yok 
# value los 7 ci epocdam sonra bozouluyor.

# %%
model.evaluate(X_test, y_test, verbose=0) 
# verbose hangi clasa bakicagi
# 0 i yuzde 61 oraninda dogru tahmin ediyor
# bilgi kaybim yuzde 0.004 dur

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("Recall : ", recall)

# %%
#0.1 test size
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# ***vi. Plot Precision and Recall Curve***

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# model classlari tahmin etmede yuzde 66 oraninda basarilidir.

# %%
# dl modeli = model dedik 
model_f1 = f1_score(y_test, y_pred)
model_recall = recall_score(y_test, y_pred)
model_auc = roc_auc_score(y_test, y_pred)

# %% [markdown]
# # Deep Learning with  Full Feature

# %%
X = df.drop("class",axis=1)
y = df['class'].values

# %%
seed = 16

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size = 0.20, random_state=seed)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
tf.random.set_seed(seed)

model1 = Sequential()

model1.add(Dense(64, input_dim = X_train.shape[1]))
model1.add(BatchNormalization()) # scalling bir sonra ki adima gecmeden yapiyor.
model1.add(Activation('relu')) # biizm degerlerimiz 1 ili 0 arasina cekiyor.
model1.add(Dense(32))
model1.add(BatchNormalization())
model1.add(Activation('relu'))
model1.add(Dense(16))
model1.add(BatchNormalization())
model1.add(Activation('relu'))
model1.add(Dense(1, activation='sigmoid'))

opt = Adam(lr = 0.005)
model1.compile(optimizer=opt, loss='binary_crossentropy', metrics=['Recall'])

# %%
early_stop = EarlyStopping(monitor="val_recall",
                           mode="auto",
                           verbose=1,
                           patience=5, restore_best_weights = True)

# %%
model1.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 50, callbacks=[early_stop], verbose=1)

# %%
model1.summary()

# %%
loss_df = pd.DataFrame(model1.history.history)
loss_df.head()

# %%
loss_df.plot();

# %%
#0.1 test size
y_pred = (model1.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
y_pred_proba = model1.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %%
model1_f1 = f1_score(y_test, y_pred)
model1_recall = recall_score(y_test, y_pred)
model1_auc = roc_auc_score(y_test, y_pred)

# %% [markdown]
# # Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "Logistic Regression Grid", "Logistic Regression Smote", "Random Forest ","Random Forest Smote", 
                                   "Random Forest Grid","Random Forest Shap","Logistic Regression Shap","Deep Learning(ANN) FI ","Deep Learning(ANN)"],
                        
                        "F1": [log_model_f1, log_grid_f1 , log_smoth_f1, rf_model_f1, smote_rf_f1 , rf_grid_f1, shap_rf_f1, log_shap_f1, model_f1,model1_f1],
                        "Recall": [log_model_recall , log_grid_recall, log_smoth_recall ,rf_model_recall, smote_rf_recall, rf_grid_recall , shap_rf_recall,log_shap_recall,model_recall,model1_recall],
                        "ROC_AUC": [log_model_auc, log_grid_auc , log_smoth_auc, rf_model_auc , smote_rf_auc , rf_grid_auc , shap_rf_auc, log_shap_auc, model_auc, model1_auc ]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="RdPu")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="RdPu")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="ROC_AUC", ascending=False)
ax=sns.barplot(x="ROC_AUC", y="Model", data=compare, palette="RdPu")
labels(ax)
plt.show()

# %% [markdown]
# ## 4. Model Deployement
# You cooked the food in the kitchen and moved on to the serving stage. The question is how do you showcase your work to others? Model Deployement helps you showcase your work to the world and make better decisions with it. But, deploying a model can get a little tricky at times. Before deploying the model, many things such as data storage, preprocessing, model building and monitoring need to be studied.
#
# Deployment of machine learning models, means making your models available to your other business systems. By deploying models, other systems can send data to them and get their predictions, which are in turn populated back into the company systems. Through machine learning model deployment, can begin to take full advantage of the model you built.
#
# Data science is concerned with how to build machine learning models, which algorithm is more predictive, how to design features, and what variables to use to make the models more accurate. However, how these models are actually used is often neglected. And yet this is the most important step in the machine learning pipline. Only when a model is fully integrated with the business systems, real values ​​can be extract from its predictions.
#
# After doing the following operations in this notebook, jump to a proper IDE and create your web app with Streamlit API.

# %% [markdown]
# Final model

# %%
feature_rf_last

# %%
X = df[feature_rf_last]
y = df["class"]

# %%
rf_model = RandomForestClassifier(class_weight={1:25, 0:1}, max_depth=5, random_state=16)
rf_model.fit(X, y)

# %% [markdown]
# ### Save and Export the Model as .pkl

# %%
import joblib # modeli dosya halinde kaydediyor. Picckle a alternatif denedik.
joblib.dump(rf_model, open('rf_model.pkl', 'wb'))

# %% [markdown]
# ### Save and Export Variables as .pkl

# %%
# joblib.dump(scaler, open("scaler.pkl", 'wb'))
# scaling ithtiyac olan bir algoritma olsaydi bunuda kaydederdik
# tree based modeller scallinge ihtiyac duymuyor

# %% [markdown]
# Prediction

# %%
# final modelimizin sonuclarini gormedigi bir data seti ile denedik.

# %%
from tensorflow.keras.models import load_model

# %%
rf_model = joblib.load(open("rf_model.pkl", "rb"))

# %%
samples = predict,[X.columns]
samples

# %%
# Prediction with Random Forest 
rf_model.predict(samples)

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# https://medium.com/@merickosetorunu/makine-%C3%B6%C4%9Frenmesi-model-olu%C5%9Fturma-rehberi-b61cfc7d5db4

# %% [markdown]
# https://ink.library.smu.edu.sg/cgi/viewcontent.cgi?article=2898&context=soa_research

# %% [markdown]
# https://medium.com/finartz/maki%CC%87ne-%C3%B6%C4%9Frenmesi%CC%87-fraud-etki%CC%87le%C5%9Fi%CC%87mi%CC%87-nedi%CC%87r-
#
# https://medium.com/@gulcanogundur/do%C4%9Fruluk-accuracy-kesinlik-precision-duyarl%C4%B1l%C4%B1k-recall-ya-da-f1-score-300c925feb38
#
#
# https://medium.com/finartz/maki%CC%87ne-%C3%B6%C4%9Frenmesi%CC%87-fraud-etki%CC%87le%C5%9Fi%CC%87mi%CC%87-nedi%CC%87r-38a9f48c09c4

# %% [markdown]
# https://towardsdatascience.com/20x-times-faster-grid-search-cross-validation-19ef01409b7c

# %% [markdown]
# https://medium.com/bili%C5%9Fim-hareketi/hiperparametre-optimizasyonu-9ba0e7f32e6f

# %% [markdown]
# https://gist.github.com/KhyatiMahendru/734da147385bcf630a42ba7c11cfc6c4#file-creditcardfrauddetection-ipynb

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html
#
# https://medium.com/@gulcanogundur/model-se%C3%A7imi-k-fold-cross-validation-4635b61f143c
